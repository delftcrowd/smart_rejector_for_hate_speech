# %%
from rejector.prediction import Prediction
from rejector.values import Values
from rejector.metric import Metric
import logging
logging.basicConfig()
logging.getLogger().setLevel(logging.INFO)

values = Values(value_TP=0, value_TN=0, value_FP=25.771068, value_FN=33.822411,value_rejection=16.081677)

# %% [markdown]
# # Logistic Regression metric results

# %% [markdown]
# ### Trained on: SemEval (2019) | Tested on: Waseem and Hovy (2016)

# %%
predictions = Prediction.load("input/lr-semeval-waseem.p", gold_class="Hate")
metric = Metric(values, predictions)
metric.plot_pdfs()
metric.plot_effectiveness(use_pdf=False)
# Out:
# INFO:root:Fraction of TPS: 0.022374145431945307
# INFO:root:Fraction of TNS: 0.6699813548788067
# INFO:root:Fraction of FPS: 0.016159105034182723
# INFO:root:Fraction of FNS: 0.29148539465506523
# INFO:root:KDE optimal bandwidths: [0.03689988]
# INFO:root:KDE optimal bandwidths: [0.0128272]
# INFO:root:KDE optimal bandwidths: [0.05265914]
# INFO:root:KDE optimal bandwidths: [0.01782487]

# %% [markdown]
# ### Trained on: SemEval (2019) | Tested on: SemEval (2019)

# %%
predictions = Prediction.load("input/lr-semeval-semeval.p", gold_class="Hate")
metric = Metric(values, predictions)
metric.plot_pdfs()
metric.plot_effectiveness(use_pdf=False)
# Out:
# INFO:root:Fraction of TPS: 0.26416666666666666
# INFO:root:Fraction of TNS: 0.47
# INFO:root:Fraction of FPS: 0.11
# INFO:root:Fraction of FNS: 0.15583333333333332
# c:\Users\phili\anaconda3\envs\smart-rejector\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)
# INFO:root:KDE optimal bandwidths: [0.0090993]
# INFO:root:KDE optimal bandwidths: [0.01246497]
# INFO:root:KDE optimal bandwidths: [0.01950618]
# INFO:root:KDE optimal bandwidths: [0.01417581]

# %% [markdown]
# ### Trained on: Waseem and Hovy (2016) | Tested on: Waseem and Hovy (2016)

# %%
predictions = Prediction.load("input/lr-waseem-waseem.p", gold_class="Hate")
metric = Metric(values, predictions)
metric.plot_pdfs()
metric.plot_effectiveness(use_pdf=False)
# Out:
# INFO:root:Fraction of TPS: 0.22001243008079552
# INFO:root:Fraction of TNS: 0.6333126165320074
# INFO:root:Fraction of FPS: 0.052827843380981974
# INFO:root:Fraction of FNS: 0.09384711000621504
# c:\Users\phili\anaconda3\envs\smart-rejector\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)
# c:\Users\phili\anaconda3\envs\smart-rejector\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: divide by zero encountered in log
#   L += func(f_i)
# INFO:root:KDE optimal bandwidths: [0.00530127]
# INFO:root:KDE optimal bandwidths: [0.00476255]
# INFO:root:KDE optimal bandwidths: [0.00979833]
# INFO:root:KDE optimal bandwidths: [0.01980497]

# %% [markdown]
# ### Trained on: Waseem and Hovy (2016) | Tested on: SemEval (2019)

# %%
predictions = Prediction.load("input/lr-waseem-semeval.p", gold_class="Hate")
metric = Metric(values, predictions)
metric.plot_pdfs()
metric.plot_effectiveness(use_pdf=False)
# Out:
# INFO:root:Fraction of TPS: 0.21833333333333332
# INFO:root:Fraction of TNS: 0.4125
# INFO:root:Fraction of FPS: 0.1675
# INFO:root:Fraction of FNS: 0.20166666666666666
# c:\Users\phili\anaconda3\envs\smart-rejector\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)
# INFO:root:KDE optimal bandwidths: [0.00906045]
# INFO:root:KDE optimal bandwidths: [0.01011871]
# c:\Users\phili\anaconda3\envs\smart-rejector\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: divide by zero encountered in log
#   L += func(f_i)
# INFO:root:KDE optimal bandwidths: [0.00736247]
# INFO:root:KDE optimal bandwidths: [0.01192505]

# %%
accepted = list(filter(lambda p: p.predicted_value >= 0.5305, predictions))
correct_accepted = list(filter(lambda p: p.predicted_class == p.actual_class, accepted))
rejected = list(filter(lambda p: p.predicted_value < 0.5305, predictions))
print("Num accepted: ", len(accepted))
print("Accuracy accepted: ", len(correct_accepted) / len(accepted))
print("Num rejected: ", len(rejected))
# Out:
# Num accepted:  1150
# Accuracy accepted:  0.6452173913043479
# Num rejected:  50
