# %%
from rejector.prediction import Prediction
from rejector.values import Values
from rejector.metric import Metric
import logging
logging.basicConfig()
logging.getLogger().setLevel(logging.INFO)

values = Values(value_TP=0, value_TN=0, value_FP=25.420172, value_FN=35.27941,value_rejection=16.937694)

# %% [markdown]
# # CNN metric results

# %% [markdown]
# ### Trained on: SemEval (2019) | Tested on: Waseem and Hovy (2016)

# %%
predictions = Prediction.load("input/cnn-semeval-waseem.p", gold_class="Hate")
metric = Metric(values, predictions)
metric.plot_pdfs()
metric.plot_effectiveness()
# Out:
# INFO:root:Fraction of TPS: 0.09073958980733375
# INFO:root:Fraction of TNS: 0.5618396519577378
# INFO:root:Fraction of FPS: 0.12430080795525171
# INFO:root:Fraction of FNS: 0.22311995027967682
# INFO:root:KDE optimal bandwidths: [0.01943917]
# c:\Users\phili\anaconda3\envs\smart-rejector\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)
# INFO:root:KDE optimal bandwidths: [0.00703296]
# INFO:root:KDE optimal bandwidths: [0.0044211]
# INFO:root:KDE optimal bandwidths: [0.01567338]

# %%
accepted = list(filter(lambda p: p.predicted_value >= 0.7528, predictions))
correct_accepted = list(filter(lambda p: p.predicted_class == p.actual_class, accepted))
rejected = list(filter(lambda p: p.predicted_value < 0.7528, predictions))
print("Num accepted: ", len(accepted))
print("Accuracy accepted: ", len(correct_accepted) / len(accepted))
print("Num rejected: ", len(rejected))
# Out:
# Num accepted:  500
# Accuracy accepted:  0.716
# Num rejected:  1109

# %% [markdown]
# ### Trained on: SemEval (2019) | Tested on: SemEval (2019)

# %%
predictions = Prediction.load("input/cnn-semeval-semeval.p", gold_class="Hate")
metric = Metric(values, predictions)
metric.plot_pdfs()
metric.plot_effectiveness()
# Out:
# INFO:root:Fraction of TPS: 0.25666666666666665
# INFO:root:Fraction of TNS: 0.44333333333333336
# INFO:root:Fraction of FPS: 0.13666666666666666
# INFO:root:Fraction of FNS: 0.16333333333333333
# c:\Users\phili\anaconda3\envs\smart-rejector\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)
# INFO:root:KDE optimal bandwidths: [0.01463345]
# INFO:root:KDE optimal bandwidths: [0.00805507]
# INFO:root:KDE optimal bandwidths: [0.01407115]
# INFO:root:KDE optimal bandwidths: [0.01558962]

# %%
accepted = list(filter(lambda p: p.predicted_value >= 0.7377, predictions))
correct_accepted = list(filter(lambda p: p.predicted_class == p.actual_class, accepted))
rejected = list(filter(lambda p: p.predicted_value < 0.7377, predictions))
print("Num accepted: ", len(accepted))
print("Accuracy accepted: ", len(correct_accepted) / len(accepted))
print("Num rejected: ", len(rejected))
# Out:
# Num accepted:  499
# Accuracy accepted:  0.779559118236473
# Num rejected:  701

# %% [markdown]
# ### Trained on: Waseem and Hovy (2016) | Tested on: Waseem and Hovy (2016)

# %%
predictions = Prediction.load("input/cnn-waseem-waseem.p", gold_class="Hate")
metric = Metric(values, predictions)
metric.plot_pdfs()
metric.plot_effectiveness()
# Out:
# INFO:root:Fraction of TPS: 0.21068986948415164
# INFO:root:Fraction of TNS: 0.6339341205717837
# INFO:root:Fraction of FPS: 0.05220633934120572
# INFO:root:Fraction of FNS: 0.10316967060285892
# c:\Users\phili\anaconda3\envs\smart-rejector\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)
# INFO:root:KDE optimal bandwidths: [0.00958806]
# INFO:root:KDE optimal bandwidths: [0.0091003]
# INFO:root:KDE optimal bandwidths: [0.02024222]
# INFO:root:KDE optimal bandwidths: [0.01700394]

# %%
accepted = list(filter(lambda p: p.predicted_value >= 0.7377, predictions))
correct_accepted = list(filter(lambda p: p.predicted_class == p.actual_class, accepted))
rejected = list(filter(lambda p: p.predicted_value < 0.7377, predictions))
print("Num accepted: ", len(accepted))
print("Accuracy accepted: ", len(correct_accepted) / len(accepted))
print("Num rejected: ", len(rejected))
# Out:
# Num accepted:  1286
# Accuracy accepted:  0.9043545878693624
# Num rejected:  323

# %% [markdown]
# ### Trained on: Waseem and Hovy (2016) | Tested on: SemEval (2019)

# %%
predictions = Prediction.load("input/cnn-waseem-semeval.p", gold_class="Hate")
metric = Metric(values, predictions)
metric.plot_pdfs()
metric.plot_effectiveness()
# Out:
# INFO:root:Fraction of TPS: 0.16416666666666666
# INFO:root:Fraction of TNS: 0.46
# INFO:root:Fraction of FPS: 0.12
# INFO:root:Fraction of FNS: 0.25583333333333336
# c:\Users\phili\anaconda3\envs\smart-rejector\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)
# INFO:root:KDE optimal bandwidths: [0.01038468]
# INFO:root:KDE optimal bandwidths: [0.00758734]
# INFO:root:KDE optimal bandwidths: [0.02637732]
# INFO:root:KDE optimal bandwidths: [0.01329118]

# %%
accepted = list(filter(lambda p: p.predicted_value >= 0.7377, predictions))
correct_accepted = list(filter(lambda p: p.predicted_class == p.actual_class, accepted))
rejected = list(filter(lambda p: p.predicted_value < 0.7377, predictions))
print("Num accepted: ", len(accepted))
print("Accuracy accepted: ", len(correct_accepted) / len(accepted))
print("Num rejected: ", len(rejected))
# Out:
# Num accepted:  794
# Accuracy accepted:  0.6561712846347607
# Num rejected:  406
