# %%
from analysis import Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATH100 = "F:\Thesis\Experiments\Costs\Results\/20-06-2022 Batch-1 100.csv"
PATHME = "F:\Thesis\Experiments\Costs\Results\/20-06-2022 Batch-1 ME.csv"
data100 = pd.read_csv(PATH100)
datame = pd.read_csv(PATHME)
data100 = Analysis.append_durations(data100)
datame = Analysis.append_durations(datame)
print("fast subjects ME: ", datame['duration'].isnull().values.any())
print("fast subjects 100: ", data100['duration'].isnull().values.any())

data100 = Analysis.convert_100_data(data100)
datame = Analysis.convert_me_data(datame)
data = data100.append(datame)
print("subjects that failed the attention checks: ", data['attention_checks_passed'].loc[data['attention_checks_passed'] == False].values.any())
# Out:
# fast subjects ME:  False
# fast subjects 100:  False
# subjects that failed the attention checks:  False

# %%
print(data)
# Out:
#     S100TP1  S100TP2  S100TP3  S100TP4  S100TP5  S100TP6  S100TP7  S100TP8  \
# 0      68.0     99.0    100.0      0.0     79.0    100.0      0.0      0.0
# 1     100.0   -100.0    100.0    -27.0    100.0    100.0     93.0    100.0
# 2      50.0     10.0     40.0    -10.0     50.0     50.0      0.0      0.0
# 3      91.0     56.0    100.0     64.0     33.0     88.0     95.0     76.0
# 4     100.0    -34.0    100.0      0.0     98.0      0.0      0.0    100.0
# 5     100.0     72.0     80.0    -93.0    100.0    100.0     69.0    100.0
# 6      86.0    100.0     82.0     94.0    100.0     90.0     79.0    100.0
# 7      57.0     65.0    100.0     54.0     72.0    100.0     90.0    100.0
# 8     100.0    100.0    100.0      0.0    100.0    100.0     60.0     65.0
# 9     100.0     99.0    100.0    -70.0     99.0    100.0    -40.0    100.0
# 10     90.0    100.0    100.0     91.0    100.0    100.0    100.0     89.0
# ...

# %%
Analysis.print_means(data)
# Out:
# ...
# ME scale
# TP 0.225531
# TN 0.26179
# FP -0.089063
# FN -0.217388
# REJ -0.090671
# ...
# S100 scale
# TP 67.5
# TN 58.552083
# FP -28.03125
# FN -26.708333
# REJ -14.958333
# ...

# %%
Analysis.print_reliabilities(data)
# Out:
# ...
# ME scale
# Reliability scale:  0.8771904839860026
# TP 0.513704893362573
# TN 0.7462125576802824
# FP 0.9090217904058084
# FN -0.8368219534317438
# REJ 0.5112533014088614
# ...
# S100 scale
# Reliability scale:  0.45156161228627656
# TP 0.2406872987334151
# TN 0.12157548822958886
# FP 0.3038508066152784
# FN 0.07413282593227877
# REJ 0.07935946738786148
# ...

# %%
Analysis.print_statistics(data)
# Out:
# Cohen's d -0.31626165874896633
# Shapiro Wilk normality test MES:  ShapiroResult(statistic=0.9420494437217712, pvalue=0.04055900499224663)
# Shapiro Wilk normality test S100:  ShapiroResult(statistic=0.942866861820221, pvalue=0.043233130127191544)
# Bartlett's test for equal variances:   BartlettResult(statistic=352.6411278018541, pvalue=1.127204452269957e-78)
# Mann-Whitney U test:  MannwhitneyuResult(statistic=760.0, pvalue=0.7038777515066069)
# Unpaired T-test:  Ttest_indResult(statistic=-1.3965736706295264, pvalue=0.16650322722598376)
# Pearson:  (0.8484338064668027, 4.7550973812891216e-12)
# Spearman:  SpearmanrResult(correlation=0.8041652994446408, pvalue=4.104382971328214e-10)
# Kendall:  KendalltauResult(correlation=0.6042336073052349, pvalue=4.06487564679116e-08)

# %%
# %matplotlib inline
sns.set_theme(style="whitegrid")
sns.set(font_scale = 1.6, palette="colorblind")
Analysis.plot_validity(data)

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_boxplots(data=data)

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_boxplots(data=data, scale="ME")

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_boxplots(data=data, scale="ME", show_individual=False)

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_boxplots(data=data, scale="S100")

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_boxplots(data=data, scale="S100", show_individual=False)

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_hatefulness(data)
