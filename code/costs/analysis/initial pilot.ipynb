# %%
from analysis import Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATH100 = "F:\Thesis\Experiments\Costs\Results\/16-06-2022 PILOT 100.csv"
PATHME = "F:\Thesis\Experiments\Costs\Results\/16-06-2022 PILOT ME.csv"
data100 = pd.read_csv(PATH100)
datame = pd.read_csv(PATHME)
data100 = Analysis.append_durations(data100)
datame = Analysis.append_durations(datame)
print("fast subjects ME: ", datame['duration'].isnull().values.any())
print("fast subjects 100: ", data100['duration'].isnull().values.any())

data100 = Analysis.convert_100_data(data100)
datame = Analysis.convert_me_data(datame)
data = data100.append(datame)
print("subjects that failed the attention checks: ", data['attention_checks_passed'].loc[data['attention_checks_passed'] == False].values.any())
# Out:
# fast subjects ME:  False
# fast subjects 100:  False
# subjects that failed the attention checks:  False

# %%
print(data)
# Out:
#    S100TP1  S100TP2  S100TP3  S100TP4  S100TP5  S100TP6  S100TP7  S100TP8  \
# 0     68.0     99.0    100.0      0.0     79.0    100.0      0.0      0.0
# 1     99.0     95.0    100.0     96.0    100.0    100.0    100.0    100.0
# 2    100.0   -100.0    100.0    -27.0    100.0    100.0     93.0    100.0
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    S100TN1  S100TN2  ...     MEFN7     MEFN8    MEREJ1  MEREJ2    MEREJ3  \
# 0    -79.0     -1.0  ...       NaN       NaN       NaN     NaN       NaN
# 1    100.0    100.0  ...       NaN       NaN       NaN     NaN       NaN
# 2    100.0    100.0  ...       NaN       NaN       NaN     NaN       NaN
# 0      NaN      NaN  ...  0.576923  0.576923  0.000000     0.0 -1.153846
# 1      NaN      NaN  ... -0.025105  0.000000 -0.037657     0.0 -0.062762
# 2      NaN      NaN  ... -0.652174 -1.304348 -1.304348     0.0  0.000000
#
#      MEREJ4    MEREJ5    MEREJ6    MEREJ7    MEREJ8
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# 0  0.000000  0.000000  0.000000 -1.153846 -1.153846
# 1 -0.075314 -0.016318 -0.017573  0.000000 -0.013808
# 2  0.000000 -0.456522 -0.130435  0.000000 -0.456522
#
# [6 rows x 121 columns]

# %%
Analysis.print_means(data)
# Out:
# ===================
# ME scale
# TP 0.360194
# TN 0.74387
# FP -0.304507
# FN -0.07761
# REJ -0.251366
# ===================
# S100 scale
# TP 70.916667
# TN 50.833333
# FP -36.708333
# FN -8.958333
# REJ -16.916667
# ===================

# %%
Analysis.print_reliabilities(data)
# Out:
# ===================
# ME scale
# Reliability scale:  0.23448866537462165
# TP 0.08005804826742857
# TN -0.39064995837890715
# FP 0.6461150404446192
# FN -0.07217616070424104
# REJ -0.07747177202093392
# ===================
# S100 scale
# Reliability scale:  0.22429272804573575
# TP -0.025959338634480522
# TN 0.061838465239355433
# FP 0.3131465865212404
# FN -0.17989835410139343
# REJ -0.26296888957663644
# ===================

# %%
Analysis.print_statistics(data)
# Out:
# Cohen's d -0.30622676166656077
# Shapiro Wilk normality test MES:  ShapiroResult(statistic=0.8592784404754639, pvalue=0.00015234686725307256)
# Shapiro Wilk normality test S100:  ShapiroResult(statistic=0.9570623636245728, pvalue=0.13280285894870758)
# Bartlett's test for equal variances:   BartlettResult(statistic=298.2233948450565, pvalue=8.032256470999072e-67)
# Mann-Whitney U test:  MannwhitneyuResult(statistic=695.5, pvalue=0.3167849141005318)
# Unpaired T-test:  Ttest_indResult(statistic=-1.3522607649545177, pvalue=0.18019963074206585)
# Pearson:  (0.5874402289870055, 6.746022793181284e-05)
# Spearman:  SpearmanrResult(correlation=0.6845368508846192, pvalue=1.1101196625575013e-06)
# Kendall:  KendalltauResult(correlation=0.5023610275172583, pvalue=6.82073936500371e-06)

# %%
# %matplotlib inline
sns.set_theme(style="whitegrid")
sns.set(font_scale = 1.6, palette="colorblind")
Analysis.plot_validity(data)

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_boxplots(data=data)

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_boxplots(data=data, scale="ME")

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_boxplots(data=data, scale="ME", show_individual=False)

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_boxplots(data=data, scale="S100")

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_boxplots(data=data, scale="S100", show_individual=False)

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,7)})
sns.set(font_scale = 1.6, palette="colorblind")
sns.set_style("whitegrid")
Analysis.plot_hatefulness(data)
