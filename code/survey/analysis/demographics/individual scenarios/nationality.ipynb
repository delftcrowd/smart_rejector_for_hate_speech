# %%
import sys
sys.path.insert(0,'../..')
from analysis import Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATHME_BATCH2_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-2 ME.csv"
PATHME_BATCH3_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-3 ME.csv"
PATHME_BATCH4_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-4 ME.csv"

PATHME_BATCH2 = "F:\Thesis\Experiments\Costs\Results\/24-06-2022 Batch-2 ME.csv"
PATHME_BATCH3 = "F:\Thesis\Experiments\Costs\Results\/27-06-2022 Batch-3 ME.csv"
PATHME_BATCH4 = "F:\Thesis\Experiments\Costs\Results\/28-06-2022 Batch-4 ME.csv"

datame_batch2_demo = pd.read_csv(PATHME_BATCH2_DEMO)
datame_batch3_demo = pd.read_csv(PATHME_BATCH3_DEMO)
datame_batch4_demo = pd.read_csv(PATHME_BATCH4_DEMO)

datame_batch2 = pd.read_csv(PATHME_BATCH2)
datame_batch3 = pd.read_csv(PATHME_BATCH3)
datame_batch4 = pd.read_csv(PATHME_BATCH4)

datame_demo = pd.concat([datame_batch2_demo, datame_batch3_demo, datame_batch4_demo], ignore_index=True)
datame = pd.concat([datame_batch2, datame_batch3, datame_batch4], ignore_index=True)

mes_data = Analysis.convert_me_data(datame)

datame_demo = Analysis.filter_demographics_data(demo_data=datame_demo, data=mes_data)

# %%
print(datame_demo["Nationality"].value_counts())
# Out:
# South Africa                         22
# Poland                               10
# Portugal                              8
# Spain                                 5
# Italy                                 4
# Greece                                4
# Hungary                               3
# Mexico                                2
# Netherlands                           2
# United States                         1
# Finland                               1
# Chile                                 1
# Germany                               1
# Estonia                               1
# Zimbabwe                              1
# France                                1
# Venezuela, Bolivarian Republic of     1
# Name: Nationality, dtype: int64

# %%
mes_data_south_africa = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Nationality", column_value="South Africa")
mes_data_poland = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Nationality", column_value="Poland")
mes_data_portugal = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Nationality", column_value="Portugal")
mes_data_spain = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Nationality", column_value="Spain")

# %%
print("South Africa: ", mes_data_south_africa.shape)
print("Poland: ", mes_data_poland.shape)
print("Portugal: ", mes_data_portugal.shape)
print("Spain: ", mes_data_spain.shape)
# Out:
# South Africa:  (22, 82)
# Poland:  (10, 82)
# Portugal:  (8, 82)
# Spain:  (5, 82)

# %%
print("South Africa")
Analysis.print_means(mes_data_south_africa)
print("Poland")
Analysis.print_means(mes_data_poland)
print("Portugal")
Analysis.print_means(mes_data_portugal)
print("Spain")
Analysis.print_means(mes_data_spain)
# Out:
# South Africa
# ===================
# TP 11.750498251748251
# TN 29.28873585123585
# FP -7.034459985055844
# FN -28.572985347985348
# REJ -1.5187386048485398
# ===================
# Poland
# ===================
# TP 17.677976190476187
# TN 46.13501082251082
# FP -13.082708333333333
# FN -22.351799242424242
# REJ -13.195647916666665
# ===================
# Portugal
# ===================
# TP 24.020833333333336
# TN 36.21422101449275
# FP -34.04166862604166
# FN -34.78532671195652
# REJ -5.364590207708333
# ===================
# Spain
# ===================
# TP 62.34375
# TN 78.3125
# FP -67.8125
# FN -54.5
# REJ -29.375
# ===================

# %%
print("South Africa")
Analysis.print_reliabilities(mes_data_south_africa, scale="ME")
print("Poland")
Analysis.print_reliabilities(mes_data_poland, scale="ME")
print("Portugal")
Analysis.print_reliabilities(mes_data_portugal, scale="ME")
print("Spain")
Analysis.print_reliabilities(mes_data_spain, scale="ME")
# Out:
# South Africa
# ===================
# Reliability scale:  0.7681767756569474
# TP 0.9439603994269852
# TN -0.6558986854407147
# FP 0.99463332129488
# FN 0.8221430066983968
# REJ -0.03296002301161516
# ===================
# Poland
# ===================
# Reliability scale:  0.7983618878271288
# TP 0.9809034416210227
# TN 0.10310644410394543
# FP 0.361809585849303
# FN -0.06044714238221571
# REJ -0.5142719368184101
# ===================
# Portugal
# ===================
# Reliability scale:  0.7907133456436181
# TP -5.44037345488276
# TN -0.09103298623766665
# FP 0.44599516776233616
# FN 0.42923055357698137
# REJ 0.5456444017209077
# ===================
# Spain
# ===================
# Reliability scale:  0.9859480755630633
# TP 0.8973387667169468
# TN -0.15868092275966816
# FP 0.8548077550622858
# FN 0.6176122801236026
# REJ 0.9598014595778654
# ===================

# %%
nationality = Analysis.print_question_statistics_multiple(mes_data_south_africa, mes_data_poland, mes_data_portugal, mes_data_spain)
nationality.to_csv("nationality.csv")
# Out:
# =================================
# Question:  TP1
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9188551902770996, pvalue=0.07198245823383331)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9316610097885132, pvalue=0.5313159227371216)
# Variances are equal:  BartlettResult(statistic=1.9891769591562956, pvalue=0.5746561034646696)
# Groups are equal:  KruskalResult(statistic=6.360689974225095, pvalue=0.0953214593233949)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.2681078371603595
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.2681078371603595
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.2681078371603595
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.2681078371603595
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.2681078371603595
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.2681078371603595
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.2681078371603595
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.2681078371603595
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.2681078371603595
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.2681078371603595
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.8456673096738145, pvalue=0.15400052782182536)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7917187397697724
# Groups are equal (independent t-test) between dataset 0 and 2:  0.5516054030967364
# Groups are equal (independent t-test) between dataset 0 and 3:  0.05949088353292242
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7917187397697724
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.35148944265858917
# Statistical difference (independent t-test) between dataset 1 and 3:  0.01907960831027076
# Groups are equal (independent t-test) between dataset 2 and 0:  0.5516054030967364
# Groups are equal (independent t-test) between dataset 2 and 1:  0.35148944265858917
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.1342427046456078
# Groups are equal (independent t-test) between dataset 3 and 0:  0.05949088353292242
# Statistical difference (independent t-test) between dataset 3 and 1:  0.01907960831027076
# Groups are equal (independent t-test) between dataset 3 and 2:  0.1342427046456078
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9333963394165039, pvalue=0.14439894258975983)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9254444241523743, pvalue=0.40460580587387085)
# Variances are equal:  BartlettResult(statistic=0.6962612608214503, pvalue=0.8740829841166193)
# Groups are equal:  KruskalResult(statistic=3.6640927152318, pvalue=0.30009510465335243)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.36255734222466024
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.5829432992214935
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.36255734222466024
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.36255734222466024
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.5829432992214935
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.36255734222466024
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.4571942307374162, pvalue=0.2403025809206113)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.9187970472064612
# Groups are equal (independent t-test) between dataset 0 and 2:  0.6600525286076075
# Statistical difference (independent t-test) between dataset 0 and 3:  0.03776780363363166
# Groups are equal (independent t-test) between dataset 1 and 0:  0.9187970472064612
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.7917954785129504
# Groups are equal (independent t-test) between dataset 1 and 3:  0.11344370028066775
# Groups are equal (independent t-test) between dataset 2 and 0:  0.6600525286076075
# Groups are equal (independent t-test) between dataset 2 and 1:  0.7917954785129504
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.15380466104716561
# Statistical difference (independent t-test) between dataset 3 and 0:  0.03776780363363166
# Groups are equal (independent t-test) between dataset 3 and 1:  0.11344370028066775
# Groups are equal (independent t-test) between dataset 3 and 2:  0.15380466104716561
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP3
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.876862108707428, pvalue=0.12007739394903183)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9026839137077332, pvalue=0.30540144443511963)
# Variances are equal:  BartlettResult(statistic=1.3061994700075907, pvalue=0.727661479759192)
# Groups are equal:  KruskalResult(statistic=5.160124404446791, pvalue=0.16044059363014226)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.5536129743595053
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.5361728011517318
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.3647531166656053
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.5536129743595053
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.3647531166656053
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.3647531166656053
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.5361728011517318
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.3647531166656053
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.3647531166656053
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.3647531166656053
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.3647531166656053
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.3647531166656053
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.4485278447223102, pvalue=0.24269092751984392)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.6693461317231599
# Groups are equal (independent t-test) between dataset 0 and 2:  0.31359356006467276
# Groups are equal (independent t-test) between dataset 0 and 3:  0.10853707674388713
# Groups are equal (independent t-test) between dataset 1 and 0:  0.6693461317231599
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.3035497725043104
# Groups are equal (independent t-test) between dataset 1 and 3:  0.3539728141641798
# Groups are equal (independent t-test) between dataset 2 and 0:  0.31359356006467276
# Groups are equal (independent t-test) between dataset 2 and 1:  0.3035497725043104
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.08199680556472157
# Groups are equal (independent t-test) between dataset 3 and 0:  0.10853707674388713
# Groups are equal (independent t-test) between dataset 3 and 1:  0.3539728141641798
# Groups are equal (independent t-test) between dataset 3 and 2:  0.08199680556472157
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP4
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9440779685974121, pvalue=0.23999550938606262)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8827536702156067, pvalue=0.14032527804374695)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8364402055740356, pvalue=0.15532006323337555)
# Variances are equal:  BartlettResult(statistic=3.0942502723092513, pvalue=0.3773206826622833)
# Groups are equal:  KruskalResult(statistic=5.523624147477872, pvalue=0.13723243985538663)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.5049526891050011
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.42308634461886374
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.601483812121424
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.5049526891050011
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.23693608610069278
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.42308634461886374
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.23693608610069278
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.23693608610069278
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.601483812121424
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.23693608610069278
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.1546485489229412, pvalue=0.3386648937227056)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.392504297351394
# Groups are equal (independent t-test) between dataset 0 and 2:  0.36364710260206135
# Groups are equal (independent t-test) between dataset 0 and 3:  0.28504972653705196
# Groups are equal (independent t-test) between dataset 1 and 0:  0.392504297351394
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.15735161549177684
# Groups are equal (independent t-test) between dataset 1 and 3:  0.7776732353528755
# Groups are equal (independent t-test) between dataset 2 and 0:  0.36364710260206135
# Groups are equal (independent t-test) between dataset 2 and 1:  0.15735161549177684
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.05731238184446056
# Groups are equal (independent t-test) between dataset 3 and 0:  0.28504972653705196
# Groups are equal (independent t-test) between dataset 3 and 1:  0.7776732353528755
# Groups are equal (independent t-test) between dataset 3 and 2:  0.05731238184446056
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP5
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9250940680503845, pvalue=0.09697834402322769)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9536291360855103, pvalue=0.7115010023117065)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8996186256408691, pvalue=0.2866821587085724)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8675959706306458, pvalue=0.2568252384662628)
# Variances are equal:  BartlettResult(statistic=0.5417260168910316, pvalue=0.9096332795893783)
# Groups are equal:  KruskalResult(statistic=5.292290136931953, pvalue=0.15160345548411575)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.3665311850909085
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.8658520728559223
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.3665311850909085
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.4486060556360725
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.3881872478302971
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.4486060556360725
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.8922288200331805
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.8658520728559223
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.3881872478302971
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.8922288200331805
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=2.4004094573357455, pvalue=0.08161907352314583)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Statistical difference (independent t-test) between dataset 0 and 1:  0.02814819459644346
# Groups are equal (independent t-test) between dataset 0 and 2:  0.9059910999469714
# Groups are equal (independent t-test) between dataset 0 and 3:  0.3739420738570711
# Statistical difference (independent t-test) between dataset 1 and 0:  0.02814819459644346
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.08884395538939402
# Statistical difference (independent t-test) between dataset 1 and 3:  0.04284273334081201
# Groups are equal (independent t-test) between dataset 2 and 0:  0.9059910999469714
# Groups are equal (independent t-test) between dataset 2 and 1:  0.08884395538939402
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.5552418957114986
# Groups are equal (independent t-test) between dataset 3 and 0:  0.3739420738570711
# Statistical difference (independent t-test) between dataset 3 and 1:  0.04284273334081201
# Groups are equal (independent t-test) between dataset 3 and 2:  0.5552418957114986
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP6
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9354918003082275, pvalue=0.1596391350030899)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8712848424911499, pvalue=0.1034700870513916)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9087538719177246, pvalue=0.3453720211982727)
# Variances are equal:  BartlettResult(statistic=4.266110183612501, pvalue=0.23412578830933062)
# Significant difference between groups:  KruskalResult(statistic=14.946061712010627, pvalue=0.0018633279177136873)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.0766774200854058
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.0766774200854058
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.11890521457371887
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.0766774200854058
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Significant difference (Mann-Whitney U) between dataset 1 and 2:  0.008649325933985322
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.08250687646696638
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.0766774200854058
# Significant difference (Mann-Whitney U) between dataset 2 and 1:  0.008649325933985322
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.613155930680612
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.11890521457371887
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.08250687646696638
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.613155930680612
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Significant difference between groups:  F_onewayResult(statistic=6.525731731642146, pvalue=0.001036142146559372)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.05585286255713947
# Statistical difference (independent t-test) between dataset 0 and 2:  0.017049046435624417
# Groups are equal (independent t-test) between dataset 0 and 3:  0.061607206370421906
# Groups are equal (independent t-test) between dataset 1 and 0:  0.05585286255713947
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Statistical difference (independent t-test) between dataset 1 and 2:  8.369636177012524e-05
# Statistical difference (independent t-test) between dataset 1 and 3:  0.004202460611878778
# Statistical difference (independent t-test) between dataset 2 and 0:  0.017049046435624417
# Statistical difference (independent t-test) between dataset 2 and 1:  8.369636177012524e-05
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.9411557466007934
# Groups are equal (independent t-test) between dataset 3 and 0:  0.061607206370421906
# Statistical difference (independent t-test) between dataset 3 and 1:  0.004202460611878778
# Groups are equal (independent t-test) between dataset 3 and 2:  0.9411557466007934
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP7
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9303693175315857, pvalue=0.12488982826471329)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8737414479255676, pvalue=0.16392286121845245)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9420084357261658, pvalue=0.6801707148551941)
# Variances are equal:  BartlettResult(statistic=1.8446191261662663, pvalue=0.6052737792405567)
# Groups are equal:  KruskalResult(statistic=4.195555555555549, pvalue=0.2411072352016927)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.5897175343358452
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.5897175343358452
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.5897175343358452
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.5897175343358452
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.7984361891193927
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.5897175343358452
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.6553855181466135
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.5897175343358452
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.7984361891193927
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.6553855181466135
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.1375530175983208, pvalue=0.34523373230022997)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.13233615385850064
# Groups are equal (independent t-test) between dataset 0 and 2:  0.31225704757090267
# Groups are equal (independent t-test) between dataset 0 and 3:  0.23687931168739756
# Groups are equal (independent t-test) between dataset 1 and 0:  0.13233615385850064
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.6858129143779299
# Groups are equal (independent t-test) between dataset 1 and 3:  0.9030696533003033
# Groups are equal (independent t-test) between dataset 2 and 0:  0.31225704757090267
# Groups are equal (independent t-test) between dataset 2 and 1:  0.6858129143779299
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.6983683776765115
# Groups are equal (independent t-test) between dataset 3 and 0:  0.23687931168739756
# Groups are equal (independent t-test) between dataset 3 and 1:  0.9030696533003033
# Groups are equal (independent t-test) between dataset 3 and 2:  0.6983683776765115
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP8
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9414098858833313, pvalue=0.21161703765392303)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.836678683757782, pvalue=0.15594856441020966)
# Variances are equal:  BartlettResult(statistic=4.576203872499739, pvalue=0.20559296299662452)
# Groups are equal:  KruskalResult(statistic=2.0203766105054464, pvalue=0.5681882527670954)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.740341584934594
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.8663893776502523
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.740341584934594
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.740341584934594
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.740341584934594
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.8663893776502523
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.740341584934594
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.740341584934594
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.740341584934594
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.740341584934594
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.2553312519034302, pvalue=0.8570870139580317)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.6775807122729112
# Groups are equal (independent t-test) between dataset 0 and 2:  0.5440310442143759
# Groups are equal (independent t-test) between dataset 0 and 3:  0.49209071518654335
# Groups are equal (independent t-test) between dataset 1 and 0:  0.6775807122729112
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.8508213026093179
# Groups are equal (independent t-test) between dataset 1 and 3:  0.7328574139637116
# Groups are equal (independent t-test) between dataset 2 and 0:  0.5440310442143759
# Groups are equal (independent t-test) between dataset 2 and 1:  0.8508213026093179
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.8090276932590275
# Groups are equal (independent t-test) between dataset 3 and 0:  0.49209071518654335
# Groups are equal (independent t-test) between dataset 3 and 1:  0.7328574139637116
# Groups are equal (independent t-test) between dataset 3 and 2:  0.8090276932590275
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN1
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9540031552314758, pvalue=0.3782292902469635)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8824776411056519, pvalue=0.1393095850944519)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8964667320251465, pvalue=0.2684310972690582)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8003103733062744, pvalue=0.08150751143693924)
# Variances are equal:  BartlettResult(statistic=0.5448433856611373, pvalue=0.9089346629212037)
# Groups are equal:  KruskalResult(statistic=3.6068106641968907, pvalue=0.30717105969713754)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.7019313811101577
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.7019313811101577
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.6549972707283045
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.7019313811101577
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.7019313811101577
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.8306157755550917
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.7019313811101577
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.7019313811101577
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.6549972707283045
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.6549972707283045
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.8306157755550917
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.6549972707283045
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.4819412406783798, pvalue=0.23360799165199828)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.31139846910979896
# Groups are equal (independent t-test) between dataset 0 and 2:  0.4252908017071726
# Groups are equal (independent t-test) between dataset 0 and 3:  0.1608309644827895
# Groups are equal (independent t-test) between dataset 1 and 0:  0.31139846910979896
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.15334840148155893
# Groups are equal (independent t-test) between dataset 1 and 3:  0.585859251010941
# Groups are equal (independent t-test) between dataset 2 and 0:  0.4252908017071726
# Groups are equal (independent t-test) between dataset 2 and 1:  0.15334840148155893
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.07974752439401092
# Groups are equal (independent t-test) between dataset 3 and 0:  0.1608309644827895
# Groups are equal (independent t-test) between dataset 3 and 1:  0.585859251010941
# Groups are equal (independent t-test) between dataset 3 and 2:  0.07974752439401092
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9032279849052429, pvalue=0.23763303458690643)
# Variances are equal:  BartlettResult(statistic=0.575974014972873, pvalue=0.9019098628038155)
# Groups are equal:  KruskalResult(statistic=1.8924907456372029, pvalue=0.5950175936058932)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.4168320800445381, pvalue=0.7418414557665214)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.908575802972591
# Groups are equal (independent t-test) between dataset 0 and 2:  0.9973416389916387
# Groups are equal (independent t-test) between dataset 0 and 3:  0.25761482250631096
# Groups are equal (independent t-test) between dataset 1 and 0:  0.908575802972591
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.9340675941405794
# Groups are equal (independent t-test) between dataset 1 and 3:  0.4117562092021072
# Groups are equal (independent t-test) between dataset 2 and 0:  0.9973416389916387
# Groups are equal (independent t-test) between dataset 2 and 1:  0.9340675941405794
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.3486124387444045
# Groups are equal (independent t-test) between dataset 3 and 0:  0.25761482250631096
# Groups are equal (independent t-test) between dataset 3 and 1:  0.4117562092021072
# Groups are equal (independent t-test) between dataset 3 and 2:  0.3486124387444045
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN3
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8743376731872559, pvalue=0.11227065324783325)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.838535726070404, pvalue=0.07275548577308655)
# Variances are equal:  BartlettResult(statistic=0.0866649843228281, pvalue=0.9933881824877493)
# Groups are equal:  KruskalResult(statistic=2.6856067226890667, pvalue=0.44267882525456925)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.8677861205139554
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.7883707167987511
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.7883707167987511
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.8677861205139554
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.7883707167987511
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.7883707167987511
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.7883707167987511
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.7883707167987511
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.7883707167987511
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.7883707167987511
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.7883707167987511
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.7883707167987511
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.7818040913148872, pvalue=0.5109542899587333)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.5889119133374061
# Groups are equal (independent t-test) between dataset 0 and 2:  0.6347702169764129
# Groups are equal (independent t-test) between dataset 0 and 3:  0.23446058179526244
# Groups are equal (independent t-test) between dataset 1 and 0:  0.5889119133374061
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.39186245305707135
# Groups are equal (independent t-test) between dataset 1 and 3:  0.4558481729505971
# Groups are equal (independent t-test) between dataset 2 and 0:  0.6347702169764129
# Groups are equal (independent t-test) between dataset 2 and 1:  0.39186245305707135
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.17989946183640446
# Groups are equal (independent t-test) between dataset 3 and 0:  0.23446058179526244
# Groups are equal (independent t-test) between dataset 3 and 1:  0.4558481729505971
# Groups are equal (independent t-test) between dataset 3 and 2:  0.17989946183640446
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN4
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9198190569877625, pvalue=0.07536552846431732)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9661240577697754, pvalue=0.85276859998703)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9421788454055786, pvalue=0.6326379776000977)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9489946365356445, pvalue=0.7300042510032654)
# Variances are equal:  BartlettResult(statistic=1.0323538731196775, pvalue=0.7934239387975008)
# Groups are equal:  KruskalResult(statistic=4.153702724147036, pvalue=0.24533818949219835)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.7001982493557883
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.7001982493557883
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.7001982493557883
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.7001982493557883
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.7001982493557883
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.7001982493557883
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.7001982493557883
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.9702768253261722
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.7001982493557883
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.9702768253261722
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.670624022089377, pvalue=0.18823834680020923)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.06398325727647998
# Groups are equal (independent t-test) between dataset 0 and 2:  0.4538861801042585
# Groups are equal (independent t-test) between dataset 0 and 3:  0.16452831306205656
# Groups are equal (independent t-test) between dataset 1 and 0:  0.06398325727647998
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.33373358961086275
# Groups are equal (independent t-test) between dataset 1 and 3:  0.9672457796136251
# Groups are equal (independent t-test) between dataset 2 and 0:  0.4538861801042585
# Groups are equal (independent t-test) between dataset 2 and 1:  0.33373358961086275
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.4496819164275093
# Groups are equal (independent t-test) between dataset 3 and 0:  0.16452831306205656
# Groups are equal (independent t-test) between dataset 3 and 1:  0.9672457796136251
# Groups are equal (independent t-test) between dataset 3 and 2:  0.4496819164275093
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN5
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9703094959259033, pvalue=0.9004257917404175)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8753734230995178, pvalue=0.2888687551021576)
# Variances are equal:  BartlettResult(statistic=0.610156183032251, pvalue=0.8941034622430734)
# Groups are equal:  KruskalResult(statistic=3.6334566913382567, pvalue=0.30386124265370873)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.7727113949865825
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.4682352201741014
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.7727113949865825
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.9469502049030964
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.4682352201741014
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.9469502049030964
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.4682352201741014
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.4682352201741014
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.4682352201741014
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.4682352201741014
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.1600585165340092, pvalue=0.3366105981965968)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.6850978352143138
# Groups are equal (independent t-test) between dataset 0 and 2:  0.571062814563837
# Groups are equal (independent t-test) between dataset 0 and 3:  0.15712163471249996
# Groups are equal (independent t-test) between dataset 1 and 0:  0.6850978352143138
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.8667179344397095
# Groups are equal (independent t-test) between dataset 1 and 3:  0.10861245489705357
# Groups are equal (independent t-test) between dataset 2 and 0:  0.571062814563837
# Groups are equal (independent t-test) between dataset 2 and 1:  0.8667179344397095
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.06986213519218623
# Groups are equal (independent t-test) between dataset 3 and 0:  0.15712163471249996
# Groups are equal (independent t-test) between dataset 3 and 1:  0.10861245489705357
# Groups are equal (independent t-test) between dataset 3 and 2:  0.06986213519218623
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8487593531608582, pvalue=0.056146830320358276)
# Variances are equal:  BartlettResult(statistic=0.5084405875665353, pvalue=0.9170331766507156)
# Groups are equal:  KruskalResult(statistic=0.944663388050759, pvalue=0.8146382832282327)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.4789821733190789, pvalue=0.6986718074486644)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7868546338666846
# Groups are equal (independent t-test) between dataset 0 and 2:  0.5987245905430252
# Groups are equal (independent t-test) between dataset 0 and 3:  0.23118830845138824
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7868546338666846
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.8167548357209159
# Groups are equal (independent t-test) between dataset 1 and 3:  0.39131522800697627
# Groups are equal (independent t-test) between dataset 2 and 0:  0.5987245905430252
# Groups are equal (independent t-test) between dataset 2 and 1:  0.8167548357209159
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.5710055395735818
# Groups are equal (independent t-test) between dataset 3 and 0:  0.23118830845138824
# Groups are equal (independent t-test) between dataset 3 and 1:  0.39131522800697627
# Groups are equal (independent t-test) between dataset 3 and 2:  0.5710055395735818
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN7
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9168108105659485, pvalue=0.06531310826539993)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8640999794006348, pvalue=0.08527471870183945)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8974626660346985, pvalue=0.27409034967422485)
# Variances are equal:  BartlettResult(statistic=1.1640812040886177, pvalue=0.7616313744774877)
# Groups are equal:  KruskalResult(statistic=6.070178002125397, pvalue=0.10824538628269995)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.5083996774294093
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.4434676203651662
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.24409804942764834
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.5083996774294093
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.4434676203651662
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.4434676203651662
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.4434676203651662
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.24409804942764834
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.4434676203651662
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.4434676203651662
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=2.0511643187253776, pvalue=0.12166790586441556)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.19907286081291353
# Groups are equal (independent t-test) between dataset 0 and 2:  0.18105509940082393
# Groups are equal (independent t-test) between dataset 0 and 3:  0.0533248576367142
# Groups are equal (independent t-test) between dataset 1 and 0:  0.19907286081291353
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.8654520265058101
# Groups are equal (independent t-test) between dataset 1 and 3:  0.26834960402876945
# Groups are equal (independent t-test) between dataset 2 and 0:  0.18105509940082393
# Groups are equal (independent t-test) between dataset 2 and 1:  0.8654520265058101
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.3416378020440618
# Groups are equal (independent t-test) between dataset 3 and 0:  0.0533248576367142
# Groups are equal (independent t-test) between dataset 3 and 1:  0.26834960402876945
# Groups are equal (independent t-test) between dataset 3 and 2:  0.3416378020440618
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8503165245056152, pvalue=0.05859505385160446)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9409804344177246, pvalue=0.620752215385437)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.7995632886886597, pvalue=0.08037269115447998)
# Variances are equal:  BartlettResult(statistic=0.6605866512450708, pvalue=0.8824328262319923)
# Groups are equal:  KruskalResult(statistic=5.056767515923561, pvalue=0.16768723055005622)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.20952278727496024
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.20952278727496024
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.20952278727496024
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.20952278727496024
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.20952278727496024
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.20952278727496024
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.4973309959699266, pvalue=0.22953689566821886)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# ...
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.7130821147144064, pvalue=0.549817135360451)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.2953387087773964
# Groups are equal (independent t-test) between dataset 0 and 2:  0.18423564132946685
# Groups are equal (independent t-test) between dataset 0 and 3:  0.4192745944939248
# Groups are equal (independent t-test) between dataset 1 and 0:  0.2953387087773964
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.7794608172393613
# Groups are equal (independent t-test) between dataset 1 and 3:  0.9673239846618737
# Groups are equal (independent t-test) between dataset 2 and 0:  0.18423564132946685
# Groups are equal (independent t-test) between dataset 2 and 1:  0.7794608172393613
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.8724679693907575
# Groups are equal (independent t-test) between dataset 3 and 0:  0.4192745944939248
# Groups are equal (independent t-test) between dataset 3 and 1:  0.9673239846618737
# Groups are equal (independent t-test) between dataset 3 and 2:  0.8724679693907575
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ4
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8557576537132263, pvalue=0.10889726132154465)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8145426511764526, pvalue=0.10589898377656937)
# Variances are equal:  BartlettResult(statistic=1.5960979882798114, pvalue=0.6602748980386615)
# Significant difference between groups:  KruskalResult(statistic=10.636861486486499, pvalue=0.013860655840753936)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.09803550042892221
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.09803550042892221
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.09803550042892221
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.09803550042892221
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.42216090866265094
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.09803550042892221
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.42216090866265094
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.09803550042892221
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.42216090866265094
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.42216090866265094
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Significant difference between groups:  F_onewayResult(statistic=3.912957478610774, pvalue=0.015138684854000703)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Statistical difference (independent t-test) between dataset 0 and 1:  0.028748836720284637
# Groups are equal (independent t-test) between dataset 0 and 2:  0.07285519844891367
# Statistical difference (independent t-test) between dataset 0 and 3:  0.010621323161275432
# Statistical difference (independent t-test) between dataset 1 and 0:  0.028748836720284637
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.8049937584197688
# Groups are equal (independent t-test) between dataset 1 and 3:  0.3161749815300498
# Groups are equal (independent t-test) between dataset 2 and 0:  0.07285519844891367
# Groups are equal (independent t-test) between dataset 2 and 1:  0.8049937584197688
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.2714403664102811
# Statistical difference (independent t-test) between dataset 3 and 0:  0.010621323161275432
# Groups are equal (independent t-test) between dataset 3 and 1:  0.3161749815300498
# Groups are equal (independent t-test) between dataset 3 and 2:  0.2714403664102811
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ5
# =================================
# Groups are equal:  KruskalResult(statistic=6.0097856608012306, pvalue=0.11113510081888696)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.9474928683755076
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.3530550665677392
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.3530550665677392
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.9474928683755076
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.3530550665677392
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.3530550665677392
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.3530550665677392
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.3530550665677392
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.3530550665677392
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.3530550665677392
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.3530550665677392
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.3530550665677392
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.738392321415272, pvalue=0.17416625890794699)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.8729737650597933
# Groups are equal (independent t-test) between dataset 0 and 2:  0.6251165134709153
# Groups are equal (independent t-test) between dataset 0 and 3:  0.08426935092388269
# Groups are equal (independent t-test) between dataset 1 and 0:  0.8729737650597933
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.727079362767942
# Groups are equal (independent t-test) between dataset 1 and 3:  0.10893080450368017
# Groups are equal (independent t-test) between dataset 2 and 0:  0.6251165134709153
# Groups are equal (independent t-test) between dataset 2 and 1:  0.727079362767942
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Statistical difference (independent t-test) between dataset 2 and 3:  0.04384697392858879
# Groups are equal (independent t-test) between dataset 3 and 0:  0.08426935092388269
# Groups are equal (independent t-test) between dataset 3 and 1:  0.10893080450368017
# Statistical difference (independent t-test) between dataset 3 and 2:  0.04384697392858879
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9509254693984985, pvalue=0.6794586181640625)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.807449221611023, pvalue=0.09306267648935318)
# Variances are equal:  BartlettResult(statistic=7.112425293904022, pvalue=0.06839942744611145)
# Groups are equal:  KruskalResult(statistic=7.378101239087595, pvalue=0.06077467923894286)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.38206242753456365
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.30495320613188454
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.49766208930200173
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.38206242753456365
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.11634877161557329
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.30495320613188454
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.11634877161557329
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.18670944152527275
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.49766208930200173
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.18670944152527275
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=2.198932830155797, pvalue=0.10273012838132216)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.33712022420256205
# Groups are equal (independent t-test) between dataset 0 and 2:  0.12452580927877308
# Groups are equal (independent t-test) between dataset 0 and 3:  0.25451680661620446
# Groups are equal (independent t-test) between dataset 1 and 0:  0.33712022420256205
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Statistical difference (independent t-test) between dataset 1 and 2:  0.02396020840021156
# Groups are equal (independent t-test) between dataset 1 and 3:  0.7231525685128994
# Groups are equal (independent t-test) between dataset 2 and 0:  0.12452580927877308
# Statistical difference (independent t-test) between dataset 2 and 1:  0.02396020840021156
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Statistical difference (independent t-test) between dataset 2 and 3:  0.009820517801279235
# Groups are equal (independent t-test) between dataset 3 and 0:  0.25451680661620446
# Groups are equal (independent t-test) between dataset 3 and 1:  0.7231525685128994
# Statistical difference (independent t-test) between dataset 3 and 2:  0.009820517801279235
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ7
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8523013591766357, pvalue=0.10051333159208298)
# Variances are equal:  BartlettResult(statistic=2.723774073425141, pvalue=0.4362022469632878)
# Groups are equal:  KruskalResult(statistic=0.053211009174320895, pvalue=0.9967870880476911)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.21091930665343317, pvalue=0.8882604701704323)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.6891402832227775
# Groups are equal (independent t-test) between dataset 0 and 2:  0.4961536411158646
# Groups are equal (independent t-test) between dataset 0 and 3:  0.7059478833232993
# Groups are equal (independent t-test) between dataset 1 and 0:  0.6891402832227775
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.7550417555579004
# Groups are equal (independent t-test) between dataset 1 and 3:  0.9433611969223465
# Groups are equal (independent t-test) between dataset 2 and 0:  0.4961536411158646
# Groups are equal (independent t-test) between dataset 2 and 1:  0.7550417555579004
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.815654298137413
# Groups are equal (independent t-test) between dataset 3 and 0:  0.7059478833232993
# Groups are equal (independent t-test) between dataset 3 and 1:  0.9433611969223465
# Groups are equal (independent t-test) between dataset 3 and 2:  0.815654298137413
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ8
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9543415307998657, pvalue=0.754806637763977)
# Variances are equal:  BartlettResult(statistic=0.6086538179083735, pvalue=0.8944484533503633)
# Groups are equal:  KruskalResult(statistic=0.5796421697911438, pvalue=0.9010766042745009)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.6625918817561758, pvalue=0.5798214012272065)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7711401956934917
# Groups are equal (independent t-test) between dataset 0 and 2:  0.34446067716323225
# Groups are equal (independent t-test) between dataset 0 and 3:  0.43259276228925336
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7711401956934917
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.3425287966633783
# Groups are equal (independent t-test) between dataset 1 and 3:  0.6551069630901558
# Groups are equal (independent t-test) between dataset 2 and 0:  0.34446067716323225
# Groups are equal (independent t-test) between dataset 2 and 1:  0.3425287966633783
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.24907489860766427
# Groups are equal (independent t-test) between dataset 3 and 0:  0.43259276228925336
# Groups are equal (independent t-test) between dataset 3 and 1:  0.6551069630901558
# Groups are equal (independent t-test) between dataset 3 and 2:  0.24907489860766427
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
