# %%
import sys
sys.path.insert(0,'../..')
from analysis import Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

PATHME_BATCH2_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-2 ME.csv"
PATHME_BATCH3_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-3 ME.csv"
PATHME_BATCH4_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-4 ME.csv"

PATHME_BATCH2 = "F:\Thesis\Experiments\Costs\Results\/24-06-2022 Batch-2 ME.csv"
PATHME_BATCH3 = "F:\Thesis\Experiments\Costs\Results\/27-06-2022 Batch-3 ME.csv"
PATHME_BATCH4 = "F:\Thesis\Experiments\Costs\Results\/28-06-2022 Batch-4 ME.csv"

datame_batch2_demo = pd.read_csv(PATHME_BATCH2_DEMO)
datame_batch3_demo = pd.read_csv(PATHME_BATCH3_DEMO)
datame_batch4_demo = pd.read_csv(PATHME_BATCH4_DEMO)

datame_batch2 = pd.read_csv(PATHME_BATCH2)
datame_batch3 = pd.read_csv(PATHME_BATCH3)
datame_batch4 = pd.read_csv(PATHME_BATCH4)

datame_demo = pd.concat([datame_batch2_demo, datame_batch3_demo, datame_batch4_demo], ignore_index=True)

datame = pd.concat([datame_batch2, datame_batch3, datame_batch4], ignore_index=True)

mes_data = Analysis.convert_me_data(datame)

datame_demo = Analysis.filter_demographics_data(demo_data=datame_demo, data=mes_data)

mes_data_student = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Student status", column_value="Yes")
mes_data_nostudent = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Student status", column_value="No")

# %%
print(mes_data_student.shape)
print(mes_data_nostudent.shape)
# Out:
# (37, 82)
# (26, 82)

# %%
print("Student")
Analysis.print_means(mes_data_student)
print("No student")
Analysis.print_means(mes_data_nostudent)
# Out:
# Student
# ===================
# TP 10.354166666666666
# TN 30.979166666666668
# FP -14.625000008814611
# FN -28.25
# REJ -2.15625
# ===================
# No student
# ===================
# TP 33.069203795379536
# TN 42.772817460317455
# FP -22.296656350227778
# FN -36.51455611122337
# REJ -6.526611015693406
# ===================

# %%
print("Student")
Analysis.print_reliabilities(mes_data_student, scale="ME")
print("No student")
Analysis.print_reliabilities(mes_data_nostudent, scale="ME")
# Out:
# Student
# ===================
# Reliability scale:  0.6758265533870704
# TP 0.3569734674010089
# TN -0.9260157719185904
# FP 0.23605932355284742
# FN -0.13559430299570163
# REJ 0.5061663436624197
# ===================
# No student
# ===================
# Reliability scale:  0.8720048679603286
# TP 0.5822737905996582
# TN 0.961761424562295
# FP 0.9558882165043503
# FN 0.9468156238645957
# REJ -1.6465441204835929
# ===================

# %%
student = Analysis.print_question_statistics(data1=mes_data_student, data2=mes_data_nostudent)
student.to_csv("student.csv")
# Out:
# =================================
# Question:  TP1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9392914772033691, pvalue=0.12917456030845642)
# Variances are equal:  BartlettResult(statistic=0.02503815119407384, pvalue=0.8742720335586681)
# No significant difference:  MannwhitneyuResult(statistic=416.5, pvalue=0.37089549523782317)
# No significant difference:  Ttest_indResult(statistic=-0.5726060861044406, pvalue=0.5690160416587333)
# =================================
# Question:  TP2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9427473545074463, pvalue=0.05643165111541748)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9436416029930115, pvalue=0.16405414044857025)
# Variances are equal:  BartlettResult(statistic=3.5733894161866036, pvalue=0.05871235738164714)
# No significant difference:  MannwhitneyuResult(statistic=389.0, pvalue=0.2005055177941052)
# No significant difference:  Ttest_indResult(statistic=-1.2541340749145111, pvalue=0.21457800364637644)
# =================================
# Question:  TP3
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9455495476722717, pvalue=0.06939072906970978)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9343989491462708, pvalue=0.09867477416992188)
# Variances are equal:  BartlettResult(statistic=2.082186723542081, pvalue=0.14902655010265733)
# No significant difference:  MannwhitneyuResult(statistic=402.5, pvalue=0.2755414885213785)
# No significant difference:  Ttest_indResult(statistic=-1.3563465651738174, pvalue=0.17998811915657104)
# =================================
# Question:  TP4
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9484444856643677, pvalue=0.21319137513637543)
# Variances are equal:  BartlettResult(statistic=0.25692052677493393, pvalue=0.6122437316138825)
# No significant difference:  MannwhitneyuResult(statistic=426.0, pvalue=0.4412849326456555)
# No significant difference:  Ttest_indResult(statistic=-0.630232844980362, pvalue=0.5308961673035779)
# =================================
# Question:  TP5
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9519500732421875, pvalue=0.11153169721364975)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.946740448474884, pvalue=0.19433444738388062)
# Variances are equal:  BartlettResult(statistic=0.46154343545567034, pvalue=0.49690352866938803)
# Significant difference:  MannwhitneyuResult(statistic=298.5, pvalue=0.010922714717728668)
# Significant difference:  Ttest_indResult(statistic=-2.717176562080057, pvalue=0.008557267282337914)
# =================================
# Question:  TP6
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9566552639007568, pvalue=0.1580338031053543)
# Variances are equal:  BartlettResult(statistic=0.0006608391240057036, pvalue=0.9794912068957141)
# No significant difference:  MannwhitneyuResult(statistic=362.0, pvalue=0.09711360796856705)
# No significant difference:  Ttest_indResult(statistic=-1.5773914609212791, pvalue=0.11987780793169171)
# =================================
# Question:  TP7
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9305391907691956, pvalue=0.0798175185918808)
# Variances are equal:  BartlettResult(statistic=0.06761515761238567, pvalue=0.7948412901765091)
# No significant difference:  MannwhitneyuResult(statistic=456.0, pvalue=0.7300450582839533)
# No significant difference:  Ttest_indResult(statistic=-0.5180421980648152, pvalue=0.6063027409268398)
# =================================
# Question:  TP8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9596933126449585, pvalue=0.385534405708313)
# Variances are equal:  BartlettResult(statistic=1.2200903286806937, pvalue=0.2693429257065324)
# Significant difference:  MannwhitneyuResult(statistic=306.5, pvalue=0.014990319891317579)
# Significant difference:  Ttest_indResult(statistic=-2.096707451606096, pvalue=0.040173512289226276)
# =================================
# Question:  TN1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9475864171981812, pvalue=0.20348913967609406)
# Variances are equal:  BartlettResult(statistic=0.3922903166640545, pvalue=0.5310979643691122)
# No significant difference:  MannwhitneyuResult(statistic=430.0, pvalue=0.4796378235613632)
# No significant difference:  Ttest_indResult(statistic=-0.3237201848153434, pvalue=0.7472571793661786)
# =================================
# Question:  TN2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9412289261817932, pvalue=0.14370158314704895)
# Variances are equal:  BartlettResult(statistic=0.40500848466486133, pvalue=0.5245139364171018)
# No significant difference:  MannwhitneyuResult(statistic=418.0, pvalue=0.3823049725952645)
# No significant difference:  Ttest_indResult(statistic=-0.6348994821610557, pvalue=0.5278682867155711)
# =================================
# Question:  TN3
# =================================
# Variances are equal:  BartlettResult(statistic=0.013957242745419872, pvalue=0.9059561157891475)
# No significant difference:  MannwhitneyuResult(statistic=468.5, pvalue=0.8657906702876264)
# No significant difference:  Ttest_indResult(statistic=-0.14758259631699833, pvalue=0.8831589241269118)
# =================================
# Question:  TN4
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9576846957206726, pvalue=0.34803307056427)
# Variances are equal:  BartlettResult(statistic=1.827852680561716, pvalue=0.1763813868333212)
# No significant difference:  MannwhitneyuResult(statistic=382.5, pvalue=0.17073013715424024)
# No significant difference:  Ttest_indResult(statistic=-1.1257375544918966, pvalue=0.26468628405343325)
# =================================
# Question:  TN5
# =================================
# Variances are equal:  BartlettResult(statistic=0.033769988664973494, pvalue=0.8541969319219123)
# No significant difference:  MannwhitneyuResult(statistic=389.0, pvalue=0.19896126424210714)
# No significant difference:  Ttest_indResult(statistic=-1.2545693146851784, pvalue=0.21442095588885432)
# =================================
# Question:  TN6
# =================================
# Variances are equal:  BartlettResult(statistic=0.19690457140993842, pvalue=0.6572310743017866)
# No significant difference:  MannwhitneyuResult(statistic=433.5, pvalue=0.5102647061272407)
# No significant difference:  Ttest_indResult(statistic=-0.7715620427729423, pvalue=0.4433525770678851)
# =================================
# Question:  TN7
# =================================
# Variances are equal:  BartlettResult(statistic=2.011641358659985, pvalue=0.15609635852948736)
# No significant difference:  MannwhitneyuResult(statistic=492.5, pvalue=0.8775561533891)
# No significant difference:  Ttest_indResult(statistic=0.5779459010710118, pvalue=0.5654281261783662)
# =================================
# Question:  TN8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9511057138442993, pvalue=0.2461092323064804)
# Variances are equal:  BartlettResult(statistic=0.6858371064582272, pvalue=0.40758395474696263)
# No significant difference:  MannwhitneyuResult(statistic=422.5, pvalue=0.4167435980928005)
# No significant difference:  Ttest_indResult(statistic=-0.6981219282880944, pvalue=0.4877537765617945)
# =================================
# Question:  FP1
# =================================
# Variances are equal:  BartlettResult(statistic=2.8706894899048394, pvalue=0.09020621681269513)
# No significant difference:  MannwhitneyuResult(statistic=437.5, pvalue=0.5454009449080162)
# No significant difference:  Ttest_indResult(statistic=-0.5853826921984198, pvalue=0.5604498504599562)
# =================================
# Question:  FP2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9372143149375916, pvalue=0.11521577090024948)
# Variances are equal:  BartlettResult(statistic=1.1850735468787756, pvalue=0.2763255373506685)
# No significant difference:  MannwhitneyuResult(statistic=368.5, pvalue=0.11354093528814874)
# Significant difference:  Ttest_indResult(statistic=-2.023981241153962, pvalue=0.04735799580738487)
# =================================
# Question:  FP3
# =================================
# Variances are equal:  BartlettResult(statistic=0.815314596037917, pvalue=0.3665536390937475)
# No significant difference:  MannwhitneyuResult(statistic=434.5, pvalue=0.5086833134558865)
# No significant difference:  Ttest_indResult(statistic=-0.9165926070649146, pvalue=0.3629657925115696)
# =================================
# Question:  FP4
# =================================
# Variances are equal:  BartlettResult(statistic=0.16017135923579354, pvalue=0.6889987995300153)
# No significant difference:  MannwhitneyuResult(statistic=494.0, pvalue=0.8600959412730927)
# No significant difference:  Ttest_indResult(statistic=0.154620490112399, pvalue=0.8776309767890245)
# =================================
# Question:  FP5
# =================================
# Variances are equal:  BartlettResult(statistic=0.04876490315493668, pvalue=0.8252265414707638)
# No significant difference:  MannwhitneyuResult(statistic=535.5, pvalue=0.444589792924342)
# No significant difference:  Ttest_indResult(statistic=1.0359685851301905, pvalue=0.30430627054119713)
# =================================
# Question:  FP6
# =================================
# Variances are equal:  BartlettResult(statistic=0.5396164180344041, pvalue=0.46259173872525594)
# No significant difference:  MannwhitneyuResult(statistic=560.0, pvalue=0.2660880472084367)
# No significant difference:  Ttest_indResult(statistic=0.7725637122078344, pvalue=0.44276378221725776)
# =================================
# Question:  FP7
# =================================
# Variances are equal:  BartlettResult(statistic=0.019542589013673242, pvalue=0.8888221137361273)
# No significant difference:  MannwhitneyuResult(statistic=501.0, pvalue=0.7844276496600832)
# No significant difference:  Ttest_indResult(statistic=0.2660895035780238, pvalue=0.7910676168955577)
# =================================
# Question:  FP8
# =================================
# Variances are equal:  BartlettResult(statistic=0.11224828487580876, pvalue=0.7375988715242113)
# No significant difference:  MannwhitneyuResult(statistic=496.0, pvalue=0.8373131571221006)
# No significant difference:  Ttest_indResult(statistic=0.4299253547161316, pvalue=0.6687649331904981)
# =================================
# Question:  FN1
# =================================
# Variances are equal:  BartlettResult(statistic=0.3231248545906786, pvalue=0.5697357458491874)
# No significant difference:  MannwhitneyuResult(statistic=570.5, pvalue=0.21317517085517101)
# No significant difference:  Ttest_indResult(statistic=1.3076397439827872, pvalue=0.19590255254066152)
# =================================
# Question:  FN2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9446278214454651, pvalue=0.06482234597206116)
# Variances are equal:  BartlettResult(statistic=1.2107218151420673, pvalue=0.2711892153576746)
# No significant difference:  MannwhitneyuResult(statistic=488.0, pvalue=0.9275844408567838)
# No significant difference:  Ttest_indResult(statistic=0.173710153478127, pvalue=0.862668440769458)
# =================================
# Question:  FN3
# =================================
# Variances are equal:  BartlettResult(statistic=0.1341836869991286, pvalue=0.7141330852355782)
# No significant difference:  MannwhitneyuResult(statistic=459.0, pvalue=0.7519785055845937)
# No significant difference:  Ttest_indResult(statistic=0.07052372281105244, pvalue=0.9440075197739602)
# =================================
# Question:  FN4
# =================================
# Variances are equal:  BartlettResult(statistic=0.8908953856247513, pvalue=0.3452347822179471)
# No significant difference:  MannwhitneyuResult(statistic=521.5, pvalue=0.5732047486357807)
# No significant difference:  Ttest_indResult(statistic=1.0665267746764027, pvalue=0.2903886444494073)
# =================================
# Question:  FN5
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9654115438461304, pvalue=0.29808729887008667)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9473330974578857, pvalue=0.20070596039295197)
# Variances are equal:  BartlettResult(statistic=0.4557272212174107, pvalue=0.49962766172063455)
# No significant difference:  MannwhitneyuResult(statistic=533.5, pvalue=0.46685252890389684)
# No significant difference:  Ttest_indResult(statistic=0.5680070084952791, pvalue=0.5721151486047243)
# =================================
# Question:  FN6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9463287591934204, pvalue=0.19002209603786469)
# Variances are equal:  BartlettResult(statistic=0.23862170327806997, pvalue=0.6252033702484543)
# No significant difference:  MannwhitneyuResult(statistic=595.0, pvalue=0.11281530598168558)
# No significant difference:  Ttest_indResult(statistic=1.2860161240519712, pvalue=0.20329762280353098)
# =================================
# Question:  FN7
# =================================
# Variances are equal:  BartlettResult(statistic=0.10938400109397732, pvalue=0.7408465344637613)
# No significant difference:  MannwhitneyuResult(statistic=451.0, pvalue=0.677267807623571)
# No significant difference:  Ttest_indResult(statistic=-0.23962843550444546, pvalue=0.8114216985776814)
# =================================
# Question:  FN8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9662057161331177, pvalue=0.5279683470726013)
# Variances are equal:  BartlettResult(statistic=0.5123957535992233, pvalue=0.47410358779406236)
# Significant difference:  MannwhitneyuResult(statistic=667.0, pvalue=0.009118463629876066)
# Significant difference:  Ttest_indResult(statistic=2.768511490819951, pvalue=0.007447855811029145)
# =================================
# Question:  REJ1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9560222625732422, pvalue=0.31931862235069275)
# Variances are equal:  BartlettResult(statistic=0.9681049353062408, pvalue=0.32515325770485143)
# No significant difference:  MannwhitneyuResult(statistic=456.5, pvalue=0.7339500817294108)
# No significant difference:  Ttest_indResult(statistic=-0.6584729972502712, pvalue=0.5127119774674593)
# =================================
# Question:  REJ2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9451242685317993, pvalue=0.1779262274503708)
# Variances are equal:  BartlettResult(statistic=0.017538447927557054, pvalue=0.8946419682840049)
# No significant difference:  MannwhitneyuResult(statistic=572.5, pvalue=0.2020660018970153)
# No significant difference:  Ttest_indResult(statistic=1.057722803488187, pvalue=0.29435262729546163)
# =================================
# Question:  REJ3
# =================================
# Variances are equal:  BartlettResult(statistic=1.4151597109485743, pvalue=0.2342017367626857)
# No significant difference:  MannwhitneyuResult(statistic=464.0, pvalue=0.8152700133267389)
# No significant difference:  Ttest_indResult(statistic=-0.14219650083351568, pvalue=0.887393415679707)
# =================================
# Question:  REJ4
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9242139458656311, pvalue=0.05649452656507492)
# Variances are equal:  BartlettResult(statistic=0.04169265045139883, pvalue=0.8382067585245006)
# No significant difference:  MannwhitneyuResult(statistic=481.0, pvalue=1.0)
# No significant difference:  Ttest_indResult(statistic=-0.07426107275727677, pvalue=0.9410456418519793)
# =================================
# Question:  REJ5
# =================================
# Variances are equal:  BartlettResult(statistic=1.3315232952597291, pvalue=0.24853440270494326)
# No significant difference:  MannwhitneyuResult(statistic=482.0, pvalue=0.9938245311687255)
# No significant difference:  Ttest_indResult(statistic=-0.09688833060008203, pvalue=0.9231327096867777)
# =================================
# Question:  REJ6
# =================================
# Variances are equal:  BartlettResult(statistic=1.3581429167054269, pvalue=0.24385958976649919)
# No significant difference:  MannwhitneyuResult(statistic=570.5, pvalue=0.19545123974826117)
# No significant difference:  Ttest_indResult(statistic=0.9300333211278932, pvalue=0.35601985929082824)
# =================================
# Question:  REJ7
# =================================
# Variances are equal:  BartlettResult(statistic=0.06577048513778362, pvalue=0.7975975394137471)
# No significant difference:  MannwhitneyuResult(statistic=468.0, pvalue=0.8534038484587272)
# No significant difference:  Ttest_indResult(statistic=-0.32290246816894763, pvalue=0.7478733659877945)
# =================================
# Question:  REJ8
# =================================
# Variances are equal:  BartlettResult(statistic=2.5658272544949563, pvalue=0.10919542307383756)
# No significant difference:  MannwhitneyuResult(statistic=385.5, pvalue=0.16695876092758732)
# No significant difference:  Ttest_indResult(statistic=-1.0434978854660562, pvalue=0.3008356251247632)
