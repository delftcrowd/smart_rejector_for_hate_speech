# %%
import sys
sys.path.insert(0,'../..')
from analysis import Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATHME_BATCH2_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-2 ME.csv"
PATHME_BATCH3_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-3 ME.csv"
PATHME_BATCH4_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-4 ME.csv"

PATHME_BATCH2 = "F:\Thesis\Experiments\Costs\Results\/24-06-2022 Batch-2 ME.csv"
PATHME_BATCH3 = "F:\Thesis\Experiments\Costs\Results\/27-06-2022 Batch-3 ME.csv"
PATHME_BATCH4 = "F:\Thesis\Experiments\Costs\Results\/28-06-2022 Batch-4 ME.csv"

datame_batch2_demo = pd.read_csv(PATHME_BATCH2_DEMO)
datame_batch3_demo = pd.read_csv(PATHME_BATCH3_DEMO)
datame_batch4_demo = pd.read_csv(PATHME_BATCH4_DEMO)

datame_batch2 = pd.read_csv(PATHME_BATCH2)
datame_batch3 = pd.read_csv(PATHME_BATCH3)
datame_batch4 = pd.read_csv(PATHME_BATCH4)

datame_demo = pd.concat([datame_batch2_demo, datame_batch3_demo, datame_batch4_demo], ignore_index=True)
datame = pd.concat([datame_batch2, datame_batch3, datame_batch4], ignore_index=True)

mes_data = Analysis.convert_me_data(datame)

datame_demo = Analysis.filter_demographics_data(demo_data=datame_demo, data=mes_data)

# %%
print(datame_demo["Language"].value_counts())
# Out:
# English       21
# Polish        10
# Portuguese     9
# Spanish        8
# Italian        4
# Greek          4
# Hungarian      3
# Dutch          2
# Afrikaans      2
# Finnish        1
# German         1
# Estonian       1
# French         1
# Catalan        1
# Name: Language, dtype: int64

# %%
mes_data_english = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Language", column_value="English")
mes_data_polish = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Language", column_value="Polish")
mes_data_portuguese = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Language", column_value="Portuguese")
mes_data_spanish = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Language", column_value="Spanish")

# %%
print("English: ", mes_data_english.shape)
print("Polish: ", mes_data_polish.shape)
print("Portuguese: ", mes_data_portuguese.shape)
print("Spanish: ", mes_data_spanish.shape)
# Out:
# English:  (21, 82)
# Polish:  (10, 82)
# Portuguese:  (9, 82)
# Spanish:  (8, 82)

# %%
print("English")
Analysis.print_means(mes_data_english)
print("Polish")
Analysis.print_means(mes_data_polish)
print("Portuguese")
Analysis.print_means(mes_data_portuguese)
print("Spanish")
Analysis.print_means(mes_data_spanish)
# Out:
# English
# ===================
# TP 13.035714285714285
# TN 22.240597740597742
# FP -2.375000899090332
# FN -24.651923076923076
# REJ -0.45875
# ===================
# Polish
# ===================
# TP 17.677976190476187
# TN 46.13501082251082
# FP -13.082708333333333
# FN -22.351799242424242
# REJ -13.195647916666665
# ===================
# Portuguese
# ===================
# TP 20.3125
# TN 29.07427536231884
# FP -29.58333725208333
# FN -30.992753623188406
# REJ -5.00001249875
# ===================
# Spanish
# ===================
# TP 62.20025510204081
# TN 67.23883928571428
# FP -49.786352040816325
# FN -44.26339285714286
# REJ -24.801020408163264
# ===================

# %%
print("English")
Analysis.print_reliabilities(mes_data_english, scale="ME")
print("Polish")
Analysis.print_reliabilities(mes_data_polish, scale="ME")
print("Portuguese")
Analysis.print_reliabilities(mes_data_portuguese, scale="ME")
print("Spanish")
Analysis.print_reliabilities(mes_data_spanish, scale="ME")
# Out:
# English
# ===================
# Reliability scale:  0.7461773550405986
# TP 0.9889880821646384
# TN -0.6612469292496168
# FP 0.9952249590952289
# FN 0.8287112957011737
# REJ -0.03564888608881489
# ===================
# Polish
# ===================
# Reliability scale:  0.7983618878271288
# TP 0.9809034416210227
# TN 0.10310644410394543
# FP 0.361809585849303
# FN -0.06044714238221571
# REJ -0.5142719368184101
# ===================
# Portuguese
# ===================
# Reliability scale:  0.793286259290854
# TP -5.266385133659776
# TN 0.004158243365424363
# FP 0.4468864378005093
# FN 0.39943360935079775
# REJ 0.5491861255621567
# ===================
# Spanish
# ===================
# Reliability scale:  0.9125983738050925
# TP 0.2701292499288901
# TN 0.4262479108381326
# FP -2.622387070118096
# FN 0.576352292148322
# REJ -3.6580399860393547
# ===================

# %%
language = Analysis.print_question_statistics_multiple(mes_data_english, mes_data_polish, mes_data_portuguese, mes_data_spanish)
language.to_csv("language.csv")
# Out:
# =================================
# Question:  TP1
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9086173176765442, pvalue=0.30631721019744873)
# Variances are equal:  BartlettResult(statistic=1.5820843406386744, pvalue=0.6634588633105327)
# Groups are equal:  KruskalResult(statistic=5.89414138972913, pvalue=0.11687560877874996)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.3604866823174548
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.3846479207798188
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.3604866823174548
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.3846479207798188
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.3097186679769065
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.3846479207798188
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.3846479207798188
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.3846479207798188
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.3097186679769065
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.3846479207798188
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.403962959797152, pvalue=0.25429472331375375)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.661257251718979
# Groups are equal (independent t-test) between dataset 0 and 2:  0.767275972181691
# Groups are equal (independent t-test) between dataset 0 and 3:  0.1162875626673702
# Groups are equal (independent t-test) between dataset 1 and 0:  0.661257251718979
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.4426497699868134
# Statistical difference (independent t-test) between dataset 1 and 3:  0.048544005385815936
# Groups are equal (independent t-test) between dataset 2 and 0:  0.767275972181691
# Groups are equal (independent t-test) between dataset 2 and 1:  0.4426497699868134
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.20318805239605095
# Groups are equal (independent t-test) between dataset 3 and 0:  0.1162875626673702
# Statistical difference (independent t-test) between dataset 3 and 1:  0.048544005385815936
# Groups are equal (independent t-test) between dataset 3 and 2:  0.20318805239605095
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9254444241523743, pvalue=0.40460580587387085)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8397872447967529, pvalue=0.05744068697094917)
# Variances are equal:  BartlettResult(statistic=0.48646760644573217, pvalue=0.921854201217159)
# Groups are equal:  KruskalResult(statistic=3.4284269002659404, pvalue=0.3301642385317356)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.4459597362247949
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.7595318165101173
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.43079288268076454
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.4459597362247949
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.7595318165101173
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.43079288268076454
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.4247427204598886, pvalue=0.24830741672802165)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7830344378921446
# Groups are equal (independent t-test) between dataset 0 and 2:  0.6020689253470839
# Statistical difference (independent t-test) between dataset 0 and 3:  0.045514388595714994
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7830344378921446
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.850940718465071
# Groups are equal (independent t-test) between dataset 1 and 3:  0.17365042807788597
# Groups are equal (independent t-test) between dataset 2 and 0:  0.6020689253470839
# Groups are equal (independent t-test) between dataset 2 and 1:  0.850940718465071
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.20606790635384944
# Statistical difference (independent t-test) between dataset 3 and 0:  0.045514388595714994
# Groups are equal (independent t-test) between dataset 3 and 1:  0.17365042807788597
# Groups are equal (independent t-test) between dataset 3 and 2:  0.20606790635384944
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP3
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.876862108707428, pvalue=0.12007739394903183)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9036486744880676, pvalue=0.27391448616981506)
# Variances are equal:  BartlettResult(statistic=1.2188328145558367, pvalue=0.7484910590464038)
# Significant difference between groups:  KruskalResult(statistic=8.017166914317217, pvalue=0.045658246451917184)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.561399461797078
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.352141846171749
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.1764462937924605
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.561399461797078
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.2829399957858683
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.2579031240820964
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.352141846171749
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.2829399957858683
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.1415009930640555
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.1764462937924605
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.2579031240820964
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.1415009930640555
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=2.1735735569409855, pvalue=0.10461898997830404)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7013360129611252
# Groups are equal (independent t-test) between dataset 0 and 2:  0.24069459403712629
# Groups are equal (independent t-test) between dataset 0 and 3:  0.057316975446941414
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7013360129611252
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.2554158451211541
# Groups are equal (independent t-test) between dataset 1 and 3:  0.25892667105816186
# Groups are equal (independent t-test) between dataset 2 and 0:  0.24069459403712629
# Groups are equal (independent t-test) between dataset 2 and 1:  0.2554158451211541
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Statistical difference (independent t-test) between dataset 2 and 3:  0.026052924193609057
# Groups are equal (independent t-test) between dataset 3 and 0:  0.057316975446941414
# Groups are equal (independent t-test) between dataset 3 and 1:  0.25892667105816186
# Statistical difference (independent t-test) between dataset 3 and 2:  0.026052924193609057
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP4
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9212307929992676, pvalue=0.0918353870511055)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8827536702156067, pvalue=0.14032527804374695)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8417812585830688, pvalue=0.07855980843305588)
# Variances are equal:  BartlettResult(statistic=3.718878190256039, pvalue=0.29346400702216624)
# Groups are equal:  KruskalResult(statistic=4.961032034144171, pvalue=0.17467290996588358)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.413865548495029
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.413865548495029
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.413865548495029
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.413865548495029
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.413865548495029
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.413865548495029
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.413865548495029
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.413865548495029
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.413865548495029
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.413865548495029
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.7748908916742157, pvalue=0.16586405363032436)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.3703805145335519
# Groups are equal (independent t-test) between dataset 0 and 2:  0.44287119293938526
# Groups are equal (independent t-test) between dataset 0 and 3:  0.09560593536690642
# Groups are equal (independent t-test) between dataset 1 and 0:  0.3703805145335519
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.1615464724476639
# Groups are equal (independent t-test) between dataset 1 and 3:  0.5297124999930434
# Groups are equal (independent t-test) between dataset 2 and 0:  0.44287119293938526
# Groups are equal (independent t-test) between dataset 2 and 1:  0.1615464724476639
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Statistical difference (independent t-test) between dataset 2 and 3:  0.02271259674719812
# Groups are equal (independent t-test) between dataset 3 and 0:  0.09560593536690642
# Groups are equal (independent t-test) between dataset 3 and 1:  0.5297124999930434
# Statistical difference (independent t-test) between dataset 3 and 2:  0.02271259674719812
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP5
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9536291360855103, pvalue=0.7115010023117065)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8871594071388245, pvalue=0.18650689721107483)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8659738302230835, pvalue=0.1376158893108368)
# Variances are equal:  BartlettResult(statistic=0.2989155025175366, pvalue=0.9602323158333853)
# Groups are equal:  KruskalResult(statistic=6.126381832483544, pvalue=0.10562077967190182)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.1980952246858167
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.9623926761461288
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.9997361940987987
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.1980952246858167
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.47391812540421796
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.19959477132353756
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.9623926761461288
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.47391812540421796
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.9623926761461288
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.9997361940987987
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.19959477132353756
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.9623926761461288
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=2.583340710706003, pvalue=0.06527585808574946)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Statistical difference (independent t-test) between dataset 0 and 1:  0.013054624418889292
# Groups are equal (independent t-test) between dataset 0 and 2:  0.7245940370518182
# Groups are equal (independent t-test) between dataset 0 and 3:  0.7614962780390142
# Statistical difference (independent t-test) between dataset 1 and 0:  0.013054624418889292
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.10132667923060859
# Statistical difference (independent t-test) between dataset 1 and 3:  0.03645651420546708
# Groups are equal (independent t-test) between dataset 2 and 0:  0.7245940370518182
# Groups are equal (independent t-test) between dataset 2 and 1:  0.10132667923060859
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.6195387836872526
# Groups are equal (independent t-test) between dataset 3 and 0:  0.7614962780390142
# Statistical difference (independent t-test) between dataset 3 and 1:  0.03645651420546708
# Groups are equal (independent t-test) between dataset 3 and 2:  0.6195387836872526
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP6
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9130734801292419, pvalue=0.06316263228654861)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8712848424911499, pvalue=0.1034700870513916)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9222999811172485, pvalue=0.4116225838661194)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8814714550971985, pvalue=0.19451752305030823)
# Variances are equal:  BartlettResult(statistic=4.318644815710109, pvalue=0.22904848889627427)
# Significant difference between groups:  KruskalResult(statistic=12.61696602292815, pvalue=0.005542599493021392)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.08891391178472874
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.118670222005076
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.5217870388929049
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.08891391178472874
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Significant difference (Mann-Whitney U) between dataset 1 and 2:  0.006978092893026958
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.08891391178472874
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.118670222005076
# Significant difference (Mann-Whitney U) between dataset 2 and 1:  0.006978092893026958
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.5217870388929049
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.08891391178472874
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Significant difference between groups:  F_onewayResult(statistic=4.670196102630932, pvalue=0.006432245399867882)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.06825274998010457
# Statistical difference (independent t-test) between dataset 0 and 2:  0.04571230472514249
# Groups are equal (independent t-test) between dataset 0 and 3:  0.19994647933201298
# Groups are equal (independent t-test) between dataset 1 and 0:  0.06825274998010457
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Statistical difference (independent t-test) between dataset 1 and 2:  0.0002289435777029874
# Statistical difference (independent t-test) between dataset 1 and 3:  0.009832907831613615
# Statistical difference (independent t-test) between dataset 2 and 0:  0.04571230472514249
# Statistical difference (independent t-test) between dataset 2 and 1:  0.0002289435777029874
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.655182566995814
# Groups are equal (independent t-test) between dataset 3 and 0:  0.19994647933201298
# Statistical difference (independent t-test) between dataset 3 and 1:  0.009832907831613615
# Groups are equal (independent t-test) between dataset 3 and 2:  0.655182566995814
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP7
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9110011458396912, pvalue=0.05746835842728615)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.856035590171814, pvalue=0.08679842948913574)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8764091730117798, pvalue=0.17395660281181335)
# Variances are equal:  BartlettResult(statistic=1.157843184845402, pvalue=0.7631319775093157)
# Groups are equal:  KruskalResult(statistic=2.943063719108874, pvalue=0.40048719259435994)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.7688001899844092
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.7688001899844092
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.7688001899844092
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.8116429677898065
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.7688001899844092
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.9817169816733098
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.8116429677898065
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.9817169816733098
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.5177461493841213, pvalue=0.22314367700000756)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.11190074007148587
# Groups are equal (independent t-test) between dataset 0 and 2:  0.2525702788524847
# Groups are equal (independent t-test) between dataset 0 and 3:  0.6866114983237711
# Groups are equal (independent t-test) between dataset 1 and 0:  0.11190074007148587
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.6517568775625122
# Groups are equal (independent t-test) between dataset 1 and 3:  0.11008399514668538
# Groups are equal (independent t-test) between dataset 2 and 0:  0.2525702788524847
# Groups are equal (independent t-test) between dataset 2 and 1:  0.6517568775625122
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.19130858325019207
# Groups are equal (independent t-test) between dataset 3 and 0:  0.6866114983237711
# Groups are equal (independent t-test) between dataset 3 and 1:  0.11008399514668538
# Groups are equal (independent t-test) between dataset 3 and 2:  0.19130858325019207
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP8
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9302546381950378, pvalue=0.1392800211906433)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8837341666221619, pvalue=0.20438437163829803)
# Variances are equal:  BartlettResult(statistic=2.126908882289613, pvalue=0.546488124719058)
# Groups are equal:  KruskalResult(statistic=3.0283203513073036, pvalue=0.38727931237025504)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.8638970307253778
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.653363345626965
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.8638970307253778
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.8638970307253778
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.8149962242512677
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.8638970307253778
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.653363345626965
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.653363345626965
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.8149962242512677
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.653363345626965
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.0161624676245946, pvalue=0.39463935328636657)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.768002448651149
# Groups are equal (independent t-test) between dataset 0 and 2:  0.7647849765574214
# Groups are equal (independent t-test) between dataset 0 and 3:  0.11304807887828161
# Groups are equal (independent t-test) between dataset 1 and 0:  0.768002448651149
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.992185251817483
# Groups are equal (independent t-test) between dataset 1 and 3:  0.23115537683583876
# Groups are equal (independent t-test) between dataset 2 and 0:  0.7647849765574214
# Groups are equal (independent t-test) between dataset 2 and 1:  0.992185251817483
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.14973033732356328
# Groups are equal (independent t-test) between dataset 3 and 0:  0.11304807887828161
# Groups are equal (independent t-test) between dataset 3 and 1:  0.23115537683583876
# Groups are equal (independent t-test) between dataset 3 and 2:  0.14973033732356328
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN1
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9464828968048096, pvalue=0.2918039560317993)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8824776411056519, pvalue=0.1393095850944519)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8804973363876343, pvalue=0.15892277657985687)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9008615612983704, pvalue=0.29415619373321533)
# Variances are equal:  BartlettResult(statistic=0.5650817941669254, pvalue=0.9043774550323754)
# Groups are equal:  KruskalResult(statistic=4.012457224190646, pvalue=0.2601221129144565)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.713010924246716
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.713010924246716
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.5666227027783896
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.713010924246716
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.6266725037137446
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.713010924246716
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.6266725037137446
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.5666227027783896
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.5666227027783896
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.5666227027783896
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.6454058973578196, pvalue=0.19261799976748614)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.31972546455017703
# Groups are equal (independent t-test) between dataset 0 and 2:  0.3491297352002424
# Groups are equal (independent t-test) between dataset 0 and 3:  0.17829199058893544
# Groups are equal (independent t-test) between dataset 1 and 0:  0.31972546455017703
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.11710922580922335
# Groups are equal (independent t-test) between dataset 1 and 3:  0.741658222199204
# Groups are equal (independent t-test) between dataset 2 and 0:  0.3491297352002424
# Groups are equal (independent t-test) between dataset 2 and 1:  0.11710922580922335
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.05185044953313691
# Groups are equal (independent t-test) between dataset 3 and 0:  0.17829199058893544
# Groups are equal (independent t-test) between dataset 3 and 1:  0.741658222199204
# Groups are equal (independent t-test) between dataset 3 and 2:  0.05185044953313691
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9032279849052429, pvalue=0.23763303458690643)
# Variances are equal:  BartlettResult(statistic=0.8493447974288229, pvalue=0.837631579248797)
# Groups are equal:  KruskalResult(statistic=1.3544459065579713, pvalue=0.7162467232158987)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.36815737737480375, pvalue=0.7763277119063433)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.9343279464637368
# Groups are equal (independent t-test) between dataset 0 and 2:  0.7699417227361776
# Groups are equal (independent t-test) between dataset 0 and 3:  0.3597480145762648
# Groups are equal (independent t-test) between dataset 1 and 0:  0.9343279464637368
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.7662265740832399
# Groups are equal (independent t-test) between dataset 1 and 3:  0.49806593485778117
# Groups are equal (independent t-test) between dataset 2 and 0:  0.7699417227361776
# Groups are equal (independent t-test) between dataset 2 and 1:  0.7662265740832399
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.29711487284410854
# Groups are equal (independent t-test) between dataset 3 and 0:  0.3597480145762648
# Groups are equal (independent t-test) between dataset 3 and 1:  0.49806593485778117
# Groups are equal (independent t-test) between dataset 3 and 2:  0.29711487284410854
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN3
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8743376731872559, pvalue=0.11227065324783325)
# Variances are equal:  BartlettResult(statistic=0.9887250680457534, pvalue=0.8039801312896114)
# Groups are equal:  KruskalResult(statistic=3.677549610295574, pvalue=0.29845403063553033)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.7511393026531185
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.7511393026531185
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.6674491056461287
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.7511393026531185
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.7511393026531185
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.7511393026531185
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.7511393026531185
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.7511393026531185
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.6585583453819837
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.6674491056461287
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.7511393026531185
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.6585583453819837
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.5201505496393422, pvalue=0.22252720285478692)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.48324407341073494
# Groups are equal (independent t-test) between dataset 0 and 2:  0.5975351918212277
# Groups are equal (independent t-test) between dataset 0 and 3:  0.09125486623140162
# Groups are equal (independent t-test) between dataset 1 and 0:  0.48324407341073494
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.2852369448448865
# Groups are equal (independent t-test) between dataset 1 and 3:  0.3154228995484301
# Groups are equal (independent t-test) between dataset 2 and 0:  0.5975351918212277
# Groups are equal (independent t-test) between dataset 2 and 1:  0.2852369448448865
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Statistical difference (independent t-test) between dataset 2 and 3:  0.04854653729064458
# Groups are equal (independent t-test) between dataset 3 and 0:  0.09125486623140162
# Groups are equal (independent t-test) between dataset 3 and 1:  0.3154228995484301
# Statistical difference (independent t-test) between dataset 3 and 2:  0.04854653729064458
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN4
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9661240577697754, pvalue=0.85276859998703)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9407155513763428, pvalue=0.5894519686698914)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9337435364723206, pvalue=0.5507544875144958)
# Variances are equal:  BartlettResult(statistic=1.0456012526807124, pvalue=0.7902196581336153)
# Groups are equal:  KruskalResult(statistic=4.102542415913624, pvalue=0.2506021726714591)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.5651467106284768
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.8482421042055787
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.5651467106284768
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.5651467106284768
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.5651467106284768
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.8482421042055787
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.5651467106284768
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.8482421042055787
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.5651467106284768
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.8482421042055787
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.593064772517676, pvalue=0.2046033813654704)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.056435578730245475
# Groups are equal (independent t-test) between dataset 0 and 2:  0.543940230846955
# Groups are equal (independent t-test) between dataset 0 and 3:  0.21192851796512024
# Groups are equal (independent t-test) between dataset 1 and 0:  0.056435578730245475
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.21689019442818044
# Groups are equal (independent t-test) between dataset 1 and 3:  0.61722067031534
# Groups are equal (independent t-test) between dataset 2 and 0:  0.543940230846955
# Groups are equal (independent t-test) between dataset 2 and 1:  0.21689019442818044
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.5185728222165054
# Groups are equal (independent t-test) between dataset 3 and 0:  0.21192851796512024
# Groups are equal (independent t-test) between dataset 3 and 1:  0.61722067031534
# Groups are equal (independent t-test) between dataset 3 and 2:  0.5185728222165054
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN5
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9452197551727295, pvalue=0.6377855539321899)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9130438566207886, pvalue=0.37599706649780273)
# Variances are equal:  BartlettResult(statistic=2.371002381797523, pvalue=0.4990553449767794)
# Groups are equal:  KruskalResult(statistic=4.927396490856153, pvalue=0.17719138416984184)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.35700104193819926
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.2931971632808134
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.14661005231876
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.35700104193819926
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.2931971632808134
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.14661005231876
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.7926269531619154, pvalue=0.16249860898473942)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.8314649610738649
# Groups are equal (independent t-test) between dataset 0 and 2:  0.5799995405673704
# Groups are equal (independent t-test) between dataset 0 and 3:  0.07550618853466493
# Groups are equal (independent t-test) between dataset 1 and 0:  0.8314649610738649
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.7427532152417413
# Groups are equal (independent t-test) between dataset 1 and 3:  0.053696231994547296
# Groups are equal (independent t-test) between dataset 2 and 0:  0.5799995405673704
# Groups are equal (independent t-test) between dataset 2 and 1:  0.7427532152417413
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Statistical difference (independent t-test) between dataset 2 and 3:  0.016371942509595998
# Groups are equal (independent t-test) between dataset 3 and 0:  0.07550618853466493
# Groups are equal (independent t-test) between dataset 3 and 1:  0.053696231994547296
# Statistical difference (independent t-test) between dataset 3 and 2:  0.016371942509595998
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8487593531608582, pvalue=0.056146830320358276)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8420252799987793, pvalue=0.060826707631349564)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8766885995864868, pvalue=0.17503859102725983)
# Variances are equal:  BartlettResult(statistic=1.1117887205214847, pvalue=0.7742290288674886)
# Groups are equal:  KruskalResult(statistic=1.222928154747763, pvalue=0.747510608490296)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.5995149600097509, pvalue=0.6187428487640545)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7257926509849685
# Groups are equal (independent t-test) between dataset 0 and 2:  0.7587203418891462
# Groups are equal (independent t-test) between dataset 0 and 3:  0.1662972309173809
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7257926509849685
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.9877611696881425
# Groups are equal (independent t-test) between dataset 1 and 3:  0.35152637699079503
# Groups are equal (independent t-test) between dataset 2 and 0:  0.7587203418891462
# Groups are equal (independent t-test) between dataset 2 and 1:  0.9877611696881425
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.3897615892123052
# Groups are equal (independent t-test) between dataset 3 and 0:  0.1662972309173809
# Groups are equal (independent t-test) between dataset 3 and 1:  0.35152637699079503
# Groups are equal (independent t-test) between dataset 3 and 2:  0.3897615892123052
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN7
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9172545671463013, pvalue=0.07648799568414688)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8640999794006348, pvalue=0.08527471870183945)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8738200068473816, pvalue=0.13506580889225006)
# Variances are equal:  BartlettResult(statistic=0.26285620691990597, pvalue=0.9668558229181231)
# Groups are equal:  KruskalResult(statistic=4.385561872483111, pvalue=0.2227278767473745)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.7934730806857235
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.8409791348179191
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.3361997471747554
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.7934730806857235
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.7934730806857235
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.8409791348179191
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.7934730806857235
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.3361997471747554
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.7934730806857235
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.7934730806857235
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.5400109242851066, pvalue=0.21749831379044288)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.23625154864981063
# Groups are equal (independent t-test) between dataset 0 and 2:  0.33347528635474044
# Groups are equal (independent t-test) between dataset 0 and 3:  0.05868570442764856
# Groups are equal (independent t-test) between dataset 1 and 0:  0.23625154864981063
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.8722398067262149
# Groups are equal (independent t-test) between dataset 1 and 3:  0.4281535417138086
# Groups are equal (independent t-test) between dataset 2 and 0:  0.33347528635474044
# Groups are equal (independent t-test) between dataset 2 and 1:  0.8722398067262149
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.35963874991629274
# Groups are equal (independent t-test) between dataset 3 and 0:  0.05868570442764856
# Groups are equal (independent t-test) between dataset 3 and 1:  0.4281535417138086
# Groups are equal (independent t-test) between dataset 3 and 2:  0.35963874991629274
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TN8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8503165245056152, pvalue=0.05859505385160446)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9065743684768677, pvalue=0.2926298975944519)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8642574548721313, pvalue=0.13234949111938477)
# Variances are equal:  BartlettResult(statistic=1.3423630740442793, pvalue=0.7190989622509806)
# Groups are equal:  KruskalResult(statistic=1.1671250729146871, pvalue=0.760899386772683)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.24235764631207468, pvalue=0.8663063069091261)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.4951374243316522
# Groups are equal (independent t-test) between dataset 0 and 2:  0.9285068054903597
# Groups are equal (independent t-test) between dataset 0 and 3:  0.5560289414782222
# ...
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.021682549624609, pvalue=0.39221598381842854)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.397534529335666
# Groups are equal (independent t-test) between dataset 0 and 2:  0.2866027716043385
# Groups are equal (independent t-test) between dataset 0 and 3:  0.08424079601404375
# Groups are equal (independent t-test) between dataset 1 and 0:  0.397534529335666
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.861580511898001
# Groups are equal (independent t-test) between dataset 1 and 3:  0.4984585376732348
# Groups are equal (independent t-test) between dataset 2 and 0:  0.2866027716043385
# Groups are equal (independent t-test) between dataset 2 and 1:  0.861580511898001
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.6154212717611296
# Groups are equal (independent t-test) between dataset 3 and 0:  0.08424079601404375
# Groups are equal (independent t-test) between dataset 3 and 1:  0.4984585376732348
# Groups are equal (independent t-test) between dataset 3 and 2:  0.6154212717611296
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ4
# =================================
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9116113185882568, pvalue=0.3655499815940857)
# Variances are equal:  BartlettResult(statistic=2.5408938693212626, pvalue=0.4679459561091591)
# Significant difference between groups:  KruskalResult(statistic=8.572148046757198, pvalue=0.03555497571634086)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.06259155396756823
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.06259155396756823
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.5988474117175432
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.06259155396756823
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.06259155396756823
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.5988474117175432
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=2.5982382479362163, pvalue=0.06417036869645089)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Statistical difference (independent t-test) between dataset 0 and 1:  0.018863162335463472
# Groups are equal (independent t-test) between dataset 0 and 2:  0.05568924355576994
# Groups are equal (independent t-test) between dataset 0 and 3:  0.0850282486911027
# Statistical difference (independent t-test) between dataset 1 and 0:  0.018863162335463472
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.6883913090331526
# Groups are equal (independent t-test) between dataset 1 and 3:  0.868642313198359
# Groups are equal (independent t-test) between dataset 2 and 0:  0.05568924355576994
# Groups are equal (independent t-test) between dataset 2 and 1:  0.6883913090331526
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.8958851805752297
# Groups are equal (independent t-test) between dataset 3 and 0:  0.0850282486911027
# Groups are equal (independent t-test) between dataset 3 and 1:  0.868642313198359
# Groups are equal (independent t-test) between dataset 3 and 2:  0.8958851805752297
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ5
# =================================
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8292355537414551, pvalue=0.058290060609579086)
# Significant difference between groups:  KruskalResult(statistic=8.56148849992931, pvalue=0.035726686677831826)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.4887831570848659
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.10540243072855289
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.4515445838247323
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.15159123381962186
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.4887831570848659
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.4515445838247323
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.10540243072855289
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.10540243072855289
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.15159123381962186
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.10540243072855289
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Significant difference between groups:  F_onewayResult(statistic=5.417338690843543, pvalue=0.0029286144010246522)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.8290110745037117
# Groups are equal (independent t-test) between dataset 0 and 2:  0.9399982125036502
# Statistical difference (independent t-test) between dataset 0 and 3:  0.0024627967045465927
# Groups are equal (independent t-test) between dataset 1 and 0:  0.8290110745037117
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.7446679128636557
# Statistical difference (independent t-test) between dataset 1 and 3:  0.015559393800861005
# Groups are equal (independent t-test) between dataset 2 and 0:  0.9399982125036502
# Groups are equal (independent t-test) between dataset 2 and 1:  0.7446679128636557
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Statistical difference (independent t-test) between dataset 2 and 3:  0.0038111866913023867
# Statistical difference (independent t-test) between dataset 3 and 0:  0.0024627967045465927
# Statistical difference (independent t-test) between dataset 3 and 1:  0.015559393800861005
# Statistical difference (independent t-test) between dataset 3 and 2:  0.0038111866913023867
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9509254693984985, pvalue=0.6794586181640625)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8344829678535461, pvalue=0.05012650787830353)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9185444712638855, pvalue=0.4181644916534424)
# Groups are equal:  KruskalResult(statistic=5.078423170636269, pvalue=0.16614386357552102)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.6107451978980931
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.6107451978980931
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.8166622863367763
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.6107451978980931
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.1618140351141521
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.6107451978980931
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.6107451978980931
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.1618140351141521
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.8166622863367763
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.6107451978980931
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=1.3544112200462062, pvalue=0.26913914074420225)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.3159902238154126
# Groups are equal (independent t-test) between dataset 0 and 2:  0.15515085290153155
# Groups are equal (independent t-test) between dataset 0 and 3:  0.8038479794889037
# Groups are equal (independent t-test) between dataset 1 and 0:  0.3159902238154126
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Statistical difference (independent t-test) between dataset 1 and 2:  0.021713074509581508
# Groups are equal (independent t-test) between dataset 1 and 3:  0.3662651453189456
# Groups are equal (independent t-test) between dataset 2 and 0:  0.15515085290153155
# Statistical difference (independent t-test) between dataset 2 and 1:  0.021713074509581508
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.4005615494600908
# Groups are equal (independent t-test) between dataset 3 and 0:  0.8038479794889037
# Groups are equal (independent t-test) between dataset 3 and 1:  0.3662651453189456
# Groups are equal (independent t-test) between dataset 3 and 2:  0.4005615494600908
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ7
# =================================
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8568006753921509, pvalue=0.11155219376087189)
# Variances are equal:  BartlettResult(statistic=1.8721108644639328, pvalue=0.5993698969107684)
# Groups are equal:  KruskalResult(statistic=0.05891390023492622, pvalue=0.9962633484044915)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.3201494419990815, pvalue=0.8107378655561105)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.6304038925942056
# Groups are equal (independent t-test) between dataset 0 and 2:  0.4132673729116133
# Groups are equal (independent t-test) between dataset 0 and 3:  0.9858325043421319
# Groups are equal (independent t-test) between dataset 1 and 0:  0.6304038925942056
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.7252667320362918
# Groups are equal (independent t-test) between dataset 1 and 3:  0.6292239850925033
# Groups are equal (independent t-test) between dataset 2 and 0:  0.4132673729116133
# Groups are equal (independent t-test) between dataset 2 and 1:  0.7252667320362918
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.37969931484082053
# Groups are equal (independent t-test) between dataset 3 and 0:  0.9858325043421319
# Groups are equal (independent t-test) between dataset 3 and 1:  0.6292239850925033
# Groups are equal (independent t-test) between dataset 3 and 2:  0.37969931484082053
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ8
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9303585290908813, pvalue=0.48476845026016235)
# Variances are equal:  BartlettResult(statistic=0.6778903495735826, pvalue=0.8783916252703637)
# Groups are equal:  KruskalResult(statistic=1.2485852557319097, pvalue=0.7413766732557232)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=0.45555393215804385, pvalue=0.7147065322432509)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7524750059600096
# Groups are equal (independent t-test) between dataset 0 and 2:  0.3046384154208435
# Groups are equal (independent t-test) between dataset 0 and 3:  0.8721112629457196
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7524750059600096
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.30054406668127814
# Groups are equal (independent t-test) between dataset 1 and 3:  0.7303161401186032
# Groups are equal (independent t-test) between dataset 2 and 0:  0.3046384154208435
# Groups are equal (independent t-test) between dataset 2 and 1:  0.30054406668127814
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.5414561656870497
# Groups are equal (independent t-test) between dataset 3 and 0:  0.8721112629457196
# Groups are equal (independent t-test) between dataset 3 and 1:  0.7303161401186032
# Groups are equal (independent t-test) between dataset 3 and 2:  0.5414561656870497
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
