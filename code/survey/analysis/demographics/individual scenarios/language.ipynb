# %%
import sys
sys.path.insert(0,'../..')
from analysis import Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATHME_BATCH2_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-2 ME.csv"
PATHME_BATCH3_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-3 ME.csv"
PATHME_BATCH4_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-4 ME.csv"

PATHME_BATCH2 = "F:\Thesis\Experiments\Costs\Results\/24-06-2022 Batch-2 ME.csv"
PATHME_BATCH3 = "F:\Thesis\Experiments\Costs\Results\/27-06-2022 Batch-3 ME.csv"
PATHME_BATCH4 = "F:\Thesis\Experiments\Costs\Results\/28-06-2022 Batch-4 ME.csv"

datame_batch2_demo = pd.read_csv(PATHME_BATCH2_DEMO)
datame_batch3_demo = pd.read_csv(PATHME_BATCH3_DEMO)
datame_batch4_demo = pd.read_csv(PATHME_BATCH4_DEMO)

datame_batch2 = pd.read_csv(PATHME_BATCH2)
datame_batch3 = pd.read_csv(PATHME_BATCH3)
datame_batch4 = pd.read_csv(PATHME_BATCH4)

datame_demo = pd.concat([datame_batch2_demo, datame_batch3_demo, datame_batch4_demo], ignore_index=True)
datame = pd.concat([datame_batch2, datame_batch3, datame_batch4], ignore_index=True)

mes_data = Analysis.convert_me_data(datame)

datame_demo = Analysis.filter_demographics_data(demo_data=datame_demo, data=mes_data)

# %%
print(datame_demo["Language"].value_counts())
# Out:
# English       21
# Polish        10
# Portuguese     9
# Spanish        8
# Italian        4
# Greek          4
# Hungarian      3
# Dutch          2
# Afrikaans      2
# Finnish        1
# German         1
# Estonian       1
# French         1
# Catalan        1
# Name: Language, dtype: int64

# %%
mes_data_english = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Language", column_value="English")
mes_data_polish = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Language", column_value="Polish")
mes_data_portuguese = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Language", column_value="Portuguese")
mes_data_spanish = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Language", column_value="Spanish")

# %%
print("English: ", mes_data_english.shape)
print("Polish: ", mes_data_polish.shape)
print("Portuguese: ", mes_data_portuguese.shape)
print("Spanish: ", mes_data_spanish.shape)
# Out:
# English:  (21, 82)
# Polish:  (10, 82)
# Portuguese:  (9, 82)
# Spanish:  (8, 82)

# %%
print("English")
Analysis.print_means(mes_data_english)
print("Polish")
Analysis.print_means(mes_data_polish)
print("Portuguese")
Analysis.print_means(mes_data_portuguese)
print("Spanish")
Analysis.print_means(mes_data_spanish)
# Out:
# English
# ===================
# TP 13.035714285714285
# TN 22.240597740597742
# FP -2.375000899090332
# FN -24.651923076923076
# REJ -0.45875
# ===================
# Polish
# ===================
# TP 17.677976190476187
# TN 46.13501082251082
# FP -13.082708333333333
# FN -22.351799242424242
# REJ -13.195647916666665
# ===================
# Portuguese
# ===================
# TP 20.3125
# TN 29.07427536231884
# FP -29.58333725208333
# FN -30.992753623188406
# REJ -5.00001249875
# ===================
# Spanish
# ===================
# TP 62.20025510204081
# TN 67.23883928571428
# FP -49.786352040816325
# FN -44.26339285714286
# REJ -24.801020408163264
# ===================

# %%
print("English")
Analysis.print_reliabilities(mes_data_english, scale="ME")
print("Polish")
Analysis.print_reliabilities(mes_data_polish, scale="ME")
print("Portuguese")
Analysis.print_reliabilities(mes_data_portuguese, scale="ME")
print("Spanish")
Analysis.print_reliabilities(mes_data_spanish, scale="ME")
# Out:
# English
# ===================
# Reliability scale:  0.7461773550405986
# TP 0.9889880821646384
# TN -0.6612469292496168
# FP 0.9952249590952289
# FN 0.8287112957011737
# REJ -0.03564888608881489
# ===================
# Polish
# ===================
# Reliability scale:  0.7983618878271288
# TP 0.9809034416210227
# TN 0.10310644410394543
# FP 0.361809585849303
# FN -0.06044714238221571
# REJ -0.5142719368184101
# ===================
# Portuguese
# ===================
# Reliability scale:  0.793286259290854
# TP -5.266385133659776
# TN 0.004158243365424363
# FP 0.4468864378005093
# FN 0.39943360935079775
# REJ 0.5491861255621567
# ===================
# Spanish
# ===================
# Reliability scale:  0.9125983738050925
# TP 0.2701292499288901
# TN 0.4262479108381326
# FP -2.622387070118096
# FN 0.576352292148322
# REJ -3.6580399860393547
# ===================

# %%
language = Analysis.print_question_statistics_multiple(mes_data_english, mes_data_polish, mes_data_portuguese, mes_data_spanish)
language.to_csv("language.csv")
# Out:
# =================================
# Question:  TP1
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9086173176765442, pvalue=0.30631721019744873)
# Variances are equal:  BartlettResult(statistic=1.5820843406386744, pvalue=0.6634588633105327)
# Groups are equal:  KruskalResult(statistic=5.89414138972913, pvalue=0.11687560877874996)
# Groups are equal:  F_onewayResult(statistic=1.403962959797152, pvalue=0.25429472331375375)
# =================================
# Question:  TP2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9254444241523743, pvalue=0.40460580587387085)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8397872447967529, pvalue=0.05744068697094917)
# Variances are equal:  BartlettResult(statistic=0.48646760644573217, pvalue=0.921854201217159)
# Groups are equal:  KruskalResult(statistic=3.4284269002659404, pvalue=0.3301642385317356)
# Groups are equal:  F_onewayResult(statistic=1.4247427204598886, pvalue=0.24830741672802165)
# =================================
# Question:  TP3
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.876862108707428, pvalue=0.12007739394903183)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9036486744880676, pvalue=0.27391448616981506)
# Variances are equal:  BartlettResult(statistic=1.2188328145558367, pvalue=0.7484910590464038)
# Significant difference between groups:  KruskalResult(statistic=8.017166914317217, pvalue=0.045658246451917184)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.561399461797078
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.352141846171749
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.1764462937924605
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.561399461797078
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.2829399957858683
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.2579031240820964
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.352141846171749
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.2829399957858683
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.1415009930640555
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.1764462937924605
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.2579031240820964
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.1415009930640555
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=2.1735735569409855, pvalue=0.10461898997830404)
# =================================
# Question:  TP4
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9212307929992676, pvalue=0.0918353870511055)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8827536702156067, pvalue=0.14032527804374695)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8417812585830688, pvalue=0.07855980843305588)
# Variances are equal:  BartlettResult(statistic=3.718878190256039, pvalue=0.29346400702216624)
# Groups are equal:  KruskalResult(statistic=4.961032034144171, pvalue=0.17467290996588358)
# Groups are equal:  F_onewayResult(statistic=1.7748908916742157, pvalue=0.16586405363032436)
# =================================
# Question:  TP5
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9536291360855103, pvalue=0.7115010023117065)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8871594071388245, pvalue=0.18650689721107483)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8659738302230835, pvalue=0.1376158893108368)
# Variances are equal:  BartlettResult(statistic=0.2989155025175366, pvalue=0.9602323158333853)
# Groups are equal:  KruskalResult(statistic=6.126381832483544, pvalue=0.10562077967190182)
# Groups are equal:  F_onewayResult(statistic=2.583340710706003, pvalue=0.06527585808574946)
# =================================
# Question:  TP6
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9130734801292419, pvalue=0.06316263228654861)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8712848424911499, pvalue=0.1034700870513916)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9222999811172485, pvalue=0.4116225838661194)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8814714550971985, pvalue=0.19451752305030823)
# Variances are equal:  BartlettResult(statistic=4.318644815710109, pvalue=0.22904848889627427)
# Significant difference between groups:  KruskalResult(statistic=12.61696602292815, pvalue=0.005542599493021392)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.08891391178472874
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.118670222005076
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.5217870388929049
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.08891391178472874
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Significant difference (Mann-Whitney U) between dataset 1 and 2:  0.006978092893026958
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.08891391178472874
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.118670222005076
# Significant difference (Mann-Whitney U) between dataset 2 and 1:  0.006978092893026958
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.5217870388929049
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.08891391178472874
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Significant difference between groups:  F_onewayResult(statistic=4.670196102630932, pvalue=0.006432245399867882)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.13650549996020914
# Groups are equal (independent t-test) between dataset 0 and 2:  0.12189947926704664
# Groups are equal (independent t-test) between dataset 0 and 3:  0.3199143669312208
# Groups are equal (independent t-test) between dataset 1 and 0:  0.13650549996020914
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Statistical difference (independent t-test) between dataset 1 and 2:  0.0018315486216238992
# Statistical difference (independent t-test) between dataset 1 and 3:  0.03933163132645446
# Groups are equal (independent t-test) between dataset 2 and 0:  0.12189947926704664
# Statistical difference (independent t-test) between dataset 2 and 1:  0.0018315486216238992
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.8735767559944186
# Groups are equal (independent t-test) between dataset 3 and 0:  0.3199143669312208
# Statistical difference (independent t-test) between dataset 3 and 1:  0.03933163132645446
# Groups are equal (independent t-test) between dataset 3 and 2:  0.8735767559944186
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  TP7
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9110011458396912, pvalue=0.05746835842728615)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.856035590171814, pvalue=0.08679842948913574)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8764091730117798, pvalue=0.17395660281181335)
# Variances are equal:  BartlettResult(statistic=1.157843184845402, pvalue=0.7631319775093157)
# Groups are equal:  KruskalResult(statistic=2.943063719108874, pvalue=0.40048719259435994)
# Groups are equal:  F_onewayResult(statistic=1.5177461493841213, pvalue=0.22314367700000756)
# =================================
# Question:  TP8
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9302546381950378, pvalue=0.1392800211906433)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8837341666221619, pvalue=0.20438437163829803)
# Variances are equal:  BartlettResult(statistic=2.126908882289613, pvalue=0.546488124719058)
# Groups are equal:  KruskalResult(statistic=3.0283203513073036, pvalue=0.38727931237025504)
# Groups are equal:  F_onewayResult(statistic=1.0161624676245946, pvalue=0.39463935328636657)
# =================================
# Question:  TN1
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9464828968048096, pvalue=0.2918039560317993)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8824776411056519, pvalue=0.1393095850944519)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8804973363876343, pvalue=0.15892277657985687)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9008615612983704, pvalue=0.29415619373321533)
# Variances are equal:  BartlettResult(statistic=0.5650817941669254, pvalue=0.9043774550323754)
# Groups are equal:  KruskalResult(statistic=4.012457224190646, pvalue=0.2601221129144565)
# Groups are equal:  F_onewayResult(statistic=1.6454058973578196, pvalue=0.19261799976748614)
# =================================
# Question:  TN2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9032279849052429, pvalue=0.23763303458690643)
# Variances are equal:  BartlettResult(statistic=0.8493447974288229, pvalue=0.837631579248797)
# Groups are equal:  KruskalResult(statistic=1.3544459065579713, pvalue=0.7162467232158987)
# Groups are equal:  F_onewayResult(statistic=0.36815737737480375, pvalue=0.7763277119063433)
# =================================
# Question:  TN3
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8743376731872559, pvalue=0.11227065324783325)
# Variances are equal:  BartlettResult(statistic=0.9887250680457534, pvalue=0.8039801312896114)
# Groups are equal:  KruskalResult(statistic=3.677549610295574, pvalue=0.29845403063553033)
# Groups are equal:  F_onewayResult(statistic=1.5201505496393422, pvalue=0.22252720285478692)
# =================================
# Question:  TN4
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9661240577697754, pvalue=0.85276859998703)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9407155513763428, pvalue=0.5894519686698914)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9337435364723206, pvalue=0.5507544875144958)
# Variances are equal:  BartlettResult(statistic=1.0456012526807124, pvalue=0.7902196581336153)
# Groups are equal:  KruskalResult(statistic=4.102542415913624, pvalue=0.2506021726714591)
# Groups are equal:  F_onewayResult(statistic=1.593064772517676, pvalue=0.2046033813654704)
# =================================
# Question:  TN5
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9452197551727295, pvalue=0.6377855539321899)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9130438566207886, pvalue=0.37599706649780273)
# Variances are equal:  BartlettResult(statistic=2.371002381797523, pvalue=0.4990553449767794)
# Groups are equal:  KruskalResult(statistic=4.927396490856153, pvalue=0.17719138416984184)
# Groups are equal:  F_onewayResult(statistic=1.7926269531619154, pvalue=0.16249860898473942)
# =================================
# Question:  TN6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8487593531608582, pvalue=0.056146830320358276)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8420252799987793, pvalue=0.060826707631349564)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8766885995864868, pvalue=0.17503859102725983)
# Variances are equal:  BartlettResult(statistic=1.1117887205214847, pvalue=0.7742290288674886)
# Groups are equal:  KruskalResult(statistic=1.222928154747763, pvalue=0.747510608490296)
# Groups are equal:  F_onewayResult(statistic=0.5995149600097509, pvalue=0.6187428487640545)
# =================================
# Question:  TN7
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9172545671463013, pvalue=0.07648799568414688)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8640999794006348, pvalue=0.08527471870183945)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8738200068473816, pvalue=0.13506580889225006)
# Variances are equal:  BartlettResult(statistic=0.26285620691990597, pvalue=0.9668558229181231)
# Groups are equal:  KruskalResult(statistic=4.385561872483111, pvalue=0.2227278767473745)
# Groups are equal:  F_onewayResult(statistic=1.5400109242851066, pvalue=0.21749831379044288)
# =================================
# Question:  TN8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8503165245056152, pvalue=0.05859505385160446)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9065743684768677, pvalue=0.2926298975944519)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8642574548721313, pvalue=0.13234949111938477)
# Variances are equal:  BartlettResult(statistic=1.3423630740442793, pvalue=0.7190989622509806)
# Groups are equal:  KruskalResult(statistic=1.1671250729146871, pvalue=0.760899386772683)
# Groups are equal:  F_onewayResult(statistic=0.24235764631207468, pvalue=0.8663063069091261)
# =================================
# Question:  FP1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.922575831413269, pvalue=0.3789408206939697)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8834607601165771, pvalue=0.17069955170154572)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8991180658340454, pvalue=0.28371673822402954)
# Variances are equal:  BartlettResult(statistic=0.14264535027118888, pvalue=0.9862691914229642)
# Groups are equal:  KruskalResult(statistic=3.4038665343767, pvalue=0.33344600156433213)
# Groups are equal:  F_onewayResult(statistic=1.1556251000988338, pvalue=0.3374216914158587)
# =================================
# Question:  FP2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8894079923629761, pvalue=0.16699132323265076)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.962023138999939, pvalue=0.8192434906959534)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9727774262428284, pvalue=0.918867290019989)
# Variances are equal:  BartlettResult(statistic=0.9762951711839056, pvalue=0.8069875596952286)
# Groups are equal:  KruskalResult(statistic=5.112238856466205, pvalue=0.16376055465153458)
# Groups are equal:  F_onewayResult(statistic=1.4502913001649043, pvalue=0.24113279384570588)
# =================================
# Question:  FP3
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8864127397537231, pvalue=0.15445701777935028)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.874148964881897, pvalue=0.16542121767997742)
# Variances are equal:  BartlettResult(statistic=3.9682556373076405, pvalue=0.264912413174538)
# Groups are equal:  KruskalResult(statistic=1.3168974149029806, pvalue=0.7251245824258159)
# Groups are equal:  F_onewayResult(statistic=0.3996767627006249, pvalue=0.7538988240561889)
# =================================
# Question:  FP4
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8616572618484497, pvalue=0.07981826364994049)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8829706311225891, pvalue=0.16869840025901794)
# Variances are equal:  BartlettResult(statistic=4.61784872752147, pvalue=0.20201626395803005)
# Groups are equal:  KruskalResult(statistic=4.819467977422516, pvalue=0.18550404792666464)
# Groups are equal:  F_onewayResult(statistic=1.8603200361968475, pvalue=0.15026654671518222)
# =================================
# Question:  FP5
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9073322415351868, pvalue=0.297647625207901)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9696009755134583, pvalue=0.8948584794998169)
# Variances are equal:  BartlettResult(statistic=0.9627574603975595, pvalue=0.8102624998680751)
# Groups are equal:  KruskalResult(statistic=2.091133648503444, pvalue=0.5537085682244054)
# Groups are equal:  F_onewayResult(statistic=0.5736275730895378, pvalue=0.6353732498417579)
# =================================
# Question:  FP6
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9815308451652527, pvalue=0.971684455871582)
# Variances are equal:  BartlettResult(statistic=0.13964136789874254, pvalue=0.986688743806091)
# Groups are equal:  KruskalResult(statistic=2.8902991616180436, pvalue=0.4088499599518688)
# Groups are equal:  F_onewayResult(statistic=1.0389633371471851, pvalue=0.3847163194009222)
# =================================
# Question:  FP7
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9213430285453796, pvalue=0.09231143444776535)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8857167363166809, pvalue=0.15167172253131866)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8624252080917358, pvalue=0.10187911987304688)
# Variances are equal:  BartlettResult(statistic=3.095174460986695, pvalue=0.3771826529433802)
# Significant difference between groups:  KruskalResult(statistic=9.803835451670784, pvalue=0.020309359740102402)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.3206148186836535
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.3206148186836535
# Significant difference (Mann-Whitney U) between dataset 0 and 3:  0.01945807507192223
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.3206148186836535
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.4435392495164258
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.3206148186836535
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.3206148186836535
# Significant difference (Mann-Whitney U) between dataset 3 and 0:  0.01945807507192223
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.4435392495164258
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.3206148186836535
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Significant difference between groups:  F_onewayResult(statistic=3.1755164132272378, pvalue=0.0332705805018432)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.3361641334044273
# Groups are equal (independent t-test) between dataset 0 and 2:  0.3361641334044273
# Groups are equal (independent t-test) between dataset 0 and 3:  0.05811796188517284
# Groups are equal (independent t-test) between dataset 1 and 0:  0.3361641334044273
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  1.0
# Groups are equal (independent t-test) between dataset 1 and 3:  0.3361641334044273
# Groups are equal (independent t-test) between dataset 2 and 0:  0.3361641334044273
# Groups are equal (independent t-test) between dataset 2 and 1:  1.0
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.3361641334044273
# Groups are equal (independent t-test) between dataset 3 and 0:  0.05811796188517284
# Groups are equal (independent t-test) between dataset 3 and 1:  0.3361641334044273
# Groups are equal (independent t-test) between dataset 3 and 2:  0.3361641334044273
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  FP8
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8715820908546448, pvalue=0.12784220278263092)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9178267121315002, pvalue=0.4124782383441925)
# Variances are equal:  BartlettResult(statistic=2.2055914374254395, pvalue=0.5308478722976193)
# Groups are equal:  KruskalResult(statistic=4.365496860858004, pvalue=0.22460603225008596)
# Groups are equal:  F_onewayResult(statistic=1.852540571787245, pvalue=0.15162427894307962)
# =================================
# Question:  FN1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.900020182132721, pvalue=0.21920838952064514)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8770349621772766, pvalue=0.14610691368579865)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9057999849319458, pvalue=0.32543349266052246)
# Variances are equal:  BartlettResult(statistic=1.0988938076945758, pvalue=0.777341129541332)
# Groups are equal:  KruskalResult(statistic=1.5600926098862908, pvalue=0.6684720143042948)
# Groups are equal:  F_onewayResult(statistic=0.3482320391646818, pvalue=0.7905859192561203)
# =================================
# Question:  FN2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9207853078842163, pvalue=0.36355137825012207)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9028782844543457, pvalue=0.2691569924354553)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8558202981948853, pvalue=0.10905512422323227)
# Variances are equal:  BartlettResult(statistic=4.9065780568357376, pvalue=0.17876717485204746)
# Groups are equal:  KruskalResult(statistic=0.22057235729332145, pvalue=0.9742018172463869)
# Groups are equal:  F_onewayResult(statistic=0.1364276398273592, pvalue=0.937758068673334)
# =================================
# Question:  FN3
# =================================
# Variances are equal:  BartlettResult(statistic=6.339893449367532, pvalue=0.09619513579591653)
# Groups are equal:  KruskalResult(statistic=2.6125225600444213, pvalue=0.4552984086345676)
# Groups are equal:  F_onewayResult(statistic=0.7958118398543348, pvalue=0.5028264207139858)
# =================================
# Question:  FN4
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9118990898132324, pvalue=0.294292688369751)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9109289646148682, pvalue=0.32243117690086365)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8896403908729553, pvalue=0.23223251104354858)
# Variances are equal:  BartlettResult(statistic=0.877551059343274, pvalue=0.8308415948736577)
# Groups are equal:  KruskalResult(statistic=0.7726881640588243, pvalue=0.8559878826054672)
# Groups are equal:  F_onewayResult(statistic=0.33290055782447986, pvalue=0.8015829452861319)
# =================================
# Question:  FN5
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9571467041969299, pvalue=0.7529134750366211)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9094710350036621, pvalue=0.3503534197807312)
# Significant difference between groups:  KruskalResult(statistic=11.590765655577277, pvalue=0.00892495623981027)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.07009140640848983
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.20928857556390176
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.647462031231313
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.07009140640848983
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Significant difference (Mann-Whitney U) between dataset 1 and 2:  0.011001389096979121
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.16368609258277292
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.20928857556390176
# Significant difference (Mann-Whitney U) between dataset 2 and 1:  0.011001389096979121
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.8377525663299107
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.647462031231313
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.16368609258277292
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.8377525663299107
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Significant difference between groups:  F_onewayResult(statistic=3.6557365121627114, pvalue=0.01943339200583191)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.12878021404890702
# Groups are equal (independent t-test) between dataset 0 and 2:  0.17874001017511754
# Groups are equal (independent t-test) between dataset 0 and 3:  0.7817468459270831
# Groups are equal (independent t-test) between dataset 1 and 0:  0.12878021404890702
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Statistical difference (independent t-test) between dataset 1 and 2:  0.00137612367553377
# Groups are equal (independent t-test) between dataset 1 and 3:  0.12878021404890702
# Groups are equal (independent t-test) between dataset 2 and 0:  0.17874001017511754
# Statistical difference (independent t-test) between dataset 2 and 1:  0.00137612367553377
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Groups are equal (independent t-test) between dataset 2 and 3:  0.6354372592974995
# Groups are equal (independent t-test) between dataset 3 and 0:  0.7817468459270831
# Groups are equal (independent t-test) between dataset 3 and 1:  0.12878021404890702
# Groups are equal (independent t-test) between dataset 3 and 2:  0.6354372592974995
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  FN6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9259177446365356, pvalue=0.40895944833755493)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8737431764602661, pvalue=0.134811669588089)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9272651076316833, pvalue=0.49152445793151855)
# Variances are equal:  BartlettResult(statistic=1.561628751041634, pvalue=0.6681211924311491)
# Groups are equal:  KruskalResult(statistic=6.642074772872497, pvalue=0.08422470973765178)
# Groups are equal:  F_onewayResult(statistic=1.8497583872321246, pvalue=0.15211281084648373)
# =================================
# Question:  FN7
# =================================
# Variances are equal:  BartlettResult(statistic=7.625374169045863, pvalue=0.0544230687962236)
# Significant difference between groups:  KruskalResult(statistic=7.996340016357509, pvalue=0.04608740710824981)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.895095775713869
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.43904966738616213
# Significant difference (Mann-Whitney U) between dataset 0 and 3:  0.049457621117769135
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.895095775713869
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.7214192496402727
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.30925062055825364
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.43904966738616213
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.7214192496402727
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.54790872147559
# Significant difference (Mann-Whitney U) between dataset 3 and 0:  0.049457621117769135
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.30925062055825364
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.54790872147559
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=2.1140223328785317, pvalue=0.11206832497190065)
# =================================
# Question:  FN8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9424112439155579, pvalue=0.580142617225647)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8547254800796509, pvalue=0.08397985994815826)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9489083886146545, pvalue=0.7002192735671997)
# Variances are equal:  BartlettResult(statistic=2.964219507035673, pvalue=0.39717478734449974)
# Groups are equal:  KruskalResult(statistic=3.1901297042061163, pvalue=0.3632295872718707)
# Groups are equal:  F_onewayResult(statistic=0.9561100568511296, pvalue=0.42188481514677423)
# =================================
# Question:  REJ1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8522130250930786, pvalue=0.06171688809990883)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8653308153152466, pvalue=0.13562089204788208)
# Variances are equal:  BartlettResult(statistic=7.5532984268721926, pvalue=0.05620468662385618)
# Significant difference between groups:  KruskalResult(statistic=10.884581713934733, pvalue=0.012366641328044471)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.0755588661923096
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.3871176545824401
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.149320574767434
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.0755588661923096
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.0755588661923096
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.7113885019430745
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.3871176545824401
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.0755588661923096
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.09640158007970924
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.149320574767434
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.7113885019430745
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.09640158007970924
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=2.3184615271511904, pvalue=0.0885152165245431)
# =================================
# Question:  REJ2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9465481042861938, pvalue=0.6278766989707947)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8791290521621704, pvalue=0.1537395715713501)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8972160816192627, pvalue=0.27267998456954956)
# Variances are equal:  BartlettResult(statistic=1.1512967707435444, pvalue=0.7647074531661477)
# Groups are equal:  KruskalResult(statistic=4.030798396625579, pvalue=0.2581576067984458)
# Groups are equal:  F_onewayResult(statistic=1.3389213978321797, pvalue=0.2739478987190371)
# =================================
# Question:  REJ3
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8960773944854736, pvalue=0.1983025223016739)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9411152601242065, pvalue=0.593687117099762)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8506577610969543, pvalue=0.09674138575792313)
# Variances are equal:  BartlettResult(statistic=1.2270844971019992, pvalue=0.7465159277727249)
# Groups are equal:  KruskalResult(statistic=2.4644117900571505, pvalue=0.4817570153369478)
# Groups are equal:  F_onewayResult(statistic=1.021682549624609, pvalue=0.39221598381842854)
# =================================
# Question:  REJ4
# =================================
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9116113185882568, pvalue=0.3655499815940857)
# Variances are equal:  BartlettResult(statistic=2.5408938693212626, pvalue=0.4679459561091591)
# Significant difference between groups:  KruskalResult(statistic=8.572148046757198, pvalue=0.03555497571634086)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.06259155396756823
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.06259155396756823
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.5988474117175432
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.06259155396756823
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.06259155396756823
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.5988474117175432
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Groups are equal:  F_onewayResult(statistic=2.5982382479362163, pvalue=0.06417036869645089)
# =================================
# Question:  REJ5
# =================================
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8292355537414551, pvalue=0.058290060609579086)
# Significant difference between groups:  KruskalResult(statistic=8.56148849992931, pvalue=0.035726686677831826)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.4887831570848659
# Groups are equal (Mann-Whitney U) between dataset 0 and 3:  0.10540243072855289
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.4515445838247323
# Groups are equal (Mann-Whitney U) between dataset 1 and 3:  0.15159123381962186
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.4887831570848659
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.4515445838247323
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 3:  0.10540243072855289
# Groups are equal (Mann-Whitney U) between dataset 3 and 0:  0.10540243072855289
# Groups are equal (Mann-Whitney U) between dataset 3 and 1:  0.15159123381962186
# Groups are equal (Mann-Whitney U) between dataset 3 and 2:  0.10540243072855289
# Groups are equal (Mann-Whitney U) between dataset 3 and 3:  1.0
# Significant difference between groups:  F_onewayResult(statistic=5.417338690843543, pvalue=0.0029286144010246522)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  1.0
# Groups are equal (independent t-test) between dataset 0 and 2:  1.0
# Statistical difference (independent t-test) between dataset 0 and 3:  0.015244746765209547
# Groups are equal (independent t-test) between dataset 1 and 0:  1.0
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  1.0
# Statistical difference (independent t-test) between dataset 1 and 3:  0.04149171680229601
# Groups are equal (independent t-test) between dataset 2 and 0:  1.0
# Groups are equal (independent t-test) between dataset 2 and 1:  1.0
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# Statistical difference (independent t-test) between dataset 2 and 3:  0.015244746765209547
# Statistical difference (independent t-test) between dataset 3 and 0:  0.015244746765209547
# Statistical difference (independent t-test) between dataset 3 and 1:  0.04149171680229601
# Statistical difference (independent t-test) between dataset 3 and 2:  0.015244746765209547
# Groups are equal (independent t-test) between dataset 3 and 3:  1.0
# =================================
# Question:  REJ6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9509254693984985, pvalue=0.6794586181640625)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.8344829678535461, pvalue=0.05012650787830353)
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.9185444712638855, pvalue=0.4181644916534424)
# Groups are equal:  KruskalResult(statistic=5.078423170636269, pvalue=0.16614386357552102)
# Groups are equal:  F_onewayResult(statistic=1.3544112200462062, pvalue=0.26913914074420225)
# =================================
# Question:  REJ7
# =================================
# Dataset 3 is normally distributed:  ShapiroResult(statistic=0.8568006753921509, pvalue=0.11155219376087189)
# Variances are equal:  BartlettResult(statistic=1.8721108644639328, pvalue=0.5993698969107684)
# Groups are equal:  KruskalResult(statistic=0.05891390023492622, pvalue=0.9962633484044915)
# Groups are equal:  F_onewayResult(statistic=0.3201494419990815, pvalue=0.8107378655561105)
# =================================
# Question:  REJ8
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9303585290908813, pvalue=0.48476845026016235)
# Variances are equal:  BartlettResult(statistic=0.6778903495735826, pvalue=0.8783916252703637)
# Groups are equal:  KruskalResult(statistic=1.2485852557319097, pvalue=0.7413766732557232)
# Groups are equal:  F_onewayResult(statistic=0.45555393215804385, pvalue=0.7147065322432509)
