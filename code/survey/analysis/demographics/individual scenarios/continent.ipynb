# %%
import sys
sys.path.insert(0,'../..')
from analysis import Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATHME_BATCH2_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-2 ME.csv"
PATHME_BATCH3_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-3 ME.csv"
PATHME_BATCH4_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-4 ME.csv"

PATHME_BATCH2 = "F:\Thesis\Experiments\Costs\Results\/24-06-2022 Batch-2 ME.csv"
PATHME_BATCH3 = "F:\Thesis\Experiments\Costs\Results\/27-06-2022 Batch-3 ME.csv"
PATHME_BATCH4 = "F:\Thesis\Experiments\Costs\Results\/28-06-2022 Batch-4 ME.csv"

datame_batch2_demo = pd.read_csv(PATHME_BATCH2_DEMO)
datame_batch3_demo = pd.read_csv(PATHME_BATCH3_DEMO)
datame_batch4_demo = pd.read_csv(PATHME_BATCH4_DEMO)

datame_batch2 = pd.read_csv(PATHME_BATCH2)
datame_batch3 = pd.read_csv(PATHME_BATCH3)
datame_batch4 = pd.read_csv(PATHME_BATCH4)

datame_demo = pd.concat([datame_batch2_demo, datame_batch3_demo, datame_batch4_demo], ignore_index=True)

datame = pd.concat([datame_batch2, datame_batch3, datame_batch4], ignore_index=True)

mes_data = Analysis.convert_me_data(datame)

datame_demo = Analysis.filter_demographics_data(demo_data=datame_demo, data=mes_data)

# %%
print(datame_demo["Nationality"].value_counts())
# Out:
# South Africa                         22
# Poland                               10
# Portugal                              8
# Spain                                 5
# Italy                                 4
# Greece                                4
# Hungary                               3
# Mexico                                2
# Netherlands                           2
# United States                         1
# Finland                               1
# Chile                                 1
# Germany                               1
# Estonia                               1
# Zimbabwe                              1
# France                                1
# Venezuela, Bolivarian Republic of     1
# Name: Nationality, dtype: int64

# %%
mes_data_south_africa = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Nationality", column_value="South Africa")
mes_data_poland = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Nationality", column_value="Poland")
mes_data_portugal = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Nationality", column_value="Portugal")
mes_data_spain = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Nationality", column_value="Spain")

mes_data_europe =  pd.concat([mes_data_poland, mes_data_portugal, mes_data_spain], ignore_index=True)
mes_data_africa = mes_data_south_africa

# %%
print("Europe: ", mes_data_europe.shape)
print("Africa: ", mes_data_africa.shape)
# Out:
# Europe:  (23, 82)
# Africa:  (22, 82)

# %%
print("Europe")
Analysis.print_means(mes_data_europe)
print("Africa")
Analysis.print_means(mes_data_africa)
# Out:
# Europe
# ===================
# TP 26.145833333333336
# TN 53.64583333333333
# FP -33.28125
# FN -29.25486111
# REJ -8.0125
# ===================
# Africa
# ===================
# TP 11.750498251748251
# TN 29.28873585123585
# FP -7.034459985055844
# FN -28.572985347985348
# REJ -1.5187386048485398
# ===================

# %%
print("Europe")
Analysis.print_reliabilities(mes_data_europe, scale="ME")
print("Africa")
Analysis.print_reliabilities(mes_data_africa, scale="ME")
# Out:
# Europe
# ===================
# Reliability scale:  0.7996335116396058
# TP 0.6628370694370815
# TN -0.12903496740923703
# FP 0.21683807763259944
# FN -0.012076100076690244
# REJ 0.5462149974200006
# ===================
# Africa
# ===================
# Reliability scale:  0.7681767756569474
# TP 0.9439603994269852
# TN -0.6558986854407147
# FP 0.99463332129488
# FN 0.8221430066983968
# REJ -0.03296002301161516
# ===================

# %%
continent = Analysis.print_question_statistics(mes_data_europe, mes_data_africa)
continent.to_csv("continent.csv")
# Out:
# =================================
# Question:  TP1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9188551902770996, pvalue=0.07198245823383331)
# Variances are equal:  BartlettResult(statistic=0.9716220252203309, pvalue=0.3242759834089621)
# No significant difference:  MannwhitneyuResult(statistic=251.5, pvalue=0.9818556613147136)
# No significant difference:  Ttest_indResult(statistic=0.9143548956766941, pvalue=0.3656293307137568)
# =================================
# Question:  TP2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9216194152832031, pvalue=0.0721641480922699)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9333963394165039, pvalue=0.14439894258975983)
# Variances are equal:  BartlettResult(statistic=0.2605869342742414, pvalue=0.6097172096064815)
# No significant difference:  MannwhitneyuResult(statistic=291.5, pvalue=0.3869826524355392)
# No significant difference:  Ttest_indResult(statistic=0.9919772496197138, pvalue=0.32675811842823965)
# =================================
# Question:  TP3
# =================================
# Variances are equal:  BartlettResult(statistic=1.372397515720244, pvalue=0.24140038411895948)
# No significant difference:  MannwhitneyuResult(statistic=278.0, pvalue=0.5771572962031482)
# No significant difference:  Ttest_indResult(statistic=0.34544436017865743, pvalue=0.731444606897507)
# =================================
# Question:  TP4
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9440779685974121, pvalue=0.23999550938606262)
# Variances are equal:  BartlettResult(statistic=0.0014019981786654702, pvalue=0.970131575456042)
# No significant difference:  MannwhitneyuResult(statistic=266.0, pvalue=0.7738401474825923)
# No significant difference:  Ttest_indResult(statistic=0.4929578308107246, pvalue=0.6245504655938752)
# =================================
# Question:  TP5
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9307693243026733, pvalue=0.11363077163696289)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9250940680503845, pvalue=0.09697834402322769)
# Variances are equal:  BartlettResult(statistic=0.8251330242032829, pvalue=0.3636836519342236)
# No significant difference:  MannwhitneyuResult(statistic=214.5, pvalue=0.38724974447885796)
# No significant difference:  Ttest_indResult(statistic=-0.7963451947575967, pvalue=0.4302062492352974)
# =================================
# Question:  TP6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9354918003082275, pvalue=0.1596391350030899)
# Variances are equal:  BartlettResult(statistic=0.5583730160094098, pvalue=0.45491652286316864)
# No significant difference:  MannwhitneyuResult(statistic=271.5, pvalue=0.6816643971178604)
# No significant difference:  Ttest_indResult(statistic=0.8225741147499283, pvalue=0.4152885858898885)
# =================================
# Question:  TP7
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9348522424697876, pvalue=0.13921895623207092)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9303693175315857, pvalue=0.12488982826471329)
# Variances are equal:  BartlettResult(statistic=0.07481820089899996, pvalue=0.7844464808915474)
# No significant difference:  MannwhitneyuResult(statistic=170.0, pvalue=0.059379129954999804)
# No significant difference:  Ttest_indResult(statistic=-1.82797475479227, pvalue=0.07449679724469604)
# =================================
# Question:  TP8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9414098858833313, pvalue=0.21161703765392303)
# Variances are equal:  BartlettResult(statistic=0.0060747087183773245, pvalue=0.9378754484686295)
# No significant difference:  MannwhitneyuResult(statistic=304.5, pvalue=0.24616483537496958)
# No significant difference:  Ttest_indResult(statistic=0.790429034400625, pvalue=0.43361506832292085)
# =================================
# Question:  TN1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9540031552314758, pvalue=0.3782292902469635)
# Variances are equal:  BartlettResult(statistic=0.013600616290244462, pvalue=0.9071598566498248)
# No significant difference:  MannwhitneyuResult(statistic=279.5, pvalue=0.5541193173237149)
# No significant difference:  Ttest_indResult(statistic=0.6815478087760464, pvalue=0.4991794291711368)
# =================================
# Question:  TN2
# =================================
# Variances are equal:  BartlettResult(statistic=0.10303872396032218, pvalue=0.7482130775625249)
# No significant difference:  MannwhitneyuResult(statistic=274.5, pvalue=0.63290631360366)
# No significant difference:  Ttest_indResult(statistic=0.46477002342684126, pvalue=0.6444411052405207)
# =================================
# Question:  TN3
# =================================
# Variances are equal:  BartlettResult(statistic=0.034559571054653876, pvalue=0.8525215769627597)
# No significant difference:  MannwhitneyuResult(statistic=266.5, pvalue=0.7655612324020983)
# No significant difference:  Ttest_indResult(statistic=0.511577905848603, pvalue=0.6115636845959844)
# =================================
# Question:  TN4
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9634686708450317, pvalue=0.5368479490280151)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9198190569877625, pvalue=0.07536552846431732)
# Variances are equal:  BartlettResult(statistic=0.9542227309075799, pvalue=0.3286467616070914)
# No significant difference:  MannwhitneyuResult(statistic=336.5, pvalue=0.059017136721813586)
# Significant difference:  Ttest_indResult(statistic=2.0503821233086867, pvalue=0.0464545864097121)
# =================================
# Question:  TN5
# =================================
# Variances are equal:  BartlettResult(statistic=0.15437353805887225, pvalue=0.6943904013597072)
# No significant difference:  MannwhitneyuResult(statistic=250.5, pvalue=0.9635590971991661)
# No significant difference:  Ttest_indResult(statistic=0.02055536293869889, pvalue=0.983695436485368)
# =================================
# Question:  TN6
# =================================
# Variances are equal:  BartlettResult(statistic=0.053481933995715415, pvalue=0.8171115661828512)
# No significant difference:  MannwhitneyuResult(statistic=276.0, pvalue=0.6078583330780432)
# No significant difference:  Ttest_indResult(statistic=0.8389503740468239, pvalue=0.4061370613488414)
# =================================
# Question:  TN7
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9168108105659485, pvalue=0.06531310826539993)
# Variances are equal:  BartlettResult(statistic=1.3902002974047425, pvalue=0.23837127711104258)
# Significant difference:  MannwhitneyuResult(statistic=339.5, pvalue=0.0499114818441215)
# Significant difference:  Ttest_indResult(statistic=2.2713742708679687, pvalue=0.028187235701805584)
# =================================
# Question:  TN8
# =================================
# Variances are equal:  BartlettResult(statistic=0.33746780093147616, pvalue=0.5612945146840291)
# No significant difference:  MannwhitneyuResult(statistic=296.5, pvalue=0.3271649003642938)
# No significant difference:  Ttest_indResult(statistic=1.017132390755284, pvalue=0.314779481168255)
# =================================
# Question:  FP1
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9147095084190369, pvalue=0.05137541517615318)
# Variances are equal:  BartlettResult(statistic=0.009637599176873244, pvalue=0.921796291725331)
# No significant difference:  MannwhitneyuResult(statistic=172.0, pvalue=0.06485256425834496)
# Significant difference:  Ttest_indResult(statistic=-2.1214237821138524, pvalue=0.03968957470745177)
# =================================
# Question:  FP2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.956778347492218, pvalue=0.4014972150325775)
# Variances are equal:  BartlettResult(statistic=0.7354190854951876, pvalue=0.3911322716221226)
# No significant difference:  MannwhitneyuResult(statistic=191.0, pvalue=0.15470929161122532)
# No significant difference:  Ttest_indResult(statistic=-1.5888795343595354, pvalue=0.11941428202521516)
# =================================
# Question:  FP3
# =================================
# Variances are equal:  BartlettResult(statistic=0.32033189639812015, pvalue=0.5714082556292863)
# No significant difference:  MannwhitneyuResult(statistic=246.5, pvalue=0.8885696717638688)
# No significant difference:  Ttest_indResult(statistic=-0.1493172209297255, pvalue=0.882001457611293)
# =================================
# Question:  FP4
# =================================
# Variances are equal:  BartlettResult(statistic=1.243457271601792, pvalue=0.26480579213239797)
# No significant difference:  MannwhitneyuResult(statistic=247.5, pvalue=0.9084324416886589)
# No significant difference:  Ttest_indResult(statistic=-0.6021719084796576, pvalue=0.5502220453217388)
# =================================
# Question:  FP5
# =================================
# Variances are equal:  BartlettResult(statistic=0.7083068458295542, pvalue=0.40000647169389736)
# No significant difference:  MannwhitneyuResult(statistic=199.5, pvalue=0.22006205908196286)
# No significant difference:  Ttest_indResult(statistic=-1.3272631149514285, pvalue=0.19142605539982746)
# =================================
# Question:  FP6
# =================================
# Variances are equal:  BartlettResult(statistic=0.21188192441242912, pvalue=0.6452963528324023)
# No significant difference:  MannwhitneyuResult(statistic=227.0, pvalue=0.5548911992208245)
# No significant difference:  Ttest_indResult(statistic=-0.9545997479106524, pvalue=0.3451161071685992)
# =================================
# Question:  FP7
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9185898303985596, pvalue=0.07107861340045929)
# Variances are equal:  BartlettResult(statistic=0.655231346613628, pvalue=0.41824852251427225)
# Significant difference:  MannwhitneyuResult(statistic=146.0, pvalue=0.015276026939193228)
# Significant difference:  Ttest_indResult(statistic=-2.549443921368707, pvalue=0.014437990236755892)
# =================================
# Question:  FP8
# =================================
# Variances are equal:  BartlettResult(statistic=3.7965182380375166, pvalue=0.05135927574136867)
# No significant difference:  MannwhitneyuResult(statistic=235.0, pvalue=0.6812580056481263)
# No significant difference:  Ttest_indResult(statistic=-0.5410775475334314, pvalue=0.5912464340808725)
# =================================
# Question:  FN1
# =================================
# Variances are equal:  BartlettResult(statistic=0.43231443481513837, pvalue=0.5108554701863013)
# No significant difference:  MannwhitneyuResult(statistic=297.5, pvalue=0.31650579696614034)
# No significant difference:  Ttest_indResult(statistic=0.750802589452092, pvalue=0.45686068457043094)
# =================================
# Question:  FN2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9473071694374084, pvalue=0.2570778727531433)
# Variances are equal:  BartlettResult(statistic=1.5954190081282085, pvalue=0.2065536141163757)
# No significant difference:  MannwhitneyuResult(statistic=267.0, pvalue=0.7587710508872891)
# No significant difference:  Ttest_indResult(statistic=0.6996199989007005, pvalue=0.48793236241393845)
# =================================
# Question:  FN3
# =================================
# Variances are equal:  BartlettResult(statistic=1.755090588486918, pvalue=0.18523805221165635)
# No significant difference:  MannwhitneyuResult(statistic=283.0, pvalue=0.47973698609441207)
# No significant difference:  Ttest_indResult(statistic=0.48956766085697634, pvalue=0.6269281909867601)
# =================================
# Question:  FN4
# =================================
# Variances are equal:  BartlettResult(statistic=0.6850783563679689, pvalue=0.40784347619371186)
# No significant difference:  MannwhitneyuResult(statistic=286.5, pvalue=0.45033547621302894)
# No significant difference:  Ttest_indResult(statistic=0.7680795430853047, pvalue=0.4466376506030181)
# =================================
# Question:  FN5
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9310829639434814, pvalue=0.11541768163442612)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9143174886703491, pvalue=0.05803105607628822)
# Variances are equal:  BartlettResult(statistic=0.004629148940784952, pvalue=0.9457555046729448)
# No significant difference:  MannwhitneyuResult(statistic=241.5, pvalue=0.8021950539423451)
# No significant difference:  Ttest_indResult(statistic=-0.4969667568938177, pvalue=0.6217439848571411)
# =================================
# Question:  FN6
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9526339769363403, pvalue=0.33154013752937317)
# Variances are equal:  BartlettResult(statistic=0.1765979297337283, pvalue=0.6743133763181204)
# No significant difference:  MannwhitneyuResult(statistic=257.5, pvalue=0.9275354774757046)
# No significant difference:  Ttest_indResult(statistic=-0.07292463429291667, pvalue=0.9422042562777634)
# =================================
# Question:  FN7
# =================================
# Variances are equal:  BartlettResult(statistic=3.5420589921420715, pvalue=0.05983114639788148)
# No significant difference:  MannwhitneyuResult(statistic=179.0, pvalue=0.09254682459044117)
# No significant difference:  Ttest_indResult(statistic=-0.9673707171339349, pvalue=0.3387684414211509)
# =================================
# Question:  FN8
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9608941078186035, pvalue=0.481659859418869)
# Variances are equal:  BartlettResult(statistic=2.6245105218118097, pvalue=0.10522494958686043)
# No significant difference:  MannwhitneyuResult(statistic=242.5, pvalue=0.8193760206540015)
# No significant difference:  Ttest_indResult(statistic=0.23912512556696539, pvalue=0.8121446570222781)
# =================================
# Question:  REJ1
# =================================
# No significant difference:  MannwhitneyuResult(statistic=226.5, pvalue=0.5438416208724329)
# No significant difference:  Ttest_indResult(statistic=-0.4262529146273839, pvalue=0.6720498783647213)
# =================================
# Question:  REJ2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9316038489341736, pvalue=0.11844788491725922)
# Variances are equal:  BartlettResult(statistic=0.14684873696831643, pvalue=0.7015651930497965)
# No significant difference:  MannwhitneyuResult(statistic=238.0, pvalue=0.7410560722863606)
# No significant difference:  Ttest_indResult(statistic=-0.4458323156282066, pvalue=0.6579552002600428)
# =================================
# Question:  REJ3
# =================================
# Variances are equal:  BartlettResult(statistic=0.9416487210042329, pvalue=0.33185419320303366)
# No significant difference:  MannwhitneyuResult(statistic=182.5, pvalue=0.10840560602585866)
# No significant difference:  Ttest_indResult(statistic=-1.464259483301499, pvalue=0.15039617415517842)
# =================================
# Question:  REJ4
# =================================
# Variances are equal:  BartlettResult(statistic=0.00556690335284021, pvalue=0.9405236777447504)
# Significant difference:  MannwhitneyuResult(statistic=116.5, pvalue=0.0017637296617419615)
# Significant difference:  Ttest_indResult(statistic=-3.1641656641295164, pvalue=0.002854178713588256)
# =================================
# Question:  REJ5
# =================================
# Variances are equal:  BartlettResult(statistic=0.03475862630555087, pvalue=0.8521023498110658)
# No significant difference:  MannwhitneyuResult(statistic=274.5, pvalue=0.569789493462345)
# No significant difference:  Ttest_indResult(statistic=-0.4066561811679367, pvalue=0.6862775590252836)
# =================================
# Question:  REJ6
# =================================
# Variances are equal:  BartlettResult(statistic=0.06707085967998065, pvalue=0.7956503452246166)
# No significant difference:  MannwhitneyuResult(statistic=237.0, pvalue=0.7159848373000723)
# No significant difference:  Ttest_indResult(statistic=-0.2983099166185533, pvalue=0.7669034188255074)
# =================================
# Question:  REJ7
# =================================
# Variances are equal:  BartlettResult(statistic=2.2065756100411984, pvalue=0.13742341981829545)
# No significant difference:  MannwhitneyuResult(statistic=256.5, pvalue=0.9422186463053148)
# No significant difference:  Ttest_indResult(statistic=0.756763832354693, pvalue=0.4533180308950193)
# =================================
# Question:  REJ8
# =================================
# Variances are equal:  BartlettResult(statistic=0.4771141629205639, pvalue=0.4897323982022712)
# No significant difference:  MannwhitneyuResult(statistic=256.5, pvalue=0.9435118947655526)
# No significant difference:  Ttest_indResult(statistic=0.0029083828195688157, pvalue=0.9976929008189408)
