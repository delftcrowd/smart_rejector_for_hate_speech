# %%
import sys
sys.path.insert(0,'../..')
from analysis import Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATHME_BATCH2_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-2 ME.csv"
PATHME_BATCH3_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-3 ME.csv"
PATHME_BATCH4_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-4 ME.csv"

PATHME_BATCH2 = "F:\Thesis\Experiments\Costs\Results\/24-06-2022 Batch-2 ME.csv"
PATHME_BATCH3 = "F:\Thesis\Experiments\Costs\Results\/27-06-2022 Batch-3 ME.csv"
PATHME_BATCH4 = "F:\Thesis\Experiments\Costs\Results\/28-06-2022 Batch-4 ME.csv"
datame_batch2_demo = pd.read_csv(PATHME_BATCH2_DEMO)
datame_batch3_demo = pd.read_csv(PATHME_BATCH3_DEMO)
datame_batch4_demo = pd.read_csv(PATHME_BATCH4_DEMO)

datame_batch2 = pd.read_csv(PATHME_BATCH2)
datame_batch3 = pd.read_csv(PATHME_BATCH3)
datame_batch4 = pd.read_csv(PATHME_BATCH4)

datame_demo = pd.concat([datame_batch2_demo, datame_batch3_demo, datame_batch4_demo], ignore_index=True)
datame = pd.concat([datame_batch2, datame_batch3, datame_batch4], ignore_index=True)
mes_data = Analysis.convert_me_data(datame)
datame_demo = Analysis.filter_demographics_data(demo_data=datame_demo, data=mes_data)
mes_data_white = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Ethnicity", column_value="White")
mes_data_mixed = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Ethnicity", column_value="Mixed")
mes_data_asian = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Ethnicity", column_value="Asian")
mes_data_black = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Ethnicity", column_value="Black")
mes_data_other = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Ethnicity", column_value="Other")

# %%
print("White: ", mes_data_white.shape)
print("Mixed: ", mes_data_mixed.shape)
print("Asian: ", mes_data_asian.shape)
print("Black: ", mes_data_black.shape)
print("Other: ", mes_data_other.shape)
# Out:
# White:  (44, 82)
# Mixed:  (5, 82)
# Asian:  (0, 0)
# Black:  (18, 82)
# Other:  (1, 82)

# %%
print("White")
Analysis.print_means(mes_data_white)
print("Mixed")
Analysis.print_means(mes_data_mixed)
print("Asian")
Analysis.print_means(mes_data_asian)
print("Black")
Analysis.print_means(mes_data_black)
print("Other")
Analysis.print_means(mes_data_other)
# Out:
# White
# ===================
# TP 26.376488095238095
# TN 39.854166666666664
# FP -24.825907590759076
# FN -31.546240941473428
# REJ -6.40958630952381
# ===================
# Mixed
# ===================
# TP 49.285714285714285
# TN 58.18318318318318
# FP -46.60877714449143
# FN -43.25255102040816
# REJ -25.005005005005003
# ===================
# Asian
# ===================
# TP nan
# TN nan
# FP nan
# FN nan
# REJ nan
# ===================
# Black
# ===================
# TP 10.941079753579753
# TN 20.16318142227281
# FP -1.968750449545166
# FN -25.817628205128205
# REJ -0.8132933149989422
# ===================
# Other
# ===================
# TP 1.9999999999999998
# TN 44.5
# FP -37.75
# FN -16.5
# REJ -1.25
# ===================

# %%
print("White")
Analysis.print_reliabilities(mes_data_white, scale="ME")
print("Mixed")
Analysis.print_reliabilities(mes_data_mixed, scale="ME")
print("Asian")
Analysis.print_reliabilities(mes_data_asian, scale="ME")
print("Black")
Analysis.print_reliabilities(mes_data_black, scale="ME")
print("Other")
Analysis.print_reliabilities(mes_data_other, scale="ME")
# Out:
# White
# ===================
# Reliability scale:  0.9639234181450919
# TP 0.24917045523882364
# TN 0.22172163522242416
# FP 0.18703154619238072
# FN 0.3474333860897282
# REJ -0.24153886153215054
# ===================
# Mixed
# ===================
# Reliability scale:  0.11142699649639487
# TP -2.8899020869570524
# TN 0.9997486583333411
# FP -3.2906408743939384
# FN 0.9991621881006958
# REJ -6.161974926516546
# ===================
# Asian
# ===================
# Reliability scale:  None
# TP None
# TN None
# FP None
# FN None
# REJ None
# ===================
# Black
# ===================
# Reliability scale:  0.5242358542639157
# TP 0.04617591572885493
# TN 0.6903476116252976
# FP 0.12735197363305162
# FN -1.1190231114814044
# REJ 0.8985319561320642
# ===================
# Other
# ===================
# Reliability scale:  nan
# TP nan
# TN nan
# FP nan
# FN nan
# REJ nan
# ===================
# c:\Users\phili\anaconda3\envs\smart-rejector\lib\site-packages\krippendorff\krippendorff.py:297: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (o * d).sum() / (e * d).sum()

# %%
ethnicity = Analysis.print_question_statistics_multiple(mes_data_white, mes_data_mixed, mes_data_black)
ethnicity.to_csv("ethnicity.csv")
# Out:
# =================================
# Question:  TP1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.780037522315979, pvalue=0.05516137182712555)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9060991406440735, pvalue=0.07345669716596603)
# Variances are equal:  BartlettResult(statistic=2.008443888732512, pvalue=0.36632954871939183)
# Groups are equal:  KruskalResult(statistic=4.455929387539541, pvalue=0.10774750628747895)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.1175032415127873
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.1175032415127873
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.1175032415127873
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.1175032415127873
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=2.632523150624798, pvalue=0.07967224295731565)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.061508540206321745
# Groups are equal (independent t-test) between dataset 0 and 2:  0.259746546566575
# Groups are equal (independent t-test) between dataset 1 and 0:  0.061508540206321745
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.05755417591974059
# Groups are equal (independent t-test) between dataset 2 and 0:  0.259746546566575
# Groups are equal (independent t-test) between dataset 2 and 1:  0.05755417591974059
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TP2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9628541469573975, pvalue=0.8277052044868469)
# Variances are equal:  BartlettResult(statistic=2.3803148016285625, pvalue=0.3041733831603639)
# Groups are equal:  KruskalResult(statistic=1.5346698963045873, pvalue=0.4642486678815816)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.7501544418913699
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.7501544418913699
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.7501544418913699
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.7501544418913699
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.7501544418913699
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.7501544418913699
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.6923848316130053, pvalue=0.5040899357412623)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.3348648936792089
# Groups are equal (independent t-test) between dataset 0 and 2:  0.46369834577182856
# Groups are equal (independent t-test) between dataset 1 and 0:  0.3348648936792089
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.5326942277823122
# Groups are equal (independent t-test) between dataset 2 and 0:  0.46369834577182856
# Groups are equal (independent t-test) between dataset 2 and 1:  0.5326942277823122
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TP3
# =================================
# Variances are equal:  BartlettResult(statistic=1.8588615832472126, pvalue=0.39477835757795215)
# Groups are equal:  KruskalResult(statistic=3.962851574493055, pvalue=0.1378725202248784)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.2696551661590538
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.5512637376388464
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.2696551661590538
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.23264581857667083
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.5512637376388464
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.23264581857667083
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.8275899235970305, pvalue=0.16909294026370794)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.12042945113079274
# Groups are equal (independent t-test) between dataset 0 and 2:  0.5404129557302092
# Groups are equal (independent t-test) between dataset 1 and 0:  0.12042945113079274
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Statistical difference (independent t-test) between dataset 1 and 2:  0.03012724410202813
# Groups are equal (independent t-test) between dataset 2 and 0:  0.5404129557302092
# Statistical difference (independent t-test) between dataset 2 and 1:  0.03012724410202813
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TP4
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9388766884803772, pvalue=0.6580075621604919)
# Variances are equal:  BartlettResult(statistic=0.6736188978101569, pvalue=0.7140448889755758)
# Groups are equal:  KruskalResult(statistic=1.1298371774703975, pvalue=0.5684064195594889)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.8371159149900218, pvalue=0.43764212034535277)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.9717756482500931
# Groups are equal (independent t-test) between dataset 0 and 2:  0.19946527826977262
# Groups are equal (independent t-test) between dataset 1 and 0:  0.9717756482500931
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.4844560879712295
# Groups are equal (independent t-test) between dataset 2 and 0:  0.19946527826977262
# Groups are equal (independent t-test) between dataset 2 and 1:  0.4844560879712295
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TP5
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9603829383850098, pvalue=0.1345054805278778)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8277820944786072, pvalue=0.13387759029865265)
# Variances are equal:  BartlettResult(statistic=1.8216957794370394, pvalue=0.4021830725324862)
# Groups are equal:  KruskalResult(statistic=2.152150010014009, pvalue=0.3409310556424645)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.622832434353968
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.9452001844223391
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.622832434353968
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.622832434353968
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.9452001844223391
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.622832434353968
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.0207652559590863, pvalue=0.36610952179084594)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.19734495700953683
# Groups are equal (independent t-test) between dataset 0 and 2:  0.5773771019802598
# Groups are equal (independent t-test) between dataset 1 and 0:  0.19734495700953683
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.2584493742215598
# Groups are equal (independent t-test) between dataset 2 and 0:  0.5773771019802598
# Groups are equal (independent t-test) between dataset 2 and 1:  0.2584493742215598
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TP6
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9537642002105713, pvalue=0.0760241225361824)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9021332263946533, pvalue=0.062598317861557)
# Variances are equal:  BartlettResult(statistic=1.0888189733317413, pvalue=0.5801842887616503)
# Groups are equal:  KruskalResult(statistic=3.0763053940244673, pvalue=0.21477749429230172)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.28797006605194386
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.9695340243620809
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.28797006605194386
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.28797006605194386
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.9695340243620809
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.28797006605194386
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.4821911926818672, pvalue=0.234830986099175)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.14974326321770906
# Groups are equal (independent t-test) between dataset 0 and 2:  0.5500748372406351
# Groups are equal (independent t-test) between dataset 1 and 0:  0.14974326321770906
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.0756211625276626
# Groups are equal (independent t-test) between dataset 2 and 0:  0.5500748372406351
# Groups are equal (independent t-test) between dataset 2 and 1:  0.0756211625276626
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TP7
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8225109577178955, pvalue=0.12207525968551636)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9114153385162354, pvalue=0.09112387150526047)
# Variances are equal:  BartlettResult(statistic=4.31302956984984, pvalue=0.11572775511405854)
# Groups are equal:  KruskalResult(statistic=2.868204684317698, pvalue=0.23832920610244746)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.6045947475449155
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.6045947475449155
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.6045947475449155
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.6045947475449155
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.0144827517069623, pvalue=0.3683455168027824)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.28194163147152373
# Groups are equal (independent t-test) between dataset 0 and 2:  0.23490219695250447
# Groups are equal (independent t-test) between dataset 1 and 0:  0.28194163147152373
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.7743621737637997
# Groups are equal (independent t-test) between dataset 2 and 0:  0.23490219695250447
# Groups are equal (independent t-test) between dataset 2 and 1:  0.7743621737637997
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TP8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9556060433387756, pvalue=0.7771040797233582)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9325701594352722, pvalue=0.21544042229652405)
# Variances are equal:  BartlettResult(statistic=3.6344251606916016, pvalue=0.16247801472818504)
# Groups are equal:  KruskalResult(statistic=3.321857655566207, pvalue=0.18996245572721382)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.3280279487091284
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.3280279487091284
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=2.0397086646666214, pvalue=0.13843713545224273)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.2590633766768999
# Groups are equal (independent t-test) between dataset 0 and 2:  0.05484174920943207
# Groups are equal (independent t-test) between dataset 1 and 0:  0.2590633766768999
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.9994206166224409
# Groups are equal (independent t-test) between dataset 2 and 0:  0.05484174920943207
# Groups are equal (independent t-test) between dataset 2 and 1:  0.9994206166224409
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TN1
# =================================
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9330692291259766, pvalue=0.2198159247636795)
# Variances are equal:  BartlettResult(statistic=0.7325665607508817, pvalue=0.6933063732992595)
# Groups are equal:  KruskalResult(statistic=1.6033723987076356, pvalue=0.4485719443307804)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.668843655082673
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.668843655082673
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.668843655082673
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.668843655082673
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.668843655082673
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.668843655082673
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.61203822989758, pvalue=0.545387447267725)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.5573823181699106
# Groups are equal (independent t-test) between dataset 0 and 2:  0.42923608434593796
# Groups are equal (independent t-test) between dataset 1 and 0:  0.5573823181699106
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.2651476438041196
# Groups are equal (independent t-test) between dataset 2 and 0:  0.42923608434593796
# Groups are equal (independent t-test) between dataset 2 and 1:  0.2651476438041196
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TN2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8989250063896179, pvalue=0.4039725959300995)
# Variances are equal:  BartlettResult(statistic=0.02130827369536993, pvalue=0.9894024174443843)
# Groups are equal:  KruskalResult(statistic=0.3666166396520844, pvalue=0.8325114363820477)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.06517057923466817, pvalue=0.936969726125283)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7247888730126915
# Groups are equal (independent t-test) between dataset 0 and 2:  0.8889976270789869
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7247888730126915
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.8061382203667308
# Groups are equal (independent t-test) between dataset 2 and 0:  0.8889976270789869
# Groups are equal (independent t-test) between dataset 2 and 1:  0.8061382203667308
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TN3
# =================================
# Variances are equal:  BartlettResult(statistic=0.16883895376181188, pvalue=0.9190456568202552)
# Groups are equal:  KruskalResult(statistic=1.6785505392067026, pvalue=0.43202351056990984)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.5763244099499648
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.5763244099499648
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.5763244099499648
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.5763244099499648
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.5763244099499648
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.5763244099499648
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.4508721760602936, pvalue=0.24196973112742484)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.2906876181530433
# Groups are equal (independent t-test) between dataset 0 and 2:  0.25608310493642594
# Groups are equal (independent t-test) between dataset 1 and 0:  0.2906876181530433
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.14058991254962924
# Groups are equal (independent t-test) between dataset 2 and 0:  0.25608310493642594
# Groups are equal (independent t-test) between dataset 2 and 1:  0.14058991254962924
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TN4
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.961514949798584, pvalue=0.14824558794498444)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.952588677406311, pvalue=0.7556636333465576)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9044539332389832, pvalue=0.06873396039009094)
# Variances are equal:  BartlettResult(statistic=2.8106341992765107, pvalue=0.2452892629828778)
# Groups are equal:  KruskalResult(statistic=3.2117405221566653, pvalue=0.20071480459977598)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.7626097391464196
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.45772803673170365
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.7626097391464196
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.45772803673170365
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.45772803673170365
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.45772803673170365
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.9680567514700567, pvalue=0.1480937836520173)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.514571322447009
# Groups are equal (independent t-test) between dataset 0 and 2:  0.0770932824136448
# Groups are equal (independent t-test) between dataset 1 and 0:  0.514571322447009
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.2151314643761724
# Groups are equal (independent t-test) between dataset 2 and 0:  0.0770932824136448
# Groups are equal (independent t-test) between dataset 2 and 1:  0.2151314643761724
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TN5
# =================================
# Variances are equal:  BartlettResult(statistic=1.807240190519544, pvalue=0.405100499696716)
# Groups are equal:  KruskalResult(statistic=2.437689355617576, pvalue=0.29557144999536844)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.6203944556536841
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.6719921954289844
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.6203944556536841
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.6203944556536841
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.6719921954289844
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.6203944556536841
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.2102375670469445, pvalue=0.3048567900802503)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.1320604413861758
# Groups are equal (independent t-test) between dataset 0 and 2:  0.7310745852302118
# Groups are equal (independent t-test) between dataset 1 and 0:  0.1320604413861758
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.17368294936120693
# Groups are equal (independent t-test) between dataset 2 and 0:  0.7310745852302118
# Groups are equal (independent t-test) between dataset 2 and 1:  0.17368294936120693
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TN6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.854285717010498, pvalue=0.20844902098178864)
# Variances are equal:  BartlettResult(statistic=1.2365132474231624, pvalue=0.5388830951505834)
# Groups are equal:  KruskalResult(statistic=1.0207654172109963, pvalue=0.6002658079571372)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.8767817809319941, pvalue=0.4210578194161487)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.33846051419419365
# Groups are equal (independent t-test) between dataset 0 and 2:  0.4695055194137562
# Groups are equal (independent t-test) between dataset 1 and 0:  0.33846051419419365
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.1972825448862649
# Groups are equal (independent t-test) between dataset 2 and 0:  0.4695055194137562
# Groups are equal (independent t-test) between dataset 2 and 1:  0.1972825448862649
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TN7
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.7992591857910156, pvalue=0.07991453260183334)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9252393245697021, pvalue=0.16004808247089386)
# Variances are equal:  BartlettResult(statistic=0.006420259449439271, pvalue=0.9967950172327651)
# Groups are equal:  KruskalResult(statistic=2.3135533604259346, pvalue=0.31449827737143576)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.6350768652688732
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.8776478953841143
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.6350768652688732
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.8776478953841143
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.32974970652496, pvalue=0.2717525531065688)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7509913463978619
# Groups are equal (independent t-test) between dataset 0 and 2:  0.1088812658910912
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7509913463978619
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.5496504827468373
# Groups are equal (independent t-test) between dataset 2 and 0:  0.1088812658910912
# Groups are equal (independent t-test) between dataset 2 and 1:  0.5496504827468373
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  TN8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.933292806148529, pvalue=0.6189908981323242)
# Variances are equal:  BartlettResult(statistic=3.0293130139953264, pvalue=0.2198837003899009)
# Groups are equal:  KruskalResult(statistic=0.27479875704853063, pvalue=0.8716220494817598)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.2207798502599519, pvalue=0.8025013719407222)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.6947329771754167
# Groups are equal (independent t-test) between dataset 0 and 2:  0.5309208759113133
# Groups are equal (independent t-test) between dataset 1 and 0:  0.6947329771754167
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.9860582376503535
# Groups are equal (independent t-test) between dataset 2 and 0:  0.5309208759113133
# Groups are equal (independent t-test) between dataset 2 and 1:  0.9860582376503535
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FP1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9416573643684387, pvalue=0.6776787638664246)
# Variances are equal:  BartlettResult(statistic=1.0623969387082088, pvalue=0.587899967206835)
# Groups are equal:  KruskalResult(statistic=3.4936755710728504, pvalue=0.17432432367934492)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.37391496936474655
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.37391496936474655
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.37391496936474655
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.30421424704573646
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.37391496936474655
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.30421424704573646
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.6115109059093399, pvalue=0.5456697210720551)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.36214083956130905
# Groups are equal (independent t-test) between dataset 0 and 2:  0.7149820873994372
# Groups are equal (independent t-test) between dataset 1 and 0:  0.36214083956130905
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.2158581849928312
# Groups are equal (independent t-test) between dataset 2 and 0:  0.7149820873994372
# Groups are equal (independent t-test) between dataset 2 and 1:  0.2158581849928312
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FP2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9503248333930969, pvalue=0.056574780493974686)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8771630525588989, pvalue=0.29665255546569824)
# Variances are equal:  BartlettResult(statistic=2.5877130966711315, pvalue=0.2742112324267918)
# Groups are equal:  KruskalResult(statistic=3.2738770466481233, pvalue=0.1945748176468517)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.6386456500545105
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.32736977546472423
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.6386456500545105
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.32736977546472423
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.32736977546472423
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.32736977546472423
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.7538524053632327, pvalue=0.18132270998311922)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.3820286602533909
# Groups are equal (independent t-test) between dataset 0 and 2:  0.14336494468997743
# Groups are equal (independent t-test) between dataset 1 and 0:  0.3820286602533909
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.0904912203093424
# Groups are equal (independent t-test) between dataset 2 and 0:  0.14336494468997743
# Groups are equal (independent t-test) between dataset 2 and 1:  0.0904912203093424
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FP3
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8462831974029541, pvalue=0.18305310606956482)
# Variances are equal:  BartlettResult(statistic=0.1425128945847584, pvalue=0.9312230518736787)
# Groups are equal:  KruskalResult(statistic=3.1651168871551114, pvalue=0.20544879608196948)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.6866871366580226
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.3281686825981442
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.6866871366580226
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.3281686825981442
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.3281686825981442
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.3281686825981442
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.2416091049177727, pvalue=0.2957835948125309)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.2795165676029179
# Groups are equal (independent t-test) between dataset 0 and 2:  0.36928765868857993
# Groups are equal (independent t-test) between dataset 1 and 0:  0.2795165676029179
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.12147812146204313
# Groups are equal (independent t-test) between dataset 2 and 0:  0.36928765868857993
# Groups are equal (independent t-test) between dataset 2 and 1:  0.12147812146204313
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FP4
# =================================
# Variances are equal:  BartlettResult(statistic=2.190768945804112, pvalue=0.334411010257627)
# Groups are equal:  KruskalResult(statistic=2.1359940413171343, pvalue=0.3436962449150897)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.6415235040535587
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.8282037316327145
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.6415235040535587
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.6415235040535587
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.8282037316327145
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.6415235040535587
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.561812963323764, pvalue=0.2176436983396715)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.14916223292887823
# Groups are equal (independent t-test) between dataset 0 and 2:  0.37814070180603865
# Groups are equal (independent t-test) between dataset 1 and 0:  0.14916223292887823
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.13610001185684437
# Groups are equal (independent t-test) between dataset 2 and 0:  0.37814070180603865
# Groups are equal (independent t-test) between dataset 2 and 1:  0.13610001185684437
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FP5
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9786375761032104, pvalue=0.9272021055221558)
# Variances are equal:  BartlettResult(statistic=3.1557871376616697, pvalue=0.2064094278539741)
# Groups are equal:  KruskalResult(statistic=3.2794095940959584, pvalue=0.19403731422501538)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.3220672280160699
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.944366906571904
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.3220672280160699
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.944366906571904
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.9715989579773341, pvalue=0.38398921412995457)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.9602297358648771
# Groups are equal (independent t-test) between dataset 0 and 2:  0.15967920068974362
# Groups are equal (independent t-test) between dataset 1 and 0:  0.9602297358648771
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.5588590452916721
# Groups are equal (independent t-test) between dataset 2 and 0:  0.15967920068974362
# Groups are equal (independent t-test) between dataset 2 and 1:  0.5588590452916721
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FP6
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8986545205116272, pvalue=0.4024937152862549)
# Variances are equal:  BartlettResult(statistic=1.3860489434641843, pvalue=0.5000613581784448)
# Groups are equal:  KruskalResult(statistic=1.4432868843447706, pvalue=0.48595296375018693)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.7098583182117933
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.7098583182117933
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.7098583182117933
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.7098583182117933
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.7098583182117933
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.7098583182117933
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.9773788147973715, pvalue=0.38184143017778405)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.5749136590444095
# Groups are equal (independent t-test) between dataset 0 and 2:  0.23890448464126843
# Groups are equal (independent t-test) between dataset 1 and 0:  0.5749136590444095
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.32756985620021173
# Groups are equal (independent t-test) between dataset 2 and 0:  0.23890448464126843
# Groups are equal (independent t-test) between dataset 2 and 1:  0.32756985620021173
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FP7
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8599671125411987, pvalue=0.22813042998313904)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9263268709182739, pvalue=0.16729021072387695)
# Variances are equal:  BartlettResult(statistic=1.7703414565505942, pvalue=0.4126437173146388)
# Significant difference between groups:  KruskalResult(statistic=9.278364919354823, pvalue=0.009665596413119561)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.5515144877443809
# Significant difference (Mann-Whitney U) between dataset 0 and 2:  0.02794093299263579
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.5515144877443809
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Significant difference (Mann-Whitney U) between dataset 1 and 2:  0.02794093299263579
# Significant difference (Mann-Whitney U) between dataset 2 and 0:  0.02794093299263579
# Significant difference (Mann-Whitney U) between dataset 2 and 1:  0.02794093299263579
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Significant difference between groups:  F_onewayResult(statistic=5.133594887777727, pvalue=0.008555698309952212)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.2968931600485623
# Statistical difference (independent t-test) between dataset 0 and 2:  0.007768259153248077
# Groups are equal (independent t-test) between dataset 1 and 0:  0.2968931600485623
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Statistical difference (independent t-test) between dataset 1 and 2:  0.02026184811409007
# Statistical difference (independent t-test) between dataset 2 and 0:  0.007768259153248077
# Statistical difference (independent t-test) between dataset 2 and 1:  0.02026184811409007
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FP8
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.902276337146759, pvalue=0.4225946366786957)
# Variances are equal:  BartlettResult(statistic=2.366418087376548, pvalue=0.30629424818571277)
# Groups are equal:  KruskalResult(statistic=0.6994942942440191, pvalue=0.704866294659151)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.33359452309194526, pvalue=0.7175822662158521)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.5682742968189021
# Groups are equal (independent t-test) between dataset 0 and 2:  0.674216294206823
# Groups are equal (independent t-test) between dataset 1 and 0:  0.5682742968189021
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.33144760605266754
# Groups are equal (independent t-test) between dataset 2 and 0:  0.674216294206823
# Groups are equal (independent t-test) between dataset 2 and 1:  0.33144760605266754
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FN1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8882954716682434, pvalue=0.3486050069332123)
# Variances are equal:  BartlettResult(statistic=0.6509102862117492, pvalue=0.7221985751245696)
# Groups are equal:  KruskalResult(statistic=1.166351255629947, pvalue=0.558123157931793)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.9118068904599694
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.892412979286338
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.9118068904599694
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.892412979286338
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.892412979286338
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.892412979286338
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.40558152703511896, pvalue=0.6682901894216564)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7597132147122863
# Groups are equal (independent t-test) between dataset 0 and 2:  0.42845587141914987
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7597132147122863
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.5209466946464347
# Groups are equal (independent t-test) between dataset 2 and 0:  0.42845587141914987
# Groups are equal (independent t-test) between dataset 2 and 1:  0.5209466946464347
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FN2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9630837440490723, pvalue=0.8292771577835083)
# Variances are equal:  BartlettResult(statistic=2.180047817196714, pvalue=0.33620845533771765)
# Groups are equal:  KruskalResult(statistic=0.3891503765422045, pvalue=0.8231842821266493)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.36758357292188376, pvalue=0.693857695814236)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.5959559965981552
# Groups are equal (independent t-test) between dataset 0 and 2:  0.5627386184380048
# Groups are equal (independent t-test) between dataset 1 and 0:  0.5959559965981552
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.4508918326181586
# Groups are equal (independent t-test) between dataset 2 and 0:  0.5627386184380048
# Groups are equal (independent t-test) between dataset 2 and 1:  0.4508918326181586
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  FN3
# =================================
# Groups are equal:  KruskalResult(statistic=3.408662261051383, pvalue=0.181894008846064)
# ...
# =================================
# Question:  FN8
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9554669260978699, pvalue=0.08804073929786682)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9273847937583923, pvalue=0.5786482095718384)
# Variances are equal:  BartlettResult(statistic=4.123201635053727, pvalue=0.12725010256667693)
# Groups are equal:  KruskalResult(statistic=4.285349682107169, pvalue=0.11734055553942968)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.18103347796532357
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.7387784137512784
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.18103347796532357
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.7387784137512784
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.8787416729790256, pvalue=0.4202553888467586)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7466260437952243
# Groups are equal (independent t-test) between dataset 0 and 2:  0.16850290653551583
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7466260437952243
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.6844409277398084
# Groups are equal (independent t-test) between dataset 2 and 0:  0.16850290653551583
# Groups are equal (independent t-test) between dataset 2 and 1:  0.6844409277398084
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  REJ1
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8983275890350342, pvalue=0.4007112979888916)
# Groups are equal:  KruskalResult(statistic=3.567132855226174, pvalue=0.168037782738233)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.9633497919829263
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.31343207331061873
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.9633497919829263
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.701690153823825
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.31343207331061873
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.701690153823825
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.3297033074000946, pvalue=0.2717646594035702)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.481787164650349
# Groups are equal (independent t-test) between dataset 0 and 2:  0.20143520317380015
# Groups are equal (independent t-test) between dataset 1 and 0:  0.481787164650349
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.07457280903913725
# Groups are equal (independent t-test) between dataset 2 and 0:  0.20143520317380015
# Groups are equal (independent t-test) between dataset 2 and 1:  0.07457280903913725
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  REJ2
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8489975333213806, pvalue=0.1913706660270691)
# Variances are equal:  BartlettResult(statistic=0.9208069344276162, pvalue=0.6310289946284453)
# Groups are equal:  KruskalResult(statistic=0.5772701981605268, pvalue=0.7492855705178725)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.2580223049527556, pvalue=0.7733777875058978)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.533178341056347
# Groups are equal (independent t-test) between dataset 0 and 2:  0.8139979563270141
# Groups are equal (independent t-test) between dataset 1 and 0:  0.533178341056347
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.46179289190983
# Groups are equal (independent t-test) between dataset 2 and 0:  0.8139979563270141
# Groups are equal (independent t-test) between dataset 2 and 1:  0.46179289190983
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  REJ3
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.8473416566848755, pvalue=0.18626107275485992)
# Variances are equal:  BartlettResult(statistic=1.767944416515143, pvalue=0.4131385755595487)
# Groups are equal:  KruskalResult(statistic=4.027726626707021, pvalue=0.13347203304955216)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.20663025285098455
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.8195654575609291
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.20663025285098455
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.8195654575609291
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.9628023406557338, pvalue=0.1488287189773525)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.6921015111428004
# Statistical difference (independent t-test) between dataset 0 and 2:  0.04340616528457826
# Groups are equal (independent t-test) between dataset 1 and 0:  0.6921015111428004
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.5059664676254052
# Statistical difference (independent t-test) between dataset 2 and 0:  0.04340616528457826
# Groups are equal (independent t-test) between dataset 2 and 1:  0.5059664676254052
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  REJ4
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9281641244888306, pvalue=0.583905816078186)
# Variances are equal:  BartlettResult(statistic=1.1901722467871096, pvalue=0.5515150654733765)
# Significant difference between groups:  KruskalResult(statistic=12.143677807467718, pvalue=0.002306927090854834)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.7761662275602373
# Significant difference (Mann-Whitney U) between dataset 0 and 2:  0.0016508913238688762
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.7761662275602373
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.7761662275602373
# Significant difference (Mann-Whitney U) between dataset 2 and 0:  0.0016508913238688762
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.7761662275602373
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Significant difference between groups:  F_onewayResult(statistic=5.194332598885331, pvalue=0.00811974997789837)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.47470190182876904
# Statistical difference (independent t-test) between dataset 0 and 2:  0.001538656202688832
# Groups are equal (independent t-test) between dataset 1 and 0:  0.47470190182876904
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.32121280594138835
# Statistical difference (independent t-test) between dataset 2 and 0:  0.001538656202688832
# Groups are equal (independent t-test) between dataset 2 and 1:  0.32121280594138835
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  REJ5
# =================================
# Variances are equal:  BartlettResult(statistic=1.466101749083839, pvalue=0.48044098670655033)
# Groups are equal:  KruskalResult(statistic=4.804983907569893, pvalue=0.09049216978022531)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.6872073215732988
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  0.2154833763666574
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.6872073215732988
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.2154833763666574
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  0.2154833763666574
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.2154833763666574
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=2.2898342853477627, pvalue=0.10952340705045364)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.303927122950432
# Groups are equal (independent t-test) between dataset 0 and 2:  0.08822699564127198
# Groups are equal (independent t-test) between dataset 1 and 0:  0.303927122950432
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.11788445867472029
# Groups are equal (independent t-test) between dataset 2 and 0:  0.08822699564127198
# Groups are equal (independent t-test) between dataset 2 and 1:  0.11788445867472029
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  REJ6
# =================================
# Variances are equal:  BartlettResult(statistic=0.7433015511183042, pvalue=0.6895950239150404)
# Groups are equal:  KruskalResult(statistic=0.8201513422746546, pvalue=0.6636000328671269)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=0.03856716499567709, pvalue=0.9621894226886268)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.7719225139276358
# Groups are equal (independent t-test) between dataset 0 and 2:  0.9602970393458266
# Groups are equal (independent t-test) between dataset 1 and 0:  0.7719225139276358
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.8363285647687724
# Groups are equal (independent t-test) between dataset 2 and 0:  0.9602970393458266
# Groups are equal (independent t-test) between dataset 2 and 1:  0.8363285647687724
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  REJ7
# =================================
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9546482563018799, pvalue=0.7703138589859009)
# Variances are equal:  BartlettResult(statistic=1.0099255714289657, pvalue=0.6035280348737393)
# Significant difference between groups:  KruskalResult(statistic=7.811516174074923, pvalue=0.020125691680766968)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Significant difference (Mann-Whitney U) between dataset 0 and 1:  0.016063601155835928
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Significant difference (Mann-Whitney U) between dataset 1 and 0:  0.016063601155835928
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.11245051567113622
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.11245051567113622
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Significant difference between groups:  F_onewayResult(statistic=6.321076186873102, pvalue=0.0031245897270729727)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Statistical difference (independent t-test) between dataset 0 and 1:  0.0009698595319833399
# Groups are equal (independent t-test) between dataset 0 and 2:  0.07136398943943849
# Statistical difference (independent t-test) between dataset 1 and 0:  0.0009698595319833399
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.07770509435283378
# Groups are equal (independent t-test) between dataset 2 and 0:  0.07136398943943849
# Groups are equal (independent t-test) between dataset 2 and 1:  0.07770509435283378
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
# =================================
# Question:  REJ8
# =================================
# Groups are equal:  KruskalResult(statistic=4.442999985376255, pvalue=0.10844631807884393)
# Groups are equal (Mann-Whitney U) between dataset 0 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 0 and 1:  0.10958744950490298
# Groups are equal (Mann-Whitney U) between dataset 0 and 2:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 0:  0.10958744950490298
# Groups are equal (Mann-Whitney U) between dataset 1 and 1:  1.0
# Groups are equal (Mann-Whitney U) between dataset 1 and 2:  0.10958744950490298
# Groups are equal (Mann-Whitney U) between dataset 2 and 0:  1.0
# Groups are equal (Mann-Whitney U) between dataset 2 and 1:  0.10958744950490298
# Groups are equal (Mann-Whitney U) between dataset 2 and 2:  1.0
# Groups are equal:  F_onewayResult(statistic=1.0336592009801677, pvalue=0.36156419694867264)
# Groups are equal (independent t-test) between dataset 0 and 0:  1.0
# Groups are equal (independent t-test) between dataset 0 and 1:  0.1854836874940761
# Groups are equal (independent t-test) between dataset 0 and 2:  0.7964306541777296
# Groups are equal (independent t-test) between dataset 1 and 0:  0.1854836874940761
# Groups are equal (independent t-test) between dataset 1 and 1:  1.0
# Groups are equal (independent t-test) between dataset 1 and 2:  0.13371862799672077
# Groups are equal (independent t-test) between dataset 2 and 0:  0.7964306541777296
# Groups are equal (independent t-test) between dataset 2 and 1:  0.13371862799672077
# Groups are equal (independent t-test) between dataset 2 and 2:  1.0
