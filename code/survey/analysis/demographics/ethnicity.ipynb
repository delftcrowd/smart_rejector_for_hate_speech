# %%
import sys
sys.path.insert(0,'..')
from analysis import Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATH100_BATCH2_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-2 100.csv"
PATH100_BATCH3_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-3 100.csv"
PATH100_BATCH4_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-4 100.csv"
PATHME_BATCH2_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-2 ME.csv"
PATHME_BATCH3_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-3 ME.csv"
PATHME_BATCH4_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-4 ME.csv"

PATH100_BATCH2 = "F:\Thesis\Experiments\Costs\Results\/25-06-2022 Batch-2 100.csv"
PATH100_BATCH3 = "F:\Thesis\Experiments\Costs\Results\/27-06-2022 Batch-3 100.csv"
PATH100_BATCH4 = "F:\Thesis\Experiments\Costs\Results\/28-06-2022 Batch-4 100.csv"
PATHME_BATCH2 = "F:\Thesis\Experiments\Costs\Results\/24-06-2022 Batch-2 ME.csv"
PATHME_BATCH3 = "F:\Thesis\Experiments\Costs\Results\/27-06-2022 Batch-3 ME.csv"
PATHME_BATCH4 = "F:\Thesis\Experiments\Costs\Results\/28-06-2022 Batch-4 ME.csv"
data100_batch2_demo = pd.read_csv(PATH100_BATCH2_DEMO)
data100_batch3_demo = pd.read_csv(PATH100_BATCH3_DEMO)
data100_batch4_demo = pd.read_csv(PATH100_BATCH4_DEMO)
datame_batch2_demo = pd.read_csv(PATHME_BATCH2_DEMO)
datame_batch3_demo = pd.read_csv(PATHME_BATCH3_DEMO)
datame_batch4_demo = pd.read_csv(PATHME_BATCH4_DEMO)

data100_batch2 = pd.read_csv(PATH100_BATCH2)
data100_batch3 = pd.read_csv(PATH100_BATCH3)
data100_batch4 = pd.read_csv(PATH100_BATCH4)
datame_batch2 = pd.read_csv(PATHME_BATCH2)
datame_batch3 = pd.read_csv(PATHME_BATCH3)
datame_batch4 = pd.read_csv(PATHME_BATCH4)

data100_demo = pd.concat([data100_batch2_demo, data100_batch3_demo, data100_batch4_demo], ignore_index=True)
datame_demo = pd.concat([datame_batch2_demo, datame_batch3_demo, datame_batch4_demo], ignore_index=True)

data100 = pd.concat([data100_batch2, data100_batch3, data100_batch4], ignore_index=True)
datame = pd.concat([datame_batch2, datame_batch3, datame_batch4], ignore_index=True)

s100_data = Analysis.convert_100_data(data100)
mes_data = Analysis.convert_me_data(datame)

data100_demo = Analysis.filter_demographics_data(demo_data=data100_demo, data=s100_data)
datame_demo = Analysis.filter_demographics_data(demo_data=datame_demo, data=mes_data)

s100_data_white = Analysis.filter_data(demo_data=data100_demo, data=s100_data, column_name="Ethnicity", column_value="White")
s100_data_mixed = Analysis.filter_data(demo_data=data100_demo, data=s100_data, column_name="Ethnicity", column_value="Mixed")
s100_data_asian = Analysis.filter_data(demo_data=data100_demo, data=s100_data, column_name="Ethnicity", column_value="Asian")
s100_data_black = Analysis.filter_data(demo_data=data100_demo, data=s100_data, column_name="Ethnicity", column_value="Black")
s100_data_other = Analysis.filter_data(demo_data=data100_demo, data=s100_data, column_name="Ethnicity", column_value="Other")
mes_data_white = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Ethnicity", column_value="White")
mes_data_mixed = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Ethnicity", column_value="Mixed")
mes_data_asian = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Ethnicity", column_value="Asian")
mes_data_black = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Ethnicity", column_value="Black")
mes_data_other = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Ethnicity", column_value="Other")

# %%
print("S100 - White: ", s100_data_white.shape)
print("S100 - Mixed: ", s100_data_mixed.shape)
print("S100 - Asian: ", s100_data_asian.shape)
print("S100 - Black: ", s100_data_black.shape)
print("S100 - Other: ", s100_data_other.shape)
print("ME - White: ", mes_data_white.shape)
print("ME - Mixed: ", mes_data_mixed.shape)
print("ME - Asian: ", mes_data_asian.shape)
print("ME - Black: ", mes_data_black.shape)
print("ME - Other: ", mes_data_other.shape)
# Out:
# S100 - White:  (47, 82)
# S100 - Mixed:  (9, 82)
# S100 - Asian:  (2, 82)
# S100 - Black:  (6, 82)
# S100 - Other:  (4, 82)
# ME - White:  (44, 82)
# ME - Mixed:  (5, 82)
# ME - Asian:  (0, 0)
# ME - Black:  (18, 82)
# ME - Other:  (1, 82)

# %%
print("S100 scale - White")
Analysis.print_means(s100_data_white)
print("S100 scale - Mixed")
Analysis.print_means(s100_data_mixed)
print("S100 scale - Asian")
Analysis.print_means(s100_data_asian)
print("S100 scale - Black")
Analysis.print_means(s100_data_black)
print("S100 scale - Other")
Analysis.print_means(s100_data_other)

print("ME scale - White")
Analysis.print_means(mes_data_white)
print("ME scale - Mixed")
Analysis.print_means(mes_data_mixed)
print("ME scale - Asian")
Analysis.print_means(mes_data_asian)
print("ME scale - Black")
Analysis.print_means(mes_data_black)
print("ME scale - Other")
Analysis.print_means(mes_data_other)
# Out:
# S100 scale - White
# ...
# TP 73.25
# TN 87.0
# FP -49.25
# FN -57.625
# REJ -14.875
# ...
# S100 scale - Mixed
# ...
# TP 72.375
# TN 89.0
# FP -49.125
# FN -88.125
# REJ -42.25
# ...
# S100 scale - Asian
# ...
# TP 51.4375
# TN 68.9375
# FP -57.125
# FN -22.5625
# REJ -47.375
# ...
# S100 scale - Black
# ...
# TP 77.1875
# TN 42.375
# FP -30.5625
# FN -78.1875
# REJ -35.5
# ...
# S100 scale - Other
# ...
# TP 60.6875
# TN 79.625
# FP -47.5
# FN -62.9375
# REJ -13.125
# ...
# ME scale - White
# ...
# TP 26.376488095238095
# TN 39.854166666666664
# FP -24.825907590759076
# FN -31.546240941473428
# REJ -6.40958630952381
# ...
# ME scale - Mixed
# ...
# TP 49.285714285714285
# TN 58.18318318318318
# FP -46.60877714449143
# FN -43.25255102040816
# REJ -25.005005005005003
# ...
# ME scale - Asian
# ...
# TP nan
# TN nan
# FP nan
# FN nan
# REJ nan
# ...
# ME scale - Black
# ...
# TP 10.941079753579753
# TN 20.16318142227281
# FP -1.968750449545166
# FN -25.817628205128205
# REJ -0.8132933149989422
# ...
# ME scale - Other
# ...
# TP 1.9999999999999998
# TN 44.5
# FP -37.75
# FN -16.5
# REJ -1.25
# ...

# %%
print("S100 - White")
Analysis.print_reliabilities(s100_data_white, scale="S100")
print("S100 - Mixed")
Analysis.print_reliabilities(s100_data_mixed, scale="S100")
print("S100 - Asian")
Analysis.print_reliabilities(s100_data_asian, scale="S100")
print("S100 - Black")
Analysis.print_reliabilities(s100_data_black, scale="S100")
print("S100 - Other")
Analysis.print_reliabilities(s100_data_other, scale="S100")

print("ME - White")
Analysis.print_reliabilities(mes_data_white, scale="ME")
print("ME - Mixed")
Analysis.print_reliabilities(mes_data_mixed, scale="ME")
print("ME - Asian")
Analysis.print_reliabilities(mes_data_asian, scale="ME")
print("ME - Black")
Analysis.print_reliabilities(mes_data_black, scale="ME")
print("ME - Other")
Analysis.print_reliabilities(mes_data_other, scale="ME")
# Out:
# S100 - White
# ...
# Reliability scale:  0.44896866385870027
# TP 0.04685580993464045
# TN 0.09851664370093227
# FP 0.053275502581557665
# FN 0.1543723390024968
# REJ 0.0847582649852262
# ...
# S100 - Mixed
# ...
# Reliability scale:  0.5604752638881885
# TP 0.13030583842169563
# TN 0.09979449904233473
# FP 0.11024018602844521
# FN 0.04948848889262214
# REJ 0.1288820477421182
# ...
# S100 - Asian
# ...
# Reliability scale:  0.18077444019588562
# TP -0.4597267130791385
# TN -0.12424341377992931
# FP -0.11712310002462223
# FN -0.3903831874633341
# REJ -0.3449748082798809
# ...
# S100 - Black
# ...
# Reliability scale:  0.27477983119980576
# TP -0.09669040493958092
# TN 0.07494668203692179
# FP 0.1383154415147565
# FN -0.028925883659386642
# REJ -0.024786511157700142
# ...
# S100 - Other
# ...
# Reliability scale:  0.2429516596788136
# TP -0.23681928271742403
# TN -0.043773675119396005
# FP -0.18879135195565988
# FN 0.18939738450919974
# REJ 0.22639455138469033
# ...
# ME - White
# ...
# Reliability scale:  0.9639234181450919
# TP 0.24917045523882364
# ...

# %%
Analysis.print_question_statistics_multiple(mes_data_white, mes_data_mixed, mes_data_black)
# Out:
# ...
# Question:  TP1
# ...
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.780037522315979, pvalue=0.05516137182712555)
# Dataset 2 is normally distributed:  ShapiroResult(statistic=0.9060991406440735, pvalue=0.07345669716596603)
# Variances are equal:  BartlettResult(statistic=2.008443888732512, pvalue=0.36632954871939183)
# ...
# Question:  TP2
# ...
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9628541469573975, pvalue=0.8277052044868469)
# Variances are equal:  BartlettResult(statistic=2.3803148016285625, pvalue=0.3041733831603639)
# ...
# Question:  TP3
# ...
# Variances are equal:  BartlettResult(statistic=1.8588615832472126, pvalue=0.39477835757795215)
# ...
# Question:  TP4
# ...
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9388766884803772, pvalue=0.6580075621604919)
# Variances are equal:  BartlettResult(statistic=0.6736188978101569, pvalue=0.7140448889755758)
# ...
# Question:  TP5
# ...
