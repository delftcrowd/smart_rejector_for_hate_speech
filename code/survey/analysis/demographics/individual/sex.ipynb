# %%
import sys
sys.path.insert(0,'../..')
from analysis import Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATHME_BATCH2_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-2 ME.csv"
PATHME_BATCH3_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-3 ME.csv"
PATHME_BATCH4_DEMO = "F:\Thesis\Experiments\Costs\Results\/demographics Batch-4 ME.csv"

PATHME_BATCH2 = "F:\Thesis\Experiments\Costs\Results\/24-06-2022 Batch-2 ME.csv"
PATHME_BATCH3 = "F:\Thesis\Experiments\Costs\Results\/27-06-2022 Batch-3 ME.csv"
PATHME_BATCH4 = "F:\Thesis\Experiments\Costs\Results\/28-06-2022 Batch-4 ME.csv"

datame_batch2_demo = pd.read_csv(PATHME_BATCH2_DEMO)
datame_batch3_demo = pd.read_csv(PATHME_BATCH3_DEMO)
datame_batch4_demo = pd.read_csv(PATHME_BATCH4_DEMO)

datame_batch2 = pd.read_csv(PATHME_BATCH2)
datame_batch3 = pd.read_csv(PATHME_BATCH3)
datame_batch4 = pd.read_csv(PATHME_BATCH4)

datame_demo = pd.concat([datame_batch2_demo, datame_batch3_demo, datame_batch4_demo], ignore_index=True)

datame = pd.concat([datame_batch2, datame_batch3, datame_batch4], ignore_index=True)

mes_data = Analysis.convert_me_data(datame)

datame_demo = Analysis.filter_demographics_data(demo_data=datame_demo, data=mes_data)

mes_data_male = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Sex", column_value="Male")
mes_data_female = Analysis.filter_data(demo_data=datame_demo, data=mes_data, column_name="Sex", column_value="Female")

# %%
print(mes_data_male.shape)
print(mes_data_female.shape)
# Out:
# (36, 82)
# (32, 82)

# %%
print("Male")
Analysis.print_means(mes_data_male)
print("Female")
Analysis.print_means(mes_data_female)
# Out:
# Male
# ===================
# TP 16.923785360678927
# TN 33.97236654971803
# FP -14.73383377679222
# FN -29.7191722972973
# REJ -4.79042904290429
# ===================
# Female
# ===================
# TP 21.170370046620043
# TN 39.60828754578754
# FP -17.110417438541667
# FN -29.668353174047617
# REJ -4.896220476576994
# ===================

# %%
print("Male")
Analysis.print_reliabilities(mes_data_male, scale="ME")
print("Female")
Analysis.print_reliabilities(mes_data_female, scale="ME")
# Out:
# Male
# ===================
# Reliability scale:  0.5052485422568089
# TP -0.8510921357909076
# TN 0.9867165077785699
# FP 0.1785317389153377
# FN 0.9613552805025694
# REJ -1.0101246894582956
# ===================
# Female
# ===================
# Reliability scale:  0.7335021353257292
# TP -0.7061043131160138
# TN 0.33856604318137573
# FP 0.4652846835195755
# FN -0.14137755749034597
# REJ -0.2874958688000546
# ===================

# %%
Analysis.print_question_statistics(data1=mes_data_male, data2=mes_data_female)
# Out:
# =================================
# Question:  TP1
# =================================
# Variances are equal:  BartlettResult(statistic=0.08422761076695354, pvalue=0.7716479861591651)
# =================================
# Question:  TP2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9494827389717102, pvalue=0.1007256731390953)
# Variances are equal:  BartlettResult(statistic=0.003989481517777998, pvalue=0.9496372311600395)
# =================================
# Question:  TP3
# =================================
# Variances are equal:  BartlettResult(statistic=0.24629789729500226, pvalue=0.6196939902136471)
# =================================
# Question:  TP4
# =================================
# Variances are equal:  BartlettResult(statistic=0.3344130749945294, pvalue=0.5630719919413607)
# =================================
# Question:  TP5
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9448084831237793, pvalue=0.07180594652891159)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9537239074707031, pvalue=0.18371444940567017)
# Variances are equal:  BartlettResult(statistic=0.2252433951732291, pvalue=0.6350734317456932)
# =================================
# Question:  TP6
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9509520530700684, pvalue=0.11204824596643448)
# Variances are equal:  BartlettResult(statistic=0.2516684195879089, pvalue=0.6159027343858066)
# =================================
# Question:  TP7
# =================================
# Variances are equal:  BartlettResult(statistic=0.024856675348938782, pvalue=0.874724722203607)
# =================================
# Question:  TP8
# =================================
# Variances are equal:  BartlettResult(statistic=0.18277602489107878, pvalue=0.6689983433031026)
# =================================
# Question:  TN1
# =================================
# Variances are equal:  BartlettResult(statistic=0.0023030399996186064, pvalue=0.9617242131031731)
# =================================
# Question:  TN2
# =================================
# Variances are equal:  BartlettResult(statistic=0.013326443546171213, pvalue=0.9080962039994069)
# =================================
# Question:  TN3
# =================================
# Variances are equal:  BartlettResult(statistic=0.04781032353636258, pvalue=0.826918245212162)
# =================================
# Question:  TN4
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9498185515403748, pvalue=0.10320837050676346)
# Dataset 1 is normally distributed:  ShapiroResult(statistic=0.9409806132316589, pvalue=0.07982270419597626)
# Variances are equal:  BartlettResult(statistic=0.7254478168689278, pvalue=0.3943627196399163)
# =================================
# Question:  TN5
# =================================
# Variances are equal:  BartlettResult(statistic=0.011802123112119796, pvalue=0.9134899550801414)
# =================================
# Question:  TN6
# =================================
# Variances are equal:  BartlettResult(statistic=0.027069977864172427, pvalue=0.8693142741145434)
# =================================
# Question:  TN7
# =================================
# Variances are equal:  BartlettResult(statistic=2.4598982345375533, pvalue=0.11678634827542277)
# =================================
# Question:  TN8
# =================================
# Variances are equal:  BartlettResult(statistic=0.48409475995752443, pvalue=0.48657338963574936)
# =================================
# Question:  FP1
# =================================
# Variances are equal:  BartlettResult(statistic=0.02650748093121998, pvalue=0.8706671039121459)
# =================================
# Question:  FP2
# =================================
# Variances are equal:  BartlettResult(statistic=0.017389399195779053, pvalue=0.895088010738857)
# =================================
# Question:  FP3
# =================================
# =================================
# Question:  FP4
# =================================
# Variances are equal:  BartlettResult(statistic=0.002124492281503804, pvalue=0.9632367509636205)
# =================================
# Question:  FP5
# =================================
# Variances are equal:  BartlettResult(statistic=0.17352083310333363, pvalue=0.6770015019969854)
# =================================
# Question:  FP6
# =================================
# Variances are equal:  BartlettResult(statistic=0.06416419611266182, pvalue=0.8000313535103724)
# =================================
# Question:  FP7
# =================================
# Variances are equal:  BartlettResult(statistic=0.8607136934480714, pvalue=0.3535390466116506)
# =================================
# Question:  FP8
# =================================
# Variances are equal:  BartlettResult(statistic=0.00284919574409582, pvalue=0.9574308466688297)
# =================================
# Question:  FN1
# =================================
# Variances are equal:  BartlettResult(statistic=0.16598402879120225, pvalue=0.6837058735561323)
# =================================
# Question:  FN2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.948577344417572, pvalue=0.09432681649923325)
# Variances are equal:  BartlettResult(statistic=2.266919061187327, pvalue=0.13216240754720424)
# =================================
# Question:  FN3
# =================================
# Variances are equal:  BartlettResult(statistic=0.8232488021894857, pvalue=0.36423200158521085)
# =================================
# Question:  FN4
# =================================
# Variances are equal:  BartlettResult(statistic=2.037530012107175, pvalue=0.15345865185930613)
# =================================
# Question:  FN5
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9773725271224976, pvalue=0.6561525464057922)
# Variances are equal:  BartlettResult(statistic=0.31190450893835736, pvalue=0.5765138473203592)
# =================================
# Question:  FN6
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9505318999290466, pvalue=0.10868661850690842)
# Variances are equal:  BartlettResult(statistic=0.1898064735858501, pvalue=0.6630777366742671)
# =================================
# Question:  FN7
# =================================
# Variances are equal:  BartlettResult(statistic=1.6023831890055538, pvalue=0.205565804847594)
# =================================
# Question:  FN8
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9440115094184875, pvalue=0.067790687084198)
# Variances are equal:  BartlettResult(statistic=0.5811171864606585, pvalue=0.44587475240249763)
# =================================
# Question:  REJ1
# =================================
# Variances are equal:  BartlettResult(statistic=2.8178533060494684, pvalue=0.0932210028701591)
# =================================
# Question:  REJ2
# =================================
# Dataset 0 is normally distributed:  ShapiroResult(statistic=0.9417517781257629, pvalue=0.05760655179619789)
# Variances are equal:  BartlettResult(statistic=0.19533558148808697, pvalue=0.658512469973499)
# =================================
# Question:  REJ3
# =================================
# Variances are equal:  BartlettResult(statistic=0.7977505575913493, pvalue=0.3717667679201576)
# =================================
# Question:  REJ4
# =================================
# =================================
# Question:  REJ5
# =================================
# Variances are equal:  BartlettResult(statistic=0.00930927928903051, pvalue=0.9231356991276638)
# =================================
# Question:  REJ6
# =================================
# Variances are equal:  BartlettResult(statistic=0.17511120571902294, pvalue=0.6756087001480198)
# =================================
# Question:  REJ7
# =================================
# Variances are equal:  BartlettResult(statistic=0.40946857461419744, pvalue=0.522239359174469)
# =================================
# Question:  REJ8
# =================================
# Variances are equal:  BartlettResult(statistic=0.04423175651074437, pvalue=0.8334230212768994)
